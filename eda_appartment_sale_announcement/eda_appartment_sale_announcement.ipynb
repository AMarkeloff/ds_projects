# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Изучение-данных-из-файла" data-toc-modified-id="Изучение-данных-из-файла-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Изучение данных из файла</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Изменение-названий-столбцов" data-toc-modified-id="Изменение-названий-столбцов-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Изменение названий столбцов</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Обработка-пропусков" data-toc-modified-id="Обработка-пропусков-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Обработка пропусков</a></span><ul class="toc-item"><li><span><a href="#Столбцы-is_apartment-и-balcony" data-toc-modified-id="Столбцы-is_apartment-и-balcony-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>Столбцы <code>is_apartment</code> и <code>balcony</code></a></span></li><li><span><a href="#Количество-парков-и-прудов,-расстояние-до-них" data-toc-modified-id="Количество-парков-и-прудов,-расстояние-до-них-2.2.2"><span class="toc-item-num">2.2.2&nbsp;&nbsp;</span>Количество парков и прудов, расстояние до них</a></span><ul class="toc-item"><li><span><a href="#Столбцы-parks_around_3000,-ponds_around_3000,-airports_nearest-и-city_centers_nearest" data-toc-modified-id="Столбцы-parks_around_3000,-ponds_around_3000,-airports_nearest-и-city_centers_nearest-2.2.2.1"><span class="toc-item-num">2.2.2.1&nbsp;&nbsp;</span>Столбцы <code>parks_around_3000</code>, <code>ponds_around_3000</code>, <code>airports_nearest</code> и <code>city_centers_nearest</code></a></span></li><li><span><a href="#Столбцы-parks_nearest-и-ponds_nearest" data-toc-modified-id="Столбцы-parks_nearest-и-ponds_nearest-2.2.2.2"><span class="toc-item-num">2.2.2.2&nbsp;&nbsp;</span>Столбцы <code>parks_nearest</code> и <code>ponds_nearest</code></a></span></li></ul></li><li><span><a href="#Столбец-floors_total" data-toc-modified-id="Столбец-floors_total-2.2.3"><span class="toc-item-num">2.2.3&nbsp;&nbsp;</span>Столбец <code>floors_total</code></a></span></li><li><span><a href="#Столбец-locality_name" data-toc-modified-id="Столбец-locality_name-2.2.4"><span class="toc-item-num">2.2.4&nbsp;&nbsp;</span>Столбец <code>locality_name</code></a></span></li><li><span><a href="#Столбец-ceiling_height" data-toc-modified-id="Столбец-ceiling_height-2.2.5"><span class="toc-item-num">2.2.5&nbsp;&nbsp;</span>Столбец <code>ceiling_height</code></a></span></li><li><span><a href="#Столбец-days_exposition" data-toc-modified-id="Столбец-days_exposition-2.2.6"><span class="toc-item-num">2.2.6&nbsp;&nbsp;</span>Столбец <code>days_exposition</code></a></span></li><li><span><a href="#Площадь-кухни-и-общая-площадь" data-toc-modified-id="Площадь-кухни-и-общая-площадь-2.2.7"><span class="toc-item-num">2.2.7&nbsp;&nbsp;</span>Площадь кухни и общая площадь</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-2.2.8"><span class="toc-item-num">2.2.8&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Изменение-типа-данных" data-toc-modified-id="Изменение-типа-данных-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Изменение типа данных</a></span><ul class="toc-item"><li><span><a href="#Замена-вещественного-типа-на-целочисленный" data-toc-modified-id="Замена-вещественного-типа-на-целочисленный-2.3.1"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span>Замена вещественного типа на целочисленный</a></span></li><li><span><a href="#Замена-типа-obj-на-формат-даты-и-времени" data-toc-modified-id="Замена-типа-obj-на-формат-даты-и-времени-2.3.2"><span class="toc-item-num">2.3.2&nbsp;&nbsp;</span>Замена типа <code>obj</code> на формат даты и времени</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-2.3.3"><span class="toc-item-num">2.3.3&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li></ul></li><li><span><a href="#Расчёты-и-добавление-результатов-в-таблицу" data-toc-modified-id="Расчёты-и-добавление-результатов-в-таблицу-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Расчёты и добавление результатов в таблицу</a></span><ul class="toc-item"><li><span><a href="#Расчет-цены-квадратного-метра" data-toc-modified-id="Расчет-цены-квадратного-метра-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Расчет цены квадратного метра</a></span></li><li><span><a href="#Определние-дня-недели,-месяца-и-года-размещения-объявления" data-toc-modified-id="Определние-дня-недели,-месяца-и-года-размещения-объявления-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Определние дня недели, месяца и года размещения объявления</a></span></li><li><span><a href="#Категория-по-этажу---первый,-последний,-другой" data-toc-modified-id="Категория-по-этажу---первый,-последний,-другой-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Категория по этажу - первый, последний, другой</a></span></li><li><span><a href="#Соотношение-площадей" data-toc-modified-id="Соотношение-площадей-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Соотношение площадей</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Изучение-основных-параметров:-площадь,-цена,-число-комнат,-высота-потолков" data-toc-modified-id="Изучение-основных-параметров:-площадь,-цена,-число-комнат,-высота-потолков-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Изучение основных параметров: площадь, цена, число комнат, высота потолков</a></span><ul class="toc-item"><li><span><a href="#Общая-площадь" data-toc-modified-id="Общая-площадь-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>Общая площадь</a></span></li><li><span><a href="#Цена" data-toc-modified-id="Цена-4.1.2"><span class="toc-item-num">4.1.2&nbsp;&nbsp;</span>Цена</a></span></li><li><span><a href="#Число-комнат" data-toc-modified-id="Число-комнат-4.1.3"><span class="toc-item-num">4.1.3&nbsp;&nbsp;</span>Число комнат</a></span></li><li><span><a href="#Высота-потолков" data-toc-modified-id="Высота-потолков-4.1.4"><span class="toc-item-num">4.1.4&nbsp;&nbsp;</span>Высота потолков</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-4.1.5"><span class="toc-item-num">4.1.5&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Время-продажи-квартиры" data-toc-modified-id="Время-продажи-квартиры-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Время продажи квартиры</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-4.2.1"><span class="toc-item-num">4.2.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Факторы,-влияющие-на-стоимость-квартиры" data-toc-modified-id="Факторы,-влияющие-на-стоимость-квартиры-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Факторы, влияющие на стоимость квартиры</a></span><ul class="toc-item"><li><span><a href="#Стоимость-квадратного-метра" data-toc-modified-id="Стоимость-квадратного-метра-4.3.1"><span class="toc-item-num">4.3.1&nbsp;&nbsp;</span>Стоимость квадратного метра</a></span></li><li><span><a href="#Зависимость-от-площади-квартиры" data-toc-modified-id="Зависимость-от-площади-квартиры-4.3.2"><span class="toc-item-num">4.3.2&nbsp;&nbsp;</span>Зависимость от площади квартиры</a></span></li><li><span><a href="#Зависимость-от-числа-комнат" data-toc-modified-id="Зависимость-от-числа-комнат-4.3.3"><span class="toc-item-num">4.3.3&nbsp;&nbsp;</span>Зависимость от числа комнат</a></span></li><li><span><a href="#Влияние-этажа" data-toc-modified-id="Влияние-этажа-4.3.4"><span class="toc-item-num">4.3.4&nbsp;&nbsp;</span>Влияние этажа</a></span></li><li><span><a href="#Влияние-удалённости-от-центра" data-toc-modified-id="Влияние-удалённости-от-центра-4.3.5"><span class="toc-item-num">4.3.5&nbsp;&nbsp;</span>Влияние удалённости от центра</a></span></li><li><span><a href="#Влияние-времени-размещения-(день-недели,-месяц,-год)" data-toc-modified-id="Влияние-времени-размещения-(день-недели,-месяц,-год)-4.3.6"><span class="toc-item-num">4.3.6&nbsp;&nbsp;</span>Влияние времени размещения (день недели, месяц, год)</a></span><ul class="toc-item"><li><span><a href="#День-недели" data-toc-modified-id="День-недели-4.3.6.1"><span class="toc-item-num">4.3.6.1&nbsp;&nbsp;</span>День недели</a></span></li><li><span><a href="#Месяц-продажи" data-toc-modified-id="Месяц-продажи-4.3.6.2"><span class="toc-item-num">4.3.6.2&nbsp;&nbsp;</span>Месяц продажи</a></span></li><li><span><a href="#Год-продажи" data-toc-modified-id="Год-продажи-4.3.6.3"><span class="toc-item-num">4.3.6.3&nbsp;&nbsp;</span>Год продажи</a></span></li></ul></li><li><span><a href="#Влияние-населённого-пункта" data-toc-modified-id="Влияние-населённого-пункта-4.3.7"><span class="toc-item-num">4.3.7&nbsp;&nbsp;</span>Влияние населённого пункта</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-4.3.8"><span class="toc-item-num">4.3.8&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Предложения-квартир-по-населённым-пунктам" data-toc-modified-id="Предложения-квартир-по-населённым-пунктам-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Предложения квартир по населённым пунктам</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-4.4.1"><span class="toc-item-num">4.4.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Анализ-предложений-в-центре-Санкт-Петербурга" data-toc-modified-id="Анализ-предложений-в-центре-Санкт-Петербурга-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Анализ предложений в центре Санкт-Петербурга</a></span><ul class="toc-item"><li><span><a href="#Анализ-основных-параметров" data-toc-modified-id="Анализ-основных-параметров-4.5.1"><span class="toc-item-num">4.5.1&nbsp;&nbsp;</span>Анализ основных параметров</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-4.5.1.1"><span class="toc-item-num">4.5.1.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Факторы,-влияющие-на-цену-квартир-в-центре" data-toc-modified-id="Факторы,-влияющие-на-цену-квартир-в-центре-4.5.2"><span class="toc-item-num">4.5.2&nbsp;&nbsp;</span>Факторы, влияющие на цену квартир в центре</a></span><ul class="toc-item"><li><span><a href="#Общая-площадь" data-toc-modified-id="Общая-площадь-4.5.2.1"><span class="toc-item-num">4.5.2.1&nbsp;&nbsp;</span>Общая площадь</a></span></li><li><span><a href="#Этаж" data-toc-modified-id="Этаж-4.5.2.2"><span class="toc-item-num">4.5.2.2&nbsp;&nbsp;</span>Этаж</a></span></li><li><span><a href="#Расстояние-до-центра" data-toc-modified-id="Расстояние-до-центра-4.5.2.3"><span class="toc-item-num">4.5.2.3&nbsp;&nbsp;</span>Расстояние до центра</a></span></li><li><span><a href="#Число-комнат" data-toc-modified-id="Число-комнат-4.5.2.4"><span class="toc-item-num">4.5.2.4&nbsp;&nbsp;</span>Число комнат</a></span></li><li><span><a href="#Время-размещения" data-toc-modified-id="Время-размещения-4.5.2.5"><span class="toc-item-num">4.5.2.5&nbsp;&nbsp;</span>Время размещения</a></span></li><li><span><a href="#Дополнительные-параметры" data-toc-modified-id="Дополнительные-параметры-4.5.2.6"><span class="toc-item-num">4.5.2.6&nbsp;&nbsp;</span>Дополнительные параметры</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-4.5.2.7"><span class="toc-item-num">4.5.2.7&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Общий вывод</a></span></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span></li></ul></div>

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В нашем распоряжении данные сервиса Яндекс.Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктах за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Наша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.
#
# **Цель исследования**
#
# Установить параметры для автоматизированного определения рыночной стоимости объектов недвижимости.
#
# Показатель рыночной стоимости объекта недвижимости - **стоимость квадратного метра**.
# Нам предстоит определить параметры, оказывающие наибольше влияние на стоимость квадратного метра и проследить зависимость от них.

# %% [markdown]
# ## Изучение данных из файла

# %% [markdown]
# Составим первое впечатление об архиве объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктах за несколько лет.
#
# Для начала импортируем библиотеку `pandas` и модуль `pyplot` библиотеки `matplotlib`:

# %%
# импорт библиотеки pandas
import pandas as pd

# импорт pyplot из библиотеки matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# Прочитаем файл `real_estate_data.csv` из папки `/datasets`.
#
# В качестве разделителя столбцов зададим `\t`.
#
# Cохраним исходный датафрейм в переменной `df`:

# %%
# чтение файла с данными и сохранение в df
df = pd.read_csv('/datasets/real_estate_data.csv', sep='\t')

# %% [markdown]
# Выведем на экран первые 10 строк таблицы `df`:

# %%
# получение первых 10 строк таблицы df
df.head(10)
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0      108.00  2019-03-07T00:00:00      3
# 1             7   3350000.0       40.40  2018-12-04T00:00:00      1
# 2            10   5196000.0       56.00  2015-08-20T00:00:00      2
# 3             0  64900000.0      159.00  2015-07-24T00:00:00      3
# 4             2  10000000.0      100.00  2018-06-19T00:00:00      2
# 5            10   2890000.0       30.40  2018-09-10T00:00:00      1
# 6             6   3700000.0       37.30  2017-11-02T00:00:00      1
# 7             5   7915000.0       71.60  2019-04-18T00:00:00      2
# 8            20   2900000.0       33.16  2018-05-23T00:00:00      1
# 9            18   5400000.0       61.00  2017-02-26T00:00:00      3
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70          16.0        51.00      8          NaN  ...
# 1             NaN          11.0        18.60      1          NaN  ...
# ...

# %% [markdown]
# Получим **общую информацию** о таблице:

# %%
# получение общей информации о данных в таблице
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %% [markdown]
# Итак, в таблице **22 столбца**.
#
# Из них с **пропущенными значениями**:

# %%
#количество столбцов с пропущенными значениями
(df.isna().sum()!=0).sum()
# Out:
# 14

# %% [markdown]
# То есть в **14 столбцах** есть *пропущенные значения*.
#
# Хорошо, что **нет пропущенных значений** в стролбцах `last_price ` и `total_area`, так как они позволят получить ключевой параметр - **стоимость квадратного метра**.
#
# В некоторых столбцах **неудобный формат данных**, например, в количестве балконов, этажей можно использовать целочисленный тип данных. Предстоит перевести столбец `first_day_exposition` в формат даты и времени.

# %% [markdown]
# Из документации известно **описание данных**:
# - `total_images` — число фотографий квартиры в объявлении
# - `last_price` — цена на момент снятия с публикации
# - `total_area` — площадь квартиры в квадратных метрах (м²)
# - `first_day_exposition` — дата публикации
# - `rooms` — число комнат
# - `ceiling_height` — высота потолков (м)
# - `floors_total` — всего этажей в доме
# - `living_area` — жилая площадь в квадратных метрах (м²)
# - `floor` — этаж
# - `is_apartment` — апартаменты - это булев тип, но отображается тип `object` из-за пропущенных значений
# - `studio` — квартира-студия (булев тип)
# - `open_plan` — свободная планировка (булев тип)
# - `kitchen_area` — площадь кухни в квадратных метрах (м²)
# - `balcony` — число балконов
# - `locality_name` — название населённого пункта
# - `airports_nearest` — расстояние до ближайшего аэропорта в метрах (м)
# - `cityCenters_nearest` — расстояние до центра города (м)
# - `parks_around3000` — число парков в радиусе 3 км
# - `parks_nearest` — расстояние до ближайшего парка (м)
# - `ponds_around3000` — число водоёмов в радиусе 3 км
# - `ponds_nearest` — расстояние до ближайшего водоёма (м)
# - `days_exposition` — сколько дней было размещено объявление (от публикации до снятия)

# %% [markdown]
# ### Вывод

# %% [markdown]
# В каждой строке таблицы - данные об объекте недвижимости из размещённого объявления на сервисе Яндекс.Недвижимость.
#
# Из описания данных известно, что по каждой квартире на продажу доступны два вида данных:
# - вписаные пользователем,
# - полученные автоматически на основе картографических данных (например, расстояние до центра, аэропорта, ближайшего парка и водоёма).
#
# Всего в таблице **22 столбца**, из которых **14** с пропущенными значениями. В ключевых столбцах `last_price ` и `total_area` пропуски отсутствуют.
#
# В каких-то столбцах пропуски понятны, например, в количестве балконов, в некоторых предстоит разобраться отдельно.
#
# Помимо пропусков встречаются *неудобные типы данных* (десятичные числа вместо целочисленных).
#
#
#
# Предварительно можно утверждать, что **данных для исследования** достаточно. Перейдём к предобработке данных.

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# На стадии предобработки данных **выполним следующие операции**:
# - изменим название столбцов
# - обработаем пропущенные значения
# - изменим тип данных там, где это потребуется

# %% [markdown]
# ### Изменение названий столбцов

# %% [markdown]
# Изменим название столбца `cityCenters_nearest` для соответствия хорошему стилю на **`city_centers_nearest`**, а также
# `parks_around3000` на **`parks_around_3000`** и `ponds_around3000` на **`ponds_around_3000`**.

# %%
#переименование стобцов, методом rename()
df = df.rename(columns={
    'cityCenters_nearest':'city_centers_nearest',
    'parks_around3000':'parks_around_3000',
    'ponds_around3000':'ponds_around_3000'})

# %% [markdown]
# Выведем на экран все заголовки столбцов для проверки результата переименования:

# %%
#вывод названий столбцов для проверки результата
df.columns
# Out:
# Index(['total_images', 'last_price', 'total_area', 'first_day_exposition',
#        'rooms', 'ceiling_height', 'floors_total', 'living_area', 'floor',
#        'is_apartment', 'studio', 'open_plan', 'kitchen_area', 'balcony',
#        'locality_name', 'airports_nearest', 'city_centers_nearest',
#        'parks_around_3000', 'parks_nearest', 'ponds_around_3000',
#        'ponds_nearest', 'days_exposition'],
#       dtype='object')

# %% [markdown]
# #### Вывод
#
# Изменены названия некоторых столбцов для удобства дальнейшей работы. Переходим к обработке пропусков.

# %% [markdown]
# ### Обработка пропусков

# %% [markdown]
# Как было показано ранее, в **14 стобцах** имеются пропущенные значения. Рассмотрим каждый из них.
#
# #### Столбцы ` is_apartment` и ` balcony`
#
# Рассмотрим **долю пропущенных значений** в каждом из столбцов, отсортируем по убыванию:

# %%
#вычисление доли пропущенных значений в каждом из столбцов
#вывод на экран в порядке убывания
df.isna().mean().sort_values(ascending=False).reset_index()
# Out:
#                    index         0
# 0           is_apartment  0.882906
# 1          parks_nearest  0.659100
# 2          ponds_nearest  0.615596
# 3                balcony  0.486054
# 4         ceiling_height  0.387991
# 5       airports_nearest  0.233850
# 6   city_centers_nearest  0.232879
# 7      ponds_around_3000  0.232837
# 8      parks_around_3000  0.232837
# 9        days_exposition  0.134225
# 10          kitchen_area  0.096122
# 11           living_area  0.080299
# 12          floors_total  0.003629
# 13         locality_name  0.002068
# 14          total_images  0.000000
# 15            last_price  0.000000
# 16                studio  0.000000
# 17                 floor  0.000000
# 18                 rooms  0.000000
# 19  first_day_exposition  0.000000
# 20            total_area  0.000000
# 21             open_plan  0.000000

# %% [markdown]
# **Наибольшее количество** пропущенных значений в столбце **`is_apartment`**, что может означать **непринадлежность** этих объектов недвижимости к данной категории.
# Изучим уникальные значения этого столбца:

# %%
#выводим уникальные значения
df['is_apartment'].value_counts(dropna=False)
# Out:
# NaN      20924
# False     2725
# True        50
# Name: is_apartment, dtype: int64

# %% [markdown]
# Ранее в сводной информации о таблице по данному столбцу был получин тип `object`. Понятно, что этот столбец является категорийным, должен иметь формат данных `bool`. Принимаем решение заполнить пропуски значениями `False`:

# %%
#заполняем пропуски с помощью fillna() на 'False'
df['is_apartment']=df['is_apartment'].fillna(False)

# %% [markdown]
# Проверим результат замены:

# %%
#выводим уникальные значения повторно
df['is_apartment'].value_counts(dropna=False)
# Out:
# False    23649
# True        50
# Name: is_apartment, dtype: int64

# %% [markdown]
# **Обратим внимание**, что в исходном датафрейме есть **категорийные переменные**, обозначающие отношение объекта недвижимости к одной из категорий:
# - **аппартаменты**(`is_apartment`) - в котором было больше всего пропущенных значений,
# - **студия** (`studio`) - нет пропусков,
# - **открытая планировка** (`open_plan`) - нет пропусков.
#
# Посмотрим какой **процент** объектов принадлежит к упомянутым категориям (от общего количества объявлений):

# %%
#процент аппартаментов от общего числа объявления
df['is_apartment'].mean()*100
# Out:
# 0.21097936621798388

# %%
#процент студий от общего числа объявления
df['studio'].mean()*100
# Out:
# 0.6287185113295919

# %%
#процент открытых планировок от общего числа объявления
df['open_plan'].mean()*100
# Out:
# 0.2827123507320984

# %% [markdown]
# Информации по каждой из категорий **менее 1%**. Поэтому данные столбцы **не позволят выявить обоснованные закономерности** внутри этих категорий, так как **выборка объявлений слишком мала**.
#
# Удалять эти столбцы из `df` не будем, но данные в них в дальнейшем придётся исключить из рассмотрения.
# ___

# %% [markdown]
# Отчасти, *в плане заполнения пропусков*, **похожая ситуация со столбцом `balcony`**.
# Рассмотрим его уникальные значения:

# %%
#выводим уникальные значения 
df['balcony'].value_counts(dropna=False)
# Out:
# NaN    11519
# 1.0     4195
# 0.0     3758
# 2.0     3659
# 5.0      304
# 4.0      183
# 3.0       81
# Name: balcony, dtype: int64

# %% [markdown]
# Логично, что если продавец *не указал количество балконов*, значит скорее всего **их там нет**.
# В данном случае обоснованно заполнить пропуски в столбце `balcony` значением **`0`**:

# %%
# замена пропущенных значений на '0'
df['balcony'] = df['balcony'].fillna(0)

# %% [markdown]
# Проверяем результат заполнения пропусков:

# %%
#выводим уникальные значения повторно
df['balcony'].value_counts(dropna=False)
# Out:
# 0.0    15277
# 1.0     4195
# 2.0     3659
# 5.0      304
# 4.0      183
# 3.0       81
# Name: balcony, dtype: int64

# %% [markdown]
# Пропуски успешно заполнены, движемся дальше.

# %% [markdown]
# #### Количество парков и прудов, расстояние до них

# %% [markdown]
# Посмотрим какой столбец вырывается в лидеры пропущенных значений после замены пропусков в 2 столбцах:

# %%
#вычисление доли пропущенных значений в каждом из столбцов
#вывод на экран в порядке убывания
df.isna().mean().sort_values(ascending=False).reset_index()
# Out:
#                    index         0
# 0          parks_nearest  0.659100
# 1          ponds_nearest  0.615596
# 2         ceiling_height  0.387991
# 3       airports_nearest  0.233850
# 4   city_centers_nearest  0.232879
# 5      ponds_around_3000  0.232837
# 6      parks_around_3000  0.232837
# 7        days_exposition  0.134225
# 8           kitchen_area  0.096122
# 9            living_area  0.080299
# 10          floors_total  0.003629
# 11         locality_name  0.002068
# 12               balcony  0.000000
# 13          total_images  0.000000
# 14            last_price  0.000000
# 15                studio  0.000000
# 16          is_apartment  0.000000
# 17                 floor  0.000000
# 18                 rooms  0.000000
# 19  first_day_exposition  0.000000
# 20            total_area  0.000000
# 21             open_plan  0.000000

# %% [markdown]
# Очевидно, что это расстояние для ближайших парков и прудов. **Но** настораживает **несовпадение пропущенных значений** в двух парах столбцов:
#
# `parks_nearest` и `parks_around_3000`,
#
# `ponds_nearest` и `ponds_around_3000`.
#
# Судя по столбцам `parks_around_3000` и `ponds_around_3000` в почти 77% объявлений **есть информация о наличии парков и/или прудов в радиусе 3000 м**.
#
# При этом в столбцах `parks_nearest` и `ponds_nearest` информация о расстоянии до парка/пруда только **примерно в 39% объявлений**.
#
# Предстоит соотнести эти пары столбцов и аккуратнее заполнить пропуски.

# %% [markdown]
# Если устраним пропуски в указанных парах столбцов, то избавимся сразу от 4 столбцов с пропущенными значениями.

# %% [markdown]
# Рассмотрим **уникальные значения** в столбцах `parks_around_3000` и `ponds_around_3000`:

# %%
#уникальные значения в столбце 'parks_around_3000'
df['parks_around_3000'].value_counts(dropna=False)
# Out:
# 0.0    10106
# 1.0     5681
# NaN     5518
# 2.0     1747
# 3.0      647
# Name: parks_around_3000, dtype: int64

# %%
#уникальные значения в столбце 'ponds_around_3000'
df['ponds_around_3000'].value_counts(dropna=False)
# Out:
# 0.0    9071
# 1.0    5717
# NaN    5518
# 2.0    1892
# 3.0    1501
# Name: ponds_around_3000, dtype: int64

# %% [markdown]
# Нет неявных дубликатов. Логичным кажется **сначала** заполнить пропуски в столбцах `parks_around_3000` и `ponds_around_3000`, ведь в этих столбцах речь идёт о **количестве** парков/прудов. Пропущенные значения в этих столбцах по идее должны соответствовать **отсутствию парков и прудов** в радиусе 3000 м.
#
# **Но** у нас есть ещё столбцы **`parks_nearest` и `ponds_nearest`**.
#
# Сперва посмотрим как пропущенные значения `parks_around_3000` связаны с пропущенным значениям `parks_nearest`.
#
# Начнём с количества пропущенных значений в столбце `parks_around_3000`:

# %%
#количество пропущенных значений в столбце 'parks_around_3000'
len(df[df['parks_around_3000'].isna() == True])
# Out:
# 5518

# %% [markdown]
# Теперь выведем общую информацию о датафрейме, отфильтрованном по пропущенным значениям в столбце `parks_around_3000`, чтобы увидеть информацию о пропущенных значениях в других столбцах:

# %%
#вывод на экран информации о срезе датафрейма,
#в котором в столбце 'parks_around_3000' только пропущенные значения (NaN)
df[df['parks_around_3000'].isna() == True].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5518 entries, 5 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          5518 non-null   int64
#  1   last_price            5518 non-null   float64
#  2   total_area            5518 non-null   float64
#  3   first_day_exposition  5518 non-null   object
#  4   rooms                 5518 non-null   int64
#  5   ceiling_height        2943 non-null   float64
#  6   floors_total          5508 non-null   float64
#  7   living_area           4895 non-null   float64
#  8   floor                 5518 non-null   int64
#  9   is_apartment          5518 non-null   bool
#  10  studio                5518 non-null   bool
#  11  open_plan             5518 non-null   bool
#  12  kitchen_area          4803 non-null   float64
#  13  balcony               5518 non-null   float64
#  14  locality_name         5510 non-null   object
# ...

# %% [markdown]
# **Неожиданно**, но мы находим взаимосвязь между пропущенными значениями не только в столбцах `parks_around_3000` и `parks_nearest`.
# Мы видим **взаимосвязь между пропущенными значениями во всех столбцах, данные в которых получены автоматически**:
#
# - `airports_nearest`
# - `city_centers_nearest`
# - `parks_around_3000`
# - `parks_nearest`
# - `ponds_around_3000`
# - `ponds_nearest`

# %% [markdown]
# Факт того, что это именно **пропущенные значения** подтверждает также следующая строка кода:

# %%
#количество пропущенных значений в столбце 'parks_nearest'
#таблицы, в которой оставлены строки только с пропусками 
#в столбце 'parks_around_3000'
(
    df[df['parks_around_3000']
       .isna() == True]['parks_nearest']
    .value_counts(dropna=False)
)
# Out:
# NaN    5518
# Name: parks_nearest, dtype: int64

# %% [markdown]
# Посмотрим к каким населённым пунктам относятся пропущенные значени:

# %%
#количество пропущенных значений в столбце 'parks_around_3000'
#по населённым пунктам

(
df[df['parks_around_3000']
   .isna() == True]['locality_name']
    .value_counts()
    .head(30)
)
# Out:
# посёлок Мурино               522
# Всеволожск                   398
# Гатчина                      307
# деревня Кудрово              299
# Выборг                       237
# Кудрово                      173
# деревня Новое Девяткино      144
# Сертолово                    142
# Кириши                       125
# Сланцы                       112
# Волхов                       111
# Тосно                        104
# Кингисепп                    104
# Никольское                    93
# Коммунар                      89
# Сосновый Бор                  87
# Кировск                       84
# Отрадное                      80
# посёлок Бугры                 69
# Приозерск                     66
# деревня Старая                64
# городской посёлок Янино-1     61
# Санкт-Петербург               61
# Шлиссельбург                  57
# Луга                          56
# Тихвин                        49
# поселок Бугры                 45
# посёлок Тельмана              39
# ...

# %% [markdown]
# Судя по всему, это населённые пункты, находящиеся за пределами Санкт-Петербурга. Но врядли в них отсуствуют пруды и парки.

# %% [markdown]
# Отметим, что **общее количество пропусков** в столбцах `parks_nearest` и `ponds_nearest` по отдельности **существенно превышает** количество пропусков в столбцах `parks_around_3000` и `ponds_around_3000`, соответственно, и составляет:

# %%
#количество пропусков в столбце 'parks_nearest'
df['parks_nearest'].isna().sum()
# Out:
# 15620

# %%
#количество пропусков в столбце 'ponds_nearest'
df['ponds_nearest'].isna().sum()
# Out:
# 14589

# %% [markdown]
# Количество пропусков в столбцах `airports_nearest` и `city_centers_nearest` **близко к количеству пропусков в `parks_around_3000`**:

# %%
#количество пропусков в столбце 'airports_nearest'
df['airports_nearest'].isna().sum()
# Out:
# 5542

# %%
#количество пропусков в столбце 'city_centers_nearest'
df['city_centers_nearest'].isna().sum()
# Out:
# 5519

# %% [markdown]
# При этом количество пропусков в столбцах `parks_around_3000` и `ponds_around_3000` совпадает **абсолютно точно**:

# %%
#количество пропусков в столбце 'parks_around_3000'
df['parks_around_3000'].isna().sum()
# Out:
# 5518

# %%
#количество пропусков в столбце 'ponds_around_3000'
df['ponds_around_3000'].isna().sum()
# Out:
# 5518

# %% [markdown]
# **Наиболее вероятная причина появления пропусков в рассматриваемой группе столбцов:**
#
# *сбой при автоматическом получении данных на основе картографических данных*. Либо это те исключительные объекты недвижимости, рядом с которыми нет ни парков, ни прудов, ни аэрапортов, ни центра города, что может быть, но маловероятно.

# %% [markdown]
# Посмотрим минимальные значения в столбцах `airports_nearest` и `city_centers_nearest`, это пригодится нам в дальнейшем:

# %%
#минимальное значение в столбце 'airports_nearest'
df['airports_nearest'].min()
# Out:
# 0.0

# %%
#минимальное значение в столбце 'city_centers_nearest'
df['city_centers_nearest'].min()
# Out:
# 181.0

# %% [markdown]
# Теперь можем переходить к заполнению пропусков в столбцах `parks_around_3000`, `ponds_around_3000`, `airports_nearest` и `city_centers_nearest`.

# %% [markdown]
# ##### Столбцы `parks_around_3000`, `ponds_around_3000`, `airports_nearest` и `city_centers_nearest`

# %% [markdown]
# **Каждое отдельно взятое объявление представляет интерес для анализа**, так как это данные о реальном объекте недвижимости, введённые продавцом.
#
# Чтобы сохранить объявления, в которых произошёл сбой при автоматической генерации данных (или это уникальные отдалённые от благ цивилизации объекты, что, будем недеяться, не так), **выделим отдельную группу данных**.
#
# **Заменим пропуски** в столбцах `parks_around_3000`, `ponds_around_3000`, `airports_nearest` и `city_centers_nearest` на **выделяющееся** значение **`-1`**, так как **в них нет отрицательных значений**.
#
# Это позволит заполнить пропуски и в дальнейшем *идентифицировать группу объявлений с некорректными данными*, сгенерированными автоматически.
#
# Переходим к заполнению пропусков методом `fillna()`:

# %%
# перебор названий столбцов в цикле и замена 
# пропущенных значений на '-1'
columns_to_replace = ['parks_around_3000',
                       'ponds_around_3000',
                       'airports_nearest',
                       'city_centers_nearest']
for column in columns_to_replace:
    df[column] = df[column].fillna(-1)

# %% [markdown]
# Ознакомимся с результатами заполнения пропусков:

# %%
#уникальные значения столбца 'parks_around_3000' после заполнения пропусков
df['parks_around_3000'].value_counts()
# Out:
#  0.0    10106
#  1.0     5681
# -1.0     5518
#  2.0     1747
#  3.0      647
# Name: parks_around_3000, dtype: int64

# %%
#уникальные значения столбца 'ponds_around_3000' после заполнения пропусков
df['ponds_around_3000'].value_counts()
# Out:
#  0.0    9071
#  1.0    5717
# -1.0    5518
#  2.0    1892
#  3.0    1501
# Name: ponds_around_3000, dtype: int64

# %% [markdown]
# Посмотрим, как изменилась доля пропущенных значений в каждом из столбцов. Увидим, что количество столбцов с пропусками **значительно сократилось**.

# %%
#доля пропущенных значений в каждом из столбцов
df.isna().mean().sort_values(ascending=False)
# Out:
# parks_nearest           0.659100
# ponds_nearest           0.615596
# ceiling_height          0.387991
# days_exposition         0.134225
# kitchen_area            0.096122
# living_area             0.080299
# floors_total            0.003629
# locality_name           0.002068
# balcony                 0.000000
# ponds_around_3000       0.000000
# parks_around_3000       0.000000
# city_centers_nearest    0.000000
# airports_nearest        0.000000
# total_images            0.000000
# last_price              0.000000
# studio                  0.000000
# is_apartment            0.000000
# floor                   0.000000
# rooms                   0.000000
# first_day_exposition    0.000000
# total_area              0.000000
# open_plan               0.000000
# dtype: float64

# %% [markdown]
# Теперь рассмотрим 2 оставшихся столбца с пропусками, имеющих отношение к паркам и прудам: `parks_nearest` и `ponds_nearest`.

# %% [markdown]
# ##### Столбцы `parks_nearest` и `ponds_nearest`

# %% [markdown]
# Посмотрим минимальные значения в столбцах `parks_nearest` и `ponds_nearest`:

# %%
#минимальное значение в столбце 'parks_nearest'
df['parks_nearest'].min()
# Out:
# 1.0

# %%
#минимальное значение в столбце 'ponds_nearest'
df['ponds_nearest'].min()
# Out:
# 13.0

# %% [markdown]
# Хорошо, что в данных столбцах нет ячеек с нулевыми значениями и отрицательными, это позволит нам поставить "маркеры" в этих столбцах.
#
# **Но** будем помнить, что пропущенных значений в столбцах `parks_nearest` и `ponds_nearest` больше чем в заполненных на предыдущем шаге связанных столбцах `parks_around_3000` и `ponds_around_3000`.
#
# Чтобы **аккуратно** заменить пропущенные значения в ячейках столбцов `parks_nearest` и `ponds_nearest` используем проставленный ранее маркер `-1`: в строках `parks_around_3000` и `ponds_around_3000` уже стоит `-1`.
#
# Сделаем это с помощью метода `.loc()`:

# %%
#заменяем пропуски в столбце 'parks_nearest', но только в тех ячейках,
#где уже стоит -1 в столбце 'parks_around_3000'
df.loc[df['parks_around_3000']==-1, ['parks_nearest']] = -1

#заменяем пропуски в столбце 'ponds_nearest', но только в тех ячейках,
#где уже стоит -1 в столбце 'ponds_around_3000'
df.loc[df['ponds_around_3000']==-1, ['ponds_nearest']] = -1

# %% [markdown]
# Из **сводной информации по срезу**, который и позволил нам обнаружить группу объявлений с данными, видно, что отсутствуют пропуски, появившиеся, вероятно, в результате некорректной работы автоматической системы.
#
# Пропущенные значения в данном срезе в столбцах
# - `airports_nearest`,
# - `city_centers_nearest`,
# - `parks_around_3000`,
# - `parks_nearest`,
# - `ponds_around_3000`,
# - `ponds_nearest`
#
# **отсутствуют**.
#
# Очевидно, что заполнение пропусков **выполнено успешно**:

# %%
#повторный вывод информации по срезу, в котором были выявлены пропущенные значения сразу в нескольких столбцах
df[df['parks_around_3000']==-1].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5518 entries, 5 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          5518 non-null   int64
#  1   last_price            5518 non-null   float64
#  2   total_area            5518 non-null   float64
#  3   first_day_exposition  5518 non-null   object
#  4   rooms                 5518 non-null   int64
#  5   ceiling_height        2943 non-null   float64
#  6   floors_total          5508 non-null   float64
#  7   living_area           4895 non-null   float64
#  8   floor                 5518 non-null   int64
#  9   is_apartment          5518 non-null   bool
#  10  studio                5518 non-null   bool
#  11  open_plan             5518 non-null   bool
#  12  kitchen_area          4803 non-null   float64
#  13  balcony               5518 non-null   float64
#  14  locality_name         5510 non-null   object
# ...

# %% [markdown]
# Посмотрим, **как теперь изменился** *рейтинг столбцов с пропущенными значениями*:

# %%
#доля пропущенных значений в каждом из столбцов
df.isna().mean().sort_values(ascending=False).reset_index()
# Out:
#                    index         0
# 0          parks_nearest  0.426263
# 1         ceiling_height  0.387991
# 2          ponds_nearest  0.382759
# 3        days_exposition  0.134225
# 4           kitchen_area  0.096122
# 5            living_area  0.080299
# 6           floors_total  0.003629
# 7          locality_name  0.002068
# 8                balcony  0.000000
# 9      ponds_around_3000  0.000000
# 10     parks_around_3000  0.000000
# 11  city_centers_nearest  0.000000
# 12      airports_nearest  0.000000
# 13          total_images  0.000000
# 14            last_price  0.000000
# 15                studio  0.000000
# 16          is_apartment  0.000000
# 17                 floor  0.000000
# 18                 rooms  0.000000
# 19  first_day_exposition  0.000000
# 20            total_area  0.000000
# 21             open_plan  0.000000

# %% [markdown]
# Столбец `ceiling_height` потеснил `ponds_nearest`, но `ponds_nearest` и `parks_nearest` по-прежнему на верхних строчках.
#
# Теперь стоит проверить **соответствуют ли пропущенные значения в столбцах `ponds_nearest` и `parks_nearest` отсутствию прудов и парков в окресности 3000 м этих объектов недвижимости**.

# %% [markdown]
# Ещё раз посмотрим количество пропущенных значений в столбцах `parks_nearest` и `ponds_nearest`, так как сейчас это будет *особенно важно*:

# %%
#количество пропущенных значений в столбце 'parks_nearest'
df['parks_nearest'].isna().sum()
# Out:
# 10102

# %%
#количество пропущенных значений в столбце 'ponds_nearest'
df['ponds_nearest'].isna().sum()
# Out:
# 9071

# %% [markdown]
# Теперь сделаем срез данных, в котором оставим только строки с пропущенными значениями в столбце `parks_nearest`, и выведем уникальные значения столбца `parks_around_3000` для этих строк:

# %%
#делаем срез данных - оставляем в исходном датафрейме только те строки,
#в которых есть пропущенные значения в столбце 'parks_nearest' и
#выводим уникальные значения столбца 'parks_around_3000' для этих строк

df[df['parks_nearest'].isna()==True]['parks_around_3000'].value_counts()
# Out:
# 0.0    10102
# Name: parks_around_3000, dtype: int64

# %% [markdown]
# **Удивительно**, но *наша гипотеза оказалась верна*. Значит автоматическая система в большинстве случаев всё-таки работает.
#
# **Делаем вывод**: все **оставшиеся** пропущенные значения в столбце `parks_nearest` свидетельствуют об **отсутствии парков**.
#
# Посмотрим какие значения принимают ячейки столбца `ponds_around_3000` в строках, где расположены пропущенные значения столбца `ponds_nearest`:

# %%
#делаем срез данных - оставляем в исходном датафрейме только те строки,
#в которых есть пропущенные значения в столбце 'ponds_nearest' и
#выводим уникальные значения столбца 'ponds_around_3000' для этих строк

df[df['ponds_nearest'].isna()==True]['ponds_around_3000'].value_counts()
# Out:
# 0.0    9071
# Name: ponds_around_3000, dtype: int64

# %% [markdown]
# **Второе подтверждение** нашей теории: если значение в столбце `ponds_nearest` пропущено, значит **прудов и водоёмов не найти в окрестностях ближайших 3000 м рассматриваемого объекта недвижимости**.

# %% [markdown]
# Заменим оставшиеся пропущенные значения в столбцах `parks_nearest`и `ponds_nearest` на уникальное значение **`0`**, которое будет иметь смысл отсутствия парков и водоёмов в радиусе 3000 м для данного объекта недвижимости.
#
# Так как мы заполняем оставшиеся пропущенные значения, то метод `loc()` не потребуется, можно использовать `fillna()`:

# %%
# перебор названий столбцов в цикле и замена 
# пропущенных значений на '-1'
columns_to_replace_2 = ['parks_nearest',
                       'ponds_nearest']
for column in columns_to_replace_2:
    df[column] = df[column].fillna(0)

# %% [markdown]
# Ознакомимся с результатами замены, обратимся к рейтингу доли пропущенных значений таблицы `df`:

# %%
#доля пропущенных значений в каждом из столбцов
df.isna().mean().sort_values(ascending=False)
# Out:
# ceiling_height          0.387991
# days_exposition         0.134225
# kitchen_area            0.096122
# living_area             0.080299
# floors_total            0.003629
# locality_name           0.002068
# balcony                 0.000000
# ponds_nearest           0.000000
# ponds_around_3000       0.000000
# parks_nearest           0.000000
# parks_around_3000       0.000000
# city_centers_nearest    0.000000
# airports_nearest        0.000000
# total_images            0.000000
# last_price              0.000000
# studio                  0.000000
# is_apartment            0.000000
# floor                   0.000000
# rooms                   0.000000
# first_day_exposition    0.000000
# total_area              0.000000
# open_plan               0.000000
# dtype: float64

# %% [markdown]
# Это **маленькая победа**. Осталось всего 6 столбцов с пропущенными значениями, с которыми нам предстоит разобраться далее.

# %% [markdown]
# #### Столбец `floors_total`

# %% [markdown]
# Разберёмся со столбцом`floors_total`. В нём и в `locality_name` меньше всего пропущенных значений.

# %% [markdown]
# По этажности здания **у нас есть подсказка** - столбец `floor`,в котором нет пропущенных значений, посмотрим его минимальное  значение:

# %%
#минимальный этаж объекта недвижимости
df['floor'].min()
# Out:
# 1

# %% [markdown]
# *Отлично*, нет нулевых или цокольных этажей.
#
# При заполнении пропусков в столбце `floors_total` необходимо учесть, что **общая этажность здания не может быть меньше указанного в столбце `floor` этажа**.
#
# Посмотрим уникальные значения столбца `floor` в тех ячейках, в строках которых есть пропущенные значения столбца `floors_total`

# %%
# уникальные значения столбца `floor` в тех ячейках, в строках 
# которых есть пропущенные значения в столбца `floors_total`

df[df['floors_total'].isna()==True]['floor'].value_counts()
# Out:
# 4     10
# 6      9
# 8      8
# 12     6
# 9      5
# 3      4
# 5      4
# 7      4
# 21     4
# 15     3
# 19     3
# 18     3
# 1      3
# 13     3
# 11     3
# 10     3
# 14     2
# 2      2
# 20     2
# 24     2
# 17     1
# 22     1
# 23     1
# Name: floor, dtype: int64

# %% [markdown]
# Получаем **разные этажи** и **отсутствие пропусков** (об отсутсвие пропусков знаем из самого первого вызова функции `info()` ).

# %% [markdown]
# **Возникает идея** заменить пропуски в этажности здания на соответствующий указанный этаж. Но тогда мы **увеличим выборку** в категории: **последний этаж**.
#
# Посмотрим сможем ли мы в дальнейшем провести исследование влияния последнего этажа на цену квадратного метра. Сколько всего у нас данных **по последнему этажу** без учета пропущенных значений во `floors_total`, какой процент от общего набора данных?

# %%
#последние, не 1ые этажи в исходной выборке, их уникальные значения и соответствующее им количество
df[(df['floors_total']==df['floor']) & (df['floor']!=1)]['floors_total'].value_counts()
# Out:
# 5.0     1275
# 9.0      394
# 4.0      330
# 3.0      233
# 2.0      191
# 6.0      149
# 12.0     121
# 10.0     118
# 16.0      91
# 7.0       89
# 8.0       44
# 17.0      42
# 25.0      36
# 18.0      35
# 14.0      33
# 19.0      26
# 13.0      22
# 15.0      21
# 24.0      18
# 23.0      15
# 11.0      13
# 22.0      13
# 20.0       7
# 27.0       7
# 26.0       7
# 21.0       6
# Name: floors_total, dtype: int64

# %%
#общее количество последних этажей, не 1ых
df[(df['floors_total']==df['floor']) & (df['floor']!=1)]['floors_total'].count()
# Out:
# 3336

# %%
#процент объявлений с последним этажом от общего количества объявлений
(
df[(df['floors_total']==df['floor']) & (df['floor']!=1)]['floors_total'].count()
    /
len(df['floor'])
    *
    100
)
# Out:
# 14.076543314063885

# %% [markdown]
# Больше **3000** объектов недвижимости, в которых предлагается жильё на последнем этаже.
#
# Это **14%** от исходного набора данных - достаточно хорошая выборка.
#
# Посмотрим насколько мы исказим данные, если будем считать пропуски в `floors_total` равными `floor`, то есть последними этажами, тогда мы добавим примерно:

# %%
#процент объявлений с пропущенными значениями в столбце 'floors_total'
#от общего количества объявлений с последним этажом

(
    df['floors_total'].isna().sum()
    /
    df[(df['floors_total']==df['floor']) & (df['floor']!=1)]['floors_total'].count()
    *
    100
)
# Out:
# 2.577937649880096

# %% [markdown]
# Почти **2,6%** значений мы искуственно введём в категорию **последний этаж**. Это может исказить результаты исследования в категории **последний этаж**.

# %% [markdown]
# Посмотрим сколько данных у нас есть по категории **первый этаж**:

# %%
#общее количество первых этажей
df[(df['floor']==1)]['floor'].count()
# Out:
# 2917

# %% [markdown]
# Из которых целых 25 одноэтажных домов:

# %%
#количество одноэтажных домов с использованием логической нумерации
df[(df['floors_total']==df['floor']) & (df['floor']==1)]['floors_total'].count()
# Out:
# 25

# %% [markdown]
# **Около 3000 объявлений** с 1 этажом - это тоже хорошая выборка.

# %% [markdown]
# Конечно, наибольшее количество объявлений будет в категории этажа **другой**, **больше 17000 объявлений** и **73%** от исходного набора данных:

# %%
#количество объявлений в категории не последний, не первый
df[(df['floors_total']!=df['floor']) & (df['floor']!=1)]['floors_total'].count()
# Out:
# 17363

# %%
# процент объявлений в категории этажей  "не последний, не первый (другой)"
# от общего количества объявлений

(
df[(df['floors_total']!=df['floor']) & (df['floor']!=1)]['floors_total'].count()
    /
len(df['floor'])
    *100
)
# Out:
# 73.26469471285708

# %% [markdown]
# Если мы заполним пропуски во `floors_total` так, чтобы эти объявления **не стали** *жильём на последнем этаже*, то мы не потеряем данные и не исказим результаты, так как добавим незначительный процент к выборке по данной категории:

# %%
# процент объявлений с пропущенными значениями в столбце 'floors_total'
# от общего количества объявлений в категории этажей  "не последний, не первый (другой)"
(
df['floors_total'].isna().sum()
    /
df[(df['floors_total']!=df['floor']) & (df['floor']!=1)]['floors_total'].count()
    *
    100
)
# Out:
# 0.4953061106951564

# %% [markdown]
# Постепенно мы приходим к решению:
#
# - **Нам предстоит** выделить  3 категории квартир по этажам:  **первый**, **последний** и **другой**.
# - Соответственно столбец `floors_total` поможет нам найти **последние этажи**, только в этом его полезная функция.
# - Увеличивать выборку категории **последний этаж** мы не будем, чтобы не исказить результаты.
#
# Поэтому, чтобы заполнить пропуски в столбце `floors_total`, сделаем так, чтобы этажи в этих объявлениях **не стали последними**.

# %% [markdown]
# Перед этим отобразим ещё одно наблюдение. Важно, что в исходных данных нет некорректных объявлений - нет строк таблицы, в которых этаж больше указанного максимального этажа здания.

# %%
# есть ли ячейки, в которых указанный этаж больше общего количества этажей?
df[(df['floor'] > df['floors_total'])]['floor'].count()
# Out:
# 0

# %% [markdown]
# Посмотрим сколько всего уникальных значений в столбце `floors_total`:

# %%
# количество уникальных значений в столбце 'floors_total'
len(df['floors_total'].unique())
# Out:
# 37

# %% [markdown]
# Выведем первые строки пар значений без пропусков, чтобы затем убедиться, что метод `fillna` не исказит значения в ячейках, в которых нет пропущенных значений в столбце `floors_total`:

# %%
#вывод на экран первых 5 строк пары столбцов 'floors_total' и 'floor'
df[['floors_total', 'floor']].head()
# Out:
#    floors_total  floor
# 0          16.0      8
# 1          11.0      1
# 2           5.0      4
# 3          14.0      9
# 4          14.0     13

# %% [markdown]
# Чтобы потом посмотреть как сработало заполнение пропусков, выведем некоторые пары с пропущенными значениями:

# %%
#Вывод на экран 10 строк с пропущенными значениями в столбце 'floors_total' и 
#соответствующее значение в столбце 'floor'
df[df['floors_total'].isna()==True][['floors_total', 'floor']].head(10)
# Out:
#       floors_total  floor
# 186            NaN      4
# 237            NaN      1
# 457            NaN     12
# 671            NaN      8
# 1757           NaN      9
# 1930           NaN      4
# 2392           NaN     22
# 2846           NaN     15
# 2952           NaN      6
# 3031           NaN     12

# %% [markdown]
# Теперь используем метод `fillna()` для замены пропусков в столбце `floors_total`.
#
# Заменим пропуски в столбце `floors_total` на значение в соответсующей ячейке столбца `floor`, **увеличенное на единицу**, чтобы этаж **не стал последним**:

# %%
# заменяем пропуски в столбце 'floors_total' на значение в столбце 
# 'floor', увеличенное на единицу, чтобы этаж не стал последним

df['floors_total'] = df['floors_total'].fillna(df['floor']+1)

# %% [markdown]
# Проверим результат работы метода `fillna` с помощью одного из индексов:

# %%
#проверка значений в строке 1930 в столбцах 'floors_total' и 'floor'
df[df.index==1930][['floors_total', 'floor']]
# Out:
#       floors_total  floor
# 1930           5.0      4

# %% [markdown]
# Повторно выведем первые строки пар значений, которые были без пропусков, чтобы убедиться, что метод `fillna` не исказил значения в ячейках, в которых не было пропущенных значений в столбце `floors_total`:

# %%
#вывод на экран первых 5 строк пары столбцов 'floors_total' и 'floor'
df[['floors_total', 'floor']].head()
# Out:
#    floors_total  floor
# 0          16.0      8
# 1          11.0      1
# 2           5.0      4
# 3          14.0      9
# 4          14.0     13

# %% [markdown]
# Проверим удалось ли заменить пропуски **полностью**:

# %%
#количество пропущенных значений в столбце 'floors_total'
df['floors_total'].isna().sum()
# Out:
# 0

# %% [markdown]
# Эта операция увеличила количество уникальных значений в столбце `floors_total`,но это не критично, так как нас будет интересовать не конкретный этаж, а категория **другие**:

# %%
#количество уникальных значений в столбце 'floors_total' после замены пропусков
len(df['floors_total'].unique())
# Out:
# 36

# %% [markdown]
# Теперь убирём пропуски в столбце `locality_name`.

# %% [markdown]
# #### Столбец `locality_name`

# %% [markdown]
# Столбец `locality_name` содержит названия населённых пунктов. Количество пропущенных значений в нём мало и, на первый взгляд, не повлияет на результаты исследования:

# %%
# количество пропущенных значений в столбце 'locality_name'
df['locality_name'].isna().sum()
# Out:
# 49

# %%
# процент пропущенных значений в столбце 'locality_name'
df['locality_name'].isna().mean()*100
# Out:
# 0.20675977889362418

# %% [markdown]
# Но нам предстоит изучить зависимость стоимости квадратного метра в населённых пунктах.
#
# Посмотрим какая выборка значений в кадом из первых 10 населённых пунктов с наибольшим количеством объявлений:

# %%
# выводим 10 населённых пунктов с наибольшим количеством объявлений
df['locality_name'].value_counts().head(10)
# Out:
# Санкт-Петербург      15721
# посёлок Мурино         522
# посёлок Шушары         440
# Всеволожск             398
# Пушкин                 369
# Колпино                338
# посёлок Парголово      327
# Гатчина                307
# деревня Кудрово        299
# Выборг                 237
# Name: locality_name, dtype: int64

# %% [markdown]
# **49 пропущенных значений** в столбце `locality_name` составляют около **20%** некоторых объявлений в Выборге (*до проверки на неявные дубликаты*).
#
# Но мы не можем восстановить названия отсутствующих населённых пунктов, учитывая, что **Санкт-Петербург протянулся с северо-запада на юго-восток на 90 км**.

# %% [markdown]
# Посмотрим какие расстояния до центра в строках с пропущенными значениями столбца `locality_name`:

# %%
# сведения о выборке среза данных, в котором есть информация о расстоянии до центра
# и есть пропущенные значения в столбце 'locality_name'
df[(df['locality_name'].isna()==True) & (df['city_centers_nearest']>0)]['city_centers_nearest'].describe()
# Out:
# count       41.000000
# mean     11278.902439
# std       8910.058254
# min       1322.000000
# 25%       4383.000000
# 50%       8943.000000
# 75%      17369.000000
# max      41294.000000
# Name: city_centers_nearest, dtype: float64

# %% [markdown]
# Полученные расстояния могут быть как Санкт-Петербургом, так и другим населённым пунктом.
#
# **Подтверждение** - соотвествие **нескольких населённых пунктов** расстоянию <1 км и >18 км от центра города :

# %%
#срез данных в столбце 'locality_name', в которых расстояние до центра >18 км
df.query('city_centers_nearest>18000')['locality_name'].value_counts().head(5)
# Out:
# Санкт-Петербург      819
# посёлок Шушары       382
# Пушкин               368
# Колпино              337
# посёлок Парголово    316
# Name: locality_name, dtype: int64

# %%
#срез данных в столбце 'locality_name', в которых расстояние до центра <1 км
df.query('city_centers_nearest<1000')['locality_name'].value_counts().head(5)
# Out:
# посёлок Мурино     522
# Всеволожск         398
# Гатчина            307
# деревня Кудрово    299
# Выборг             237
# Name: locality_name, dtype: int64

# %% [markdown]
# Поэтому заменим пропуски в столбце `locality_name` на значение `unknown` методом `fillna()`:

# %%
#заменяем пропущенные значения в столбце 'locality_name'
# на значения 'unknown'
df['locality_name'] = df['locality_name'].fillna('unknown')

# %% [markdown]
# Проверим результат заполнения:

# %%
# количество пропущенных значений в столбце 'locality_name'
df['locality_name'].isna().sum()
# Out:
# 0

# %% [markdown]
# Продолжим устранение пропущенных значений.

# %% [markdown]
# #### Столбец `ceiling_height`

# %% [markdown]
# В столбце `ceiling_height`, который характеризует высоту потолков в объекте недвижимости, отсутствуют значения почти в **40%** объявлений.

# %%
# количество пропущенных значений в столбце 'ceiling_height'
df['ceiling_height'].isna().sum()
# Out:
# 9195

# %%
# доля пропущенных значений в столбце 'ceiling_height'
df['ceiling_height'].isna().mean()
# Out:
# 0.38799105447487237

# %% [markdown]
# Потолок во всех квартирах **есть**, это факт. Тогда придётся заполнить пропуски. Пользователь скорее всего не заполнил эту характеристику, так как **в ней нет ничего выдающегося**. Продавец квартиры с высоким потолком вероятнее всего захочет отобразить этот факт в объявлении.
#
# Рассмотрим основные характеристики выборки столбца `ceiling_height` с помощью метода `describe` и посмотрим на гистограмму распределния значений в столбце в диапазоне высоты потолка 2-4 м:

# %%
#выводим основные характеристики выборки столбца 'ceiling_height'
df['ceiling_height'].describe()
# Out:
# count    14504.000000
# mean         2.771499
# std          1.261056
# min          1.000000
# 25%          2.520000
# 50%          2.650000
# 75%          2.800000
# max        100.000000
# Name: ceiling_height, dtype: float64

# %%
#строим гистрограмму с заданным диапазоном
df['ceiling_height'].hist(bins=20,range=(2,4))
plt.title('Гистограмма значений высоты потолка в диапазоне 2-4 м')
plt.xlabel('ceiling_height')
plt.show()

# %% [markdown]
# Из характеристики выборки мы видим, что **среднее значение потолка 2,77 м** немного больше **медианного значения 2,65 м**. В выборке есть выдающиеся значения, например, 100 м - понятно, что потолка такой высоты не может быть.
#
# Если сделать срез по столбцу `ceiling_height`, отбросив нереалистичные значения, то получится, что медиана не изменится, как показано далее, гистограмма тоже, значит выдающихся значений очень мало (14504 значений уменьшилось до 14376 значений):

# %%
#отбрасываем нереалистичные значения высоты потолка
good_ceiling_height_stat = df.query('2<ceiling_height<4')

#выводим характеристику выборки столбца 'ceiling_height' без выдающихся значений
good_ceiling_height_stat['ceiling_height'].describe()
# Out:
# count    14376.000000
# mean         2.718084
# std          0.249035
# min          2.200000
# 25%          2.510000
# 50%          2.650000
# 75%          2.800000
# max          3.980000
# Name: ceiling_height, dtype: float64

# %% [markdown]
# Гистограмма по срезу практически не изменилась:

# %%
#выведем гистограмму по срезу - она практически не изменилась
good_ceiling_height_stat['ceiling_height'].hist(bins=20,range=(2,4))
plt.title('Гистограмма значений высоты потолка в диапазоне 2-4 м \n без аномальных значений')
plt.xlabel('ceiling_height')
plt.show()

# %% [markdown]
# Тогда в столбце `ceiling_height` **заменим пропущенные значения медианой** с использованием метода `fillna()`:

# %%
# заполняем пропуски в столбце 'ceiling_height' медианным значением
df['ceiling_height'] = df['ceiling_height'].fillna(df['ceiling_height'].median())

# %% [markdown]
# Проверим успешность замены подсчетом количества пропусков:

# %%
# количество пропущенных значений в столбце 'ceiling_height'
df['ceiling_height'].isna().sum()
# Out:
# 0

# %% [markdown]
# И посмотрим как изменились сведения о выборке в столбце `ceiling_height` с использованием `describe()` и `hist()`:

# %%
#выводим основные характеристики выборки столбца 'ceiling_height'
df['ceiling_height'].describe()
# Out:
# count    23699.000000
# mean         2.724358
# std          0.988298
# min          1.000000
# 25%          2.600000
# 50%          2.650000
# 75%          2.700000
# max        100.000000
# Name: ceiling_height, dtype: float64

# %% [markdown]
# Изучим новую гистограмму:

# %%
#строим гистрограмму с заданным диапазоном
df['ceiling_height'].hist(bins=20,range=(2,4))
plt.title('Гистограмма значений высоты потолка в диапазоне 2-4 м \n после заполнения пропусков')
plt.xlabel('ceiling_height')
plt.show()

# %% [markdown]
# Из результатов видно, что медиана сохранилась и составляет **2,65**, а сренее значение в столбце уменьшилось и приблизилось к медиане, но  всё равно остаётся выше неё.
#
# Продолжим заполнение пропусков в других столбцах.

# %% [markdown]
# #### Столбец `days_exposition`

# %% [markdown]
# Рассмотрим столбец `days_exposition` - длительность размещения объявления. Начнём с количества пропущенных значений:

# %%
#количество пропущенных значений в столбце 'days_exposition'
df['days_exposition'].isna().sum()
# Out:
# 3181

# %% [markdown]
# Их довольно много. Посмотрим характеристики выборки данного столбца:

# %%
#характеристики выборки в столбце 'days_exposition'
df['days_exposition'].describe()
# Out:
# count    20518.000000
# mean       180.888634
# std        219.727988
# min          1.000000
# 25%         45.000000
# 50%         95.000000
# 75%        232.000000
# max       1580.000000
# Name: days_exposition, dtype: float64

# %% [markdown]
# Минимальное значение - 1 сутки. То есть при размещении объявления фиксируется минимальный срок его прибывания, даже если человек передумал продавать.
#
# Причина пропущенных значений в столбце `days_exposition`: скорее всего это объявления, которые были размещены на момент выгрузки информации из базы данных.
#
# Так как нас будет интересовать **срок продажи**, то заполним пропуски значением **`0`**, чтобы выделить **группу объвлений**, которые **были размещены на момент выгрузки информации об объектах недвижимости**. Проданы они или нет - нам неизвестно.
#
# Заполняем пропуски методом `fillna()`:

# %%
#заполняем пропуски методом fillna()
df['days_exposition'] = df['days_exposition'].fillna(0)

# %% [markdown]
# Проверим результат заполнения:

# %%
#количество пропущенных значений в столбце 'days_exposition'
df['days_exposition'].isna().sum()
# Out:
# 0

# %% [markdown]
# В дальнейшем будем иметь в виду группу объявлений, в которых нет информации о сроке продажи, выделенную нами с помощью `0`. Как видно, без учета `0` характеристики выборки не изменились:

# %%
#выводим основные характеристики выборки столбца 
#'days_exposition' при значениях >0 (без учета группы несостоявшихся продаж)
df[df['days_exposition']>0]['days_exposition'].describe()
# Out:
# count    20518.000000
# mean       180.888634
# std        219.727988
# min          1.000000
# 25%         45.000000
# 50%         95.000000
# 75%        232.000000
# max       1580.000000
# Name: days_exposition, dtype: float64

# %% [markdown]
# Из гистограмммы видно, что есть группа стремительных продаж даже без учета введённой группы `0`. С этим разберёмся позднее.

# %%
#гистограмма для значений 'days_exposition'>0
df[df['days_exposition']>0]['days_exposition'].hist(bins=50)
plt.title('Гистограмма значений длительности размещения объявления')
plt.xlabel('days_exposition')
plt.show()

# %% [markdown]
# Сейчас продолжим заполнять пропуски.

# %% [markdown]
# #### Площадь кухни и общая площадь

# %% [markdown]
# Проверим, что изменилось в рейтинге количества пропущенных значений в столбцах после ряда выполненных замен пропусков.
#
# Остаётся всего 2 столбца с пропусками:

# %%
#доля пропущенных значений в каждом из столбцов
df.isna().mean().sort_values(ascending=False)
# Out:
# kitchen_area            0.096122
# living_area             0.080299
# total_images            0.000000
# ponds_nearest           0.000000
# ponds_around_3000       0.000000
# parks_nearest           0.000000
# parks_around_3000       0.000000
# city_centers_nearest    0.000000
# airports_nearest        0.000000
# locality_name           0.000000
# balcony                 0.000000
# open_plan               0.000000
# last_price              0.000000
# studio                  0.000000
# is_apartment            0.000000
# floor                   0.000000
# floors_total            0.000000
# ceiling_height          0.000000
# rooms                   0.000000
# first_day_exposition    0.000000
# total_area              0.000000
# days_exposition         0.000000
# dtype: float64

# %% [markdown]
# Между тремя столбцами `total_area`, `kitchen_area`, `living_area` есть понятная **связь:** **сумма** *площади кухни* и *жилой площади* **не должна превышать** *общую площадь*, или
#
# $$S_{общая}>(S_{жилая}+S_{кухни})$$
#
# Если в каких-то объявлениях обнаружен этот факт, то это будет свидетельствовать об ошибке введённых продавцом данных.
#
# Перед тем, как заменить пропущенные значения в стобцах `kitchen_area` и `living_area` посмотрим для какого количества объявлений не выполняется данное условие, проверим выполнение условия
#
# $$S_{общая}-S_{жилая}-S_{кухни}>0$$

# %%
#проверим исходные объявления: все ли продавци верно указали площади
#кухни, жилой и общей?
((df['total_area']-df['kitchen_area']-df['living_area'])<0).sum()
# Out:
# 65

# %% [markdown]
# В 65 объявлениях $S_{общая}<(S_{жилая}+S_{кухни})$, в 65 объявлениях продавцы **допустили ошибку**. Будем иметь это в виду.

# %% [markdown]
# Для начала рассмотрим столбец `living_area`. Итак, количество пропусков в столбце `living_area`:

# %%
#количество пропущенных значений в столбце 'living_area'
df['living_area'].isna().sum()
# Out:
# 1903

# %% [markdown]
# Посмотрим характеристику выборки столбца `living_area`:

# %%
#характеристика выборки столбца 'living_area'
df['living_area'].describe()
# Out:
# count    21796.000000
# mean        34.457852
# std         22.030445
# min          2.000000
# 25%         18.600000
# 50%         30.000000
# 75%         42.300000
# max        409.700000
# Name: living_area, dtype: float64

# %% [markdown]
# Посмотрим характеристику выборки отношения столбцов $$\frac{S_{жилая}}{S_{общая}}$$:

# %%
#характеристика выборки отношения столбцов жилой и общей площади
(df['living_area']/df['total_area']).describe()
# Out:
# count    21796.000000
# mean         0.564766
# std          0.105368
# min          0.021583
# 25%          0.495177
# 50%          0.567860
# 75%          0.637880
# max          1.000000
# dtype: float64

# %% [markdown]
# Медиана составляет около `0.567` сохраним её в отдельную переменную:

# %%
#сохраняем медиану отношения столбцов жилой и общей площади в отдельную переменную
median_living_area_ratio = (df['living_area']/df['total_area']).median()

#выводим переменную на экран
median_living_area_ratio
# Out:
# 0.5678598992678503

# %% [markdown]
# Выведем пару столбцов `living_area`,`total_area`:

# %%
#выводим первые 10 значений для пары столбцов
df[['living_area','total_area']].head(10)
# Out:
#    living_area  total_area
# 0        51.00      108.00
# 1        18.60       40.40
# 2        34.30       56.00
# 3          NaN      159.00
# 4        32.00      100.00
# 5        14.40       30.40
# 6        10.60       37.30
# 7          NaN       71.60
# 8        15.43       33.16
# 9        43.60       61.00

# %% [markdown]
# Теперь заполним пропуски в столбце `living_area` с помощью умножения $S_{общая}$ на медиану отношения столбцов
#
# $$\frac{S_{кухни}}{S_{общая}}$$
#
# Для заполнения пропусков воспользуемся `fillna()`:

# %%
#заполняем пропуски в столбце 'living_area' умножением общей площади на медианное отношение
#жилой площади к общей
df['living_area'] = df['living_area'].fillna((df['total_area'])*median_living_area_ratio)

# %% [markdown]
# Проверяем результат заполнения:

# %%
#количество пропущенных значений в столбце 'living_area'
df['living_area'].isna().sum()
# Out:
# 0

# %% [markdown]
# Очевидно, заполнение выполнено успешно:

# %%
#выводим первые 10 значений для пары столбцов
df[['living_area','total_area']].head(10)
# Out:
#    living_area  total_area
# 0    51.000000      108.00
# 1    18.600000       40.40
# 2    34.300000       56.00
# 3    90.289724      159.00
# 4    32.000000      100.00
# 5    14.400000       30.40
# 6    10.600000       37.30
# 7    40.658769       71.60
# 8    15.430000       33.16
# 9    43.600000       61.00

# %% [markdown]
# Принятое допущение позволило заполнить 1903 пустых ячейки, но *мы потеряли 9 ячеек*, так как в них перестало выполняться неравенство, о котором мы говорили ранее: *общая площадь должна быть больше суммы площади кухни и жилой площади*.
#
# Но это не критично, важнее, что мы смогли получить 1903 строки для анализа.

# %%
#проверяем в каком количестве объявлений общая площадь меньше суммы площади кухни и жилой площади
((df['total_area']-df['kitchen_area']-df['living_area'])<0).sum()
# Out:
# 74

# %% [markdown]
# Посмотрим как изменилась характеристика выборки:

# %%
#характеристика выборки после заполнения прпоусков в столбце 'living_area'
df['living_area'].describe()
# Out:
# count    23699.000000
# mean        34.578214
# std         22.340665
# min          2.000000
# 25%         19.000000
# 50%         30.000000
# 75%         42.100000
# max        409.700000
# Name: living_area, dtype: float64

# %% [markdown]
# Медиана осталась прежней. Немного увеличились стандартное отклонение и среднее. По-прежнему присутствуют выбросы, но с ними разберёмся позднее. На данном этапе мы закончили заполнять пропуски в столбце `living_area`.

# %% [markdown]
# Рассмотрим столбец `kitchen_area` - площадь кухни, в котором около **10%** пропущенных значений - это около **2280** объявлений:

# %%
#количество пропущенных значений в столбце 'kitchen_area'
df['kitchen_area'].isna().sum()
# Out:
# 2278

# %% [markdown]
# Характеристика выборки в столбце `kitchen_area`:

# %%
df['kitchen_area'].describe()
# Out:
# count    21421.000000
# mean        10.569807
# std          5.905438
# min          1.300000
# 25%          7.000000
# 50%          9.100000
# 75%         12.000000
# max        112.000000
# Name: kitchen_area, dtype: float64

# %% [markdown]
# Гистограмма столбца `kitchen_area` до заполнения пропусков:

# %%
#выводим гистограмму значений столбца 'kitchen_area' после заполнения пропусков
#в диапазоне 0-40 м
df['kitchen_area'].hist(range=(0,40), bins=20)
plt.title('Гистограмма значений площади кухни')
plt.xlabel('kitchen_area')
plt.show()

# %% [markdown]
# Заполним пропуски в столбце `kitchen_area`, зная `living_area` и `total_area`, по формуле:
#
# $$S_{кухни}=(S_{общая}-S_{жилая})k_{kitchen}$$
#
# где $k_{kitchen}$ - медиана в выражении для столбцов `kitchen_area`, `living_area` и `total_area`, **с ячейками без пропущенных значений**, которое можно записать как
#
# $$\frac{S_{кухни}}{S_{общая}-S_{жилая}}$$
#
# Это коэффициент, который затем обозначим переменной `median_kitchen_ratio`.

# %% [markdown]
# Выведем общую характеристику выборки выражения $\frac{S_{кухни}}{S_{общая}-S_{жилая}}$ для столбцов `kitchen_area`, `living_area` и `total_area` с ячейками без пропущенных значений

# %%
#выводим характеристику выборки для отношения площади кухни
#к разнице общей и жилой площадей для ячеек без пропущенных значений
(df['kitchen_area']/(df['total_area']-df['living_area'])).describe()
# Out:
# count    21421.000000
# mean         0.429765
# std          0.201965
# min          0.040967
# 25%          0.352941
# 50%          0.411765
# 75%          0.479508
# max         11.365854
# dtype: float64

# %% [markdown]
# Сохраним медианное значение `0.41` отношения площади кухни к разнице общей площади и жилой, оно пригодится нам для заполнения пропусков в столбце кухня:

# %%
# сохраняем медиану отношения площади кухни к разнице общей и жилой площадей для ячеек без пропущенных значений
median_kitchen_ratio = (df['kitchen_area']/(df['total_area']-df['living_area'])).median()

# %%
#выводим на экран значение median_kitchen_ratio
median_kitchen_ratio
# Out:
# 0.4117647058823529

# %% [markdown]
# Теперь заполним пропуски с использованием метода `fillna()` и введённой переменной `median_kitchen_ratio`:

# %%
#заполняем прпоуски в столбце 'kitchen_area'
df['kitchen_area'] = df['kitchen_area'].fillna((df['total_area']-df['living_area'])*median_kitchen_ratio)

# %% [markdown]
# Проверим результат заполнения:

# %%
#количество пропущенных значений в столбце 'kitchen_area'
df['kitchen_area'].isna().sum()
# Out:
# 0

# %% [markdown]
# Благодаря осторожному заполнению пропусков в столбце `kitchen_area` не увеличилось количество объявлений, в которых нарушается неравенство $S_{общая}>(S_{жилая}+S_{кухни})$:

# %%
#количество объявлений,в которых общая площадь меньше суммы жилой и площади кухни
((df['total_area']-df['kitchen_area']-df['living_area'])<0).sum()
# Out:
# 74

# %% [markdown]
# Посмотрим как изменилась выборка в столбце `kitchen_area` и гистограмма:

# %%
#характеристика выборки в столбце 'kitchen_area' после заполнения пропусков
df['kitchen_area'].describe()
# Out:
# count    23699.000000
# mean        10.489911
# std          6.073253
# min          0.000000
# 25%          7.000000
# 50%          9.000000
# 75%         12.000000
# max        112.000000
# Name: kitchen_area, dtype: float64

# %%
#выводим гистограмму значений столбца 'kitchen_area' после заполнения пропусков
#в диапазоне 0-40 м
df['kitchen_area'].hist(range=(0,40), bins=20)
plt.title('Гистограмма значений площади кухни \n после заполнения пропусков')
plt.xlabel('kitchen_area')
plt.show()

# %% [markdown]
# Медиана стала `9` вместо `9.1`, немного снизилось среднее. Но есть выдающиеся значения, которые затем предстоит исключить из рассмотрения. В целом можно сделать вывод, что данные не ухудшились.

# %% [markdown]
# Как видно из общей информации о таблице `df` все пропуски заполнены, данные готовы к дальнейшим действиям:

# %%
#вывод информации о таблице df после заполнения пропусков
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        23699 non-null  float64
#  6   floors_total          23699 non-null  float64
#  7   living_area           23699 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          23699 non-null  bool
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          23699 non-null  float64
#  13  balcony               23699 non-null  float64
#  14  locality_name         23699 non-null  object
# ...

# %% [markdown]
# #### Вывод

# %% [markdown]
# Заполнены пропущенные значения в 14 столбцах:
# - в столбцах `is apartment` и `balcony` пропущенные значения **заменены на `0`**, так как их наиболее вероятная причина - не указано пользователем, следовательно не является аппратаментом/отсутствует;
# - обнаружено, что в столбцах *аппартаменты*(`is_apartment`), *студия* (`studio`) и *открытая планировка* (`open_plan`) **менее 1% данных**, соответствующих данным категориям - слишком маленькая выборка, по этим категориям не удастся выявить закономерности;
# - в ходе анализа пропусков в столбце `parks_around_3000` обнаружено **около 5000** пропущенных значений **одновременно в 6 столбцах, которые получены автоматически** на основании картографических данных (`airports_nearest`, `city_centers_nearest`, `parks_around_3000`, `parks_nearest`, `ponds_around_3000`, `ponds_nearest`). Данная группа пропусков была **выделена значением `-1`**. Наиболее вероятная причина появления данной группы пропусков - сбой в системе или удалённые объекты недвижимости. Последнее маловероятно, так как в дальнейшем было выявлено, что факт отстутсвия прудов/парков отмечен значением ноль, а не пропуском.
# - пропусков в столбцах `parks_nearest` и `ponds_nearest` было больше чем в столбцах `parks_around_3000` и `ponds_around_3000`, но после выделения группы `-1` было показано, что эти пропуски соответствуют количеству парков и прудов **равному нулю**, причем количество пропусков и нулей совпало с абсолюнтой точностью. Чтобы выделить в столбцах `parks_nearest` и `ponds_nearest` группу с отсутствием парков и прудов, **оставшиеся пропуски в них были заменены на `0`**, так как в них не было нулевых и отрицательных значений;
# - пропуски в столбце `floors_total` были заменены значениями ячеек соотвествующего **столбца `floor`, увеличенными на 1**, чтобы не увеличивать категорию последний или первый этаж, которые будут выделены далее. Вероятная причина появления пропусков - не указано пользователем;
# - пропуски в  `locality_name` **заменены значением `unknown`**, так как восстановить название населённого пункта не представляется возможным, причина пропусков - не указано пользователем;
# - пропуски в столбце `ceiling_height` заменены, так как потолок есть во всех квартирах. Для замены выбрано **медианное значение**, потому что обнаружены выдающиеся значения;
# - пропуски в `days_exposition` возникли скорее всего из-за того, что объявления были размещены **на момент выгрузки базы данных**, то есть неизвестно были объекты проданы на момент выгрузки или нет. Поэтому пропуски заполнены маркером - **значением `0`**, так как минимальное значение в столбце не равно нулю - `1`. В дальнейшем будем это иметь в виду, когда будем изучать срезы данных.
# - пропуски в столбцах `kitchen_area`, `living_area` заменены на значения, рассчитаные с использованием **значений столбца `total_area`** и **отношения** площади кухни к разнице общей и жилой, отношения жилой к общей, соответственно, рассчитанных для ячеек без пропущенных значений. Причина пропусков в этих столбцах - не указано пользователем.
#
# Перейдём к изменению типа данных в некоторых столбцах.

# %% [markdown]
# ### Изменение типа данных

# %% [markdown]
# #### Замена вещественного типа на целочисленный

# %% [markdown]
# Выведем 5 строк таблицы `df` и посмотрим в каких столбцах для удобства изменить тип данных с вещественного на целочисленный:

# %%
#вывод первых 5 строк таблицы df
df.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0  2019-03-07T00:00:00      3
# 1             7   3350000.0        40.4  2018-12-04T00:00:00      1
# 2            10   5196000.0        56.0  2015-08-20T00:00:00      2
# 3             0  64900000.0       159.0  2015-07-24T00:00:00      3
# 4             2  10000000.0       100.0  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0            2.70          16.0    51.000000      8         False  ...
# 1            2.65          11.0    18.600000      1         False  ...
# 2            2.65           5.0    34.300000      4         False  ...
# 3            2.65          14.0    90.289724      9         False  ...
# 4            3.03          14.0    32.000000     13         False  ...
#
#    kitchen_area  balcony    locality_name  airports_nearest  \
# 0     25.000000      0.0  Санкт-Петербург           18863.0
# ...

# %% [markdown]
# Для удобства заменим тип данных на целочисленный в столбцах, в которых могут быть только целые числа по смыслу, не может быть дробных значений:
# - `floors_total` - этажи,
# - `balcony` - балконы,
# - `parks_around_3000` - парки,
# - `ponds_around_3000`- пруды,
# - `days_exposition` - дни, в течение которых было размещено объявление.
#
# Из документации известно, что расстояние измеряется в метрах, кратно 1 метру, поэтому можно перевести в целочисленный формат столбцы:
# - `airports_nearest`,
# - `city_centers_nearest`,
# - `parks_nearest`,
# - `ponds_nearest`.
#
# В цене квартир, как правило, не указывают копейки, так как сумма велика,  поэтому для удобства можем перевести в целое число столбец:
# - `last_price` - цена квартиры.
#
# Запишем массив названий столбцов для замены типа:

# %%
#перечень столбцов для замены типа на целочисленный
columns_change_type = ['last_price', 
                       'floors_total',
                      'balcony',
                      'airports_nearest',
                      'city_centers_nearest',
                      'parks_around_3000',
                      'parks_nearest',
                      'ponds_around_3000',
                      'ponds_nearest',
                      'days_exposition']

# %% [markdown]
# Воспользуемся циклом и методом `astype`:

# %%
#цикл для изменения типа данных в столбцах
for column in columns_change_type:
    df[column] = df[column].astype('int64')

# %% [markdown]
# Далее округлим значение в столбцах `living_area` и `kitchen_area`:

# %%
#перечень столбцов для округления
columns_round_up = ['living_area',
                   'kitchen_area']

# %% [markdown]
# Для округления воспользуемся циклом и `round()`:

# %%
#цикл для округления
for column in columns_round_up:
    df[column]= round(df[column],2)

# %% [markdown]
# Проверим как изменилась общая информация о таблице:

# %%
#выводим общую информацию о таблице
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  int64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        23699 non-null  float64
#  6   floors_total          23699 non-null  int64
#  7   living_area           23699 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          23699 non-null  bool
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          23699 non-null  float64
#  13  balcony               23699 non-null  int64
#  14  locality_name         23699 non-null  object
# ...

# %% [markdown]
# Посмотрим, как изменились значения:

# %%
#выводим первые 5 строк таблицы
df.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20    13000000       108.0  2019-03-07T00:00:00      3
# 1             7     3350000        40.4  2018-12-04T00:00:00      1
# 2            10     5196000        56.0  2015-08-20T00:00:00      2
# 3             0    64900000       159.0  2015-07-24T00:00:00      3
# 4             2    10000000       100.0  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0            2.70            16        51.00      8         False  ...
# 1            2.65            11        18.60      1         False  ...
# 2            2.65             5        34.30      4         False  ...
# 3            2.65            14        90.29      9         False  ...
# 4            3.03            14        32.00     13         False  ...
#
#    kitchen_area  balcony    locality_name  airports_nearest  \
# 0         25.00        0  Санкт-Петербург             18863
# ...

# %% [markdown]
# Таблица стала выглядить более аккуратной. Заменим формат `obj` на формат даты и времени.

# %% [markdown]
# #### Замена типа `obj` на формат даты и времени

# %% [markdown]
# Выведем на экран несколько значений столбца `first_day_exposition`

# %%
#вывод первых строк столбца `first_day_exposition`
df['first_day_exposition'].head()
# Out:
# 0    2019-03-07T00:00:00
# 1    2018-12-04T00:00:00
# 2    2015-08-20T00:00:00
# 3    2015-07-24T00:00:00
# 4    2018-06-19T00:00:00
# Name: first_day_exposition, dtype: object

# %% [markdown]
# Это тип данных `obj`, который не позволит производить вычисления времени, идентификации дня неделя и прочее. Поэтому преобразуем данные в столбце `first_day_exposition` в формат даты и времени методом `to_datetime`:

# %%
#изменение формата данных в столбце `first_day_exposition`
df['first_day_exposition'] = pd.to_datetime(df['first_day_exposition'],format='%Y-%m-%dT%H:%M:%S')

# %% [markdown]
# Проверим результат изменения типа, отсортируем по убыванию, чтобы узнать дату, в которую была выгружена база данных:

# %%
#проверка результата изменения формата данных в столбце `first_day_exposition`
df['first_day_exposition'].sort_values(ascending=False).head()
# Out:
# 12003   2019-05-03
# 14246   2019-05-03
# 3254    2019-05-03
# 12343   2019-05-03
# 5986    2019-05-03
# Name: first_day_exposition, dtype: datetime64[ns]

# %% [markdown]
# Тип данных успешно изменён. Верхнее значение - дата выгрузки объявлений. С помощью `sort_values` мы определили дату выгрузки объявлений из базы - `2019-05-03`.

# %% [markdown]
# #### Вывод

# %% [markdown]
# **Формат данных изменен** там, где это было нужно. Вещественные числа заменены на целые, выполнено окгруление, `obj` заменён на формат даты и времени. Теперь таблица выглядит приятнее и готова к дальнейшему анализу.

# %% [markdown]
# ## Расчёты и добавление результатов в таблицу

# %% [markdown]
# Для дальнейшего анализа нам понадобится **дополнительная информация**:
# - цена квадратного метра;
# - день недели, месяц и год публикации объявления;
# - категория по этажу - первый, последний, другой;
# - соотношение жилой и общей площади,
# - также отношение площади кухни к общей.

# %% [markdown]
# ### Расчет цены квадратного метра

# %% [markdown]
# Добавим столбец **`square_meter_price`** с ценой квадратного метра, разделив финальную цену на общую площадь:

# %%
# вычисляем стоимость квадратного метра, создаём новый столбец
df['square_meter_price'] = round(df['last_price']/df['total_area'])

# %% [markdown]
# ### Определние дня недели, месяца и года размещения объявления

# %% [markdown]
# Создаём столбец **`weekday_exposition`** с днём недели, в который объявление было размещено, с использованием `dt.weekday`:

# %%
#из столбца с датой размещения 'first_day_exposition' узнаём день
#недели, когда было размещено объявление и добавляем в новый столбец 'weekday_exposition'
df['weekday_exposition'] = df['first_day_exposition'].dt.weekday

# %% [markdown]
# Добавляем столбец **`month_exposition`** с месяцем размещения объявления с использованием `dt.month`:

# %%
#из столбца с датой размещения 'first_day_exposition' узнаём месяц,
#в который было размещено объявление и добавляем его в новый столбец 'month_exposition'
df['month_exposition'] = df['first_day_exposition'].dt.month

# %% [markdown]
# А также столбец **`year_exposition`** с годом размещения объявления, нам поможет `dt.year`:

# %%
#из столбца с датой размещения 'first_day_exposition' узнаём год,
#в который было размещено объявление и добавляем его в новый столбец 'year_exposition'
df['year_exposition'] = df['first_day_exposition'].dt.year

# %% [markdown]
# ### Категория по этажу - первый, последний, другой

# %% [markdown]
# С помощью данных в столбцах `floor` и `floors_total` запишем функцию, которая выполнит категоризацию данных по этажу: первый, последний или другой.
#
# Принцип категоризации:
# - **первый этаж** - строки со значением 1 в столбце `floor`,
# - **последний этаж** - строки, в которых значение `floor` = `floors_total` и не равно 1 (не равно единице, чтобы не дублировать 1ые этажи для одноэтажных зданий),
# - **другой** - все прочие объекты недвижимости, не удовлетворяющие первым двум условиям.
#
# Теперь запишем это в виде функции:

# %%
#создаём функцию floor_category
def floor_category(column1, column2):
    
    #проверяем относится ли объявление к первому этажу
    if (column1 == 1):
        return 'первый'
    
    #проверяем последний это этаж или нет
    if ((column1 == column2) &
        (column1 != 1)):
        return 'последний'
    
    #если первые два условия не выполнены, то категория - другой
    else:
        return 'другой'

# %% [markdown]
# Функцию необходимо применить к **двум столбцам сразу** (`floor` и `floors_total`), чтобы получить новый столбец `floor_category`, поэтому для записи кода в одну строчку воспользуемся `lambda`-функцией и методом `apply()`:

# %%
#создаём новый столбец 'floor_category', в который добавляем категорию объявления по этажу
# с помощью функции floor_category, lambda-функции и метода apply();
#для категоризации используем данные в столбцах 'floor' и 'floors_total'

df['floor_category'] = df.apply(lambda x: floor_category(x.floor, x.floors_total), axis=1)

# %% [markdown]
# Проверим результат работы функции - выведем 15 строк таблицы для столбцов `floor`, `floors_total` и `floor_category`:

# %%
#выводим 15 строк таблицы для столбцов 'floor','floors_total' и 'floor_category'
df[['floor','floors_total','floor_category']].head(15)
# Out:
#     floor  floors_total floor_category
# 0       8            16         другой
# 1       1            11         первый
# 2       4             5         другой
# 3       9            14         другой
# 4      13            14         другой
# 5       5            12         другой
# 6       6            26         другой
# 7      22            24         другой
# 8      26            27         другой
# 9       7             9         другой
# 10      3            12         другой
# 11      4             5         другой
# 12      5             5      последний
# 13      5             5      последний
# 14      1             6         первый

# %% [markdown]
# Приятно видеть, что функция сработала правильно: 1 - первый, последний, другой. Теперь сможем укрупнить группы, рассмотреть влияние последних и первых этажей на стоимость недвижимости.

# %% [markdown]
# ### Соотношение площадей

# %% [markdown]
# Вычислим отношение жилой площади к общей площади, сохраним результат в новом столбце `living_area_ratio`:

# %%
#вычисление отношения жилой площади к общей, окргуление до 3 значащих цифр
df['living_area_ratio'] = round(df['living_area']/df['total_area'],3)

# %% [markdown]
# Вычислим отношение площади кухни к общей площади, сохраним результат в новом столбце `kitchen_area_ratio`:

# %%
#вычисление отношения площади кухни к общей площади, окргуление до 3 значащих цифр
df['kitchen_area_ratio'] = round(df['kitchen_area']/df['total_area'],3)

# %% [markdown]
# Посмотрим, как изменилась сводная информация о таблице:

# %%
#Вывод общей информации о таблице после добавления новых столбцов
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 29 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  int64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  datetime64[ns]
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        23699 non-null  float64
#  6   floors_total          23699 non-null  int64
#  7   living_area           23699 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          23699 non-null  bool
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          23699 non-null  float64
#  13  balcony               23699 non-null  int64
#  14  locality_name         23699 non-null  object
# ...

# %% [markdown]
# Выведем несколько строк новых столбцов на экран, чтобы ознакомиться с результатом вычислений:

# %%
#выводим первые 5 строк новых столбцов для ознакомления
df.iloc[:, 22:].head()
# Out:
#    square_meter_price  weekday_exposition  month_exposition  year_exposition  \
# 0            120370.0                   3                 3             2019
# 1             82921.0                   1                12             2018
# 2             92786.0                   3                 8             2015
# 3            408176.0                   4                 7             2015
# 4            100000.0                   1                 6             2018
#
#   floor_category  living_area_ratio  kitchen_area_ratio
# 0         другой              0.472               0.231
# 1         первый              0.460               0.272
# 2         другой              0.612               0.148
# 3         другой              0.568               0.178
# 4         другой              0.320               0.410

# %% [markdown]
# ### Вывод

# %% [markdown]
# В таблицу `df` добавлено **7 новых столбцов**:
#
# - `square_meter_price` - расчитана стоимость 1 квадратного метра,
# - `weekday_exposition` - выделен день размещения объявления,
# - `month_exposition` - определен месяц размещения объявления,
# - `year_exposition`	- добавлен столбец с годом размещения объявления,
# - `floor_category` - выполнена категоризация по этажу (первый, последний, другой),
# - `living_area_ratio` - вычислено отношение жилой площади к общей,
# - `kitchen_area_ratio` - вычислено отношение площади кухни к общей площади.
#
# **Данные готовы к исследовательскому анализу**.

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Изучение основных параметров: площадь, цена, число комнат, высота потолков

# %% [markdown]
# Изучим основные параметры, построим гистограммы, ознакомимся с тем какие значения есть в исходной выборке.

# %% [markdown]
# #### Общая площадь

# %% [markdown]
# Изучим какие значения общей площади жилья есть в исходной выборке. Для начала рассмотрим характеристику выборки:

# %%
#характеристика выборки в столбце 'total_area'
df['total_area'].describe()
# Out:
# count    23699.000000
# mean        60.348651
# std         35.654083
# min         12.000000
# 25%         40.000000
# 50%         52.000000
# 75%         69.900000
# max        900.000000
# Name: total_area, dtype: float64

# %% [markdown]
# Медиана - **52** квадратных метра. Среднее - 60 кв. м. Максимум - 900 метров - это явный выброс.
#
# Это также подтверждается гистограммой по полному диапазону значений, пик **сильно сдвинут влево**:

# %%
plt.figure(figsize=(10,5))
#гистограмма по полному диапазону значений общей площади
df['total_area'].hist(bins=100)
plt.title('Гистограмма значений общей площади \n по полному исходному диапазону')
plt.xlabel('total_area')
plt.show()

# %% [markdown]
# Также из графика "ящик с усами" видно большое количество выбросов:

# %%
#ящик с усами для стобца 'total_area'
df.boxplot(column='total_area')
plt.title('"Ящик с усами" общей площади \n по полному диапазону')
plt.show()

# %% [markdown]
# Оценим интервал значений для столбца `total_area`, которые будут более вероятны исходя из параметров выборки. Нижнее значение у нас ограничено 12 квадратными метрами, а верхнее рассчитаем, зная первый и третий квартили, умножив их разность на 1,5:

# %%
#первый квартиль для 'total_area'
total_area_Q1 = df['total_area'].quantile(0.25)

#третий квартиль для 'total_area'
total_area_Q3 = df['total_area'].quantile(0.75)

# %% [markdown]
# Сделаем срез данных от минимального значения выборки `total_area` до значения $Q3+1.5(Q3-Q1)$, где $(Q3-Q1)$ -это $IQR$ (интерквартильный размах).
# Выведем общую информацию о выборке среза данных:

# %%
#делаем срез данных от минимального значения `total_area` до (Q3+1.5*IQR)
df.query('total_area <= @total_area_Q3 + 1.5 * (@total_area_Q3-@total_area_Q1)')['total_area'].describe()
# Out:
# count    22459.000000
# mean        54.364907
# std         19.385325
# min         12.000000
# 25%         39.400000
# 50%         50.100000
# 75%         65.600000
# max        114.600000
# Name: total_area, dtype: float64

# %% [markdown]
# Видно, что максимум изменился до значения 114,6 квадратных метров, что вполне реалистично. Но зная, что могут быть единичные квартиры с большой площадью можно увеличить верхнее значение до 150-200 м. В этом верхнем диапазоне теоретически могут быть реальные объекты.

# %% [markdown]
# Посмотрим, как выглядит гистограмма среза данных, она уже чем-то напоминает скорее **распределение Пуассона**, чем нормальное.

# %%
#строим гистограмму по срезу дынных в 'total_area'
plt.figure(figsize=(10,5))
(
    df
    .query('total_area <= (@total_area_Q3 + 1.5 * (@total_area_Q3-@total_area_Q1))')['total_area']
    .hist(bins=25)
)

plt.title('Гистограмма значений общей площади \n по срезу данных')
plt.xlabel('total_area')
plt.show()

# %% [markdown]
# Из графика также видно, что очень мало объявлений с площадью менее 20 квадратных метров. Их можно будет исключить из рассмотрения.

# %% [markdown]
# Теперь мы знаем каким значениям `total_area` можно доверять: от, примерно, 20 квадратных метров, до **114** квадратных метров (по $IQR$ и до 150-200 метров квадратных, исходя из здравого смысла). Будем двигаться дальше.

# %% [markdown]
# #### Цена

# %% [markdown]
# Изучим основные параметры, характеризующие объект недвижимости: площадь, цена, число комнат, высота потолков.

# %%
#характеристика выборки в столбце 'last_price'
df['last_price'].describe()
# Out:
# count    2.369900e+04
# mean     6.541549e+06
# std      1.088701e+07
# min      1.219000e+04
# 25%      3.400000e+06
# 50%      4.650000e+06
# 75%      6.800000e+06
# max      7.630000e+08
# Name: last_price, dtype: float64

# %% [markdown]
# Из общего описания виден явный выброс, гистограмма также смещена влево:

# %%
plt.figure(figsize=(10,5))

#гистограмма по полному диапазону значений 'last_price
df['last_price'].hist(bins=50)

plt.title('Гистограмма цен квартир \n по полному исходному диапазону')
plt.xlabel('last_price')
plt.show()

# %% [markdown]
# Посчитаем примерный диапазон, в котором могут быть реалистичные значения с использованием $IQR$. Вычилим первый и третий квартили для `last_price`:

# %%
#первый квартиль для 'last_price'
last_price_Q1 = df['last_price'].quantile(0.25)

#третий квартиль для 'last_price'
last_price_Q3 = df['last_price'].quantile(0.75)

# %% [markdown]
# Посмотрим чему равно $IQR$:

# %%
(last_price_Q3-last_price_Q1)
# Out:
# 3400000.0

# %% [markdown]
# Теперь сделаем срез данных от минимального значения `last_price` до $Q3+1.5IQR$:

# %%
#делаем срез данных от минимального значения `last_price` до (Q3+1.5*IQR)
df.query('last_price <= (@last_price_Q3 + 1.5 * (@last_price_Q3-@last_price_Q1))')['last_price'].describe()
# Out:
# count    2.166500e+04
# mean     4.848768e+06
# std      2.229914e+06
# min      1.219000e+04
# 25%      3.300000e+06
# 50%      4.400000e+06
# 75%      6.000000e+06
# max      1.190000e+07
# Name: last_price, dtype: float64

# %% [markdown]
# Максимальная цена квартиры составила **11,9 млн руб**, большинство значений выборки (75%) **менее 6 млн. руб.**. Средняя цена 4,85 млн. руб, медиана - 4,4 млн. руб..
# Посмотрим, как изменилась гистограмма:

# %%
#строим гистограмму по срезу
plt.figure(figsize=(10,5))

(
    df
    .query('last_price <=(@last_price_Q3 + 1.5 * (@last_price_Q3-@last_price_Q1))')['last_price']
    .hist(bins=50)
)

plt.title('Гистограмма цен квартир \n по срезу данных')
plt.xlabel('last_price')
plt.show()

# %% [markdown]
# Если следовать IQR, то минимальное значение цены мы вправе принять равным `0`, но так как недвижимость не может стоить меньше какого-то минимального значения, то реалистичная минимальная цена из гистограммы - от **1 000 000 рублей**.
#
# Будем это иметь в виду, но в дальнейшем изучим как на категорию низкой цены влияют другие параметры. Всё-таки цену назначают люди, поэтому она может иметь вероятностный характер и быть **чем-то среднем между Пуассоном и Гауссом**. Кому-то нужно срочно продать, где-то жильё ветхое, поэтому не будем пока что откидывать минимальные значения.

# %% [markdown]
# Но будем помнить, что если ограничим минимум **3 млн. руб.**, то получем график очень похожий на распределение Пуассона:

# %%
#строим гистограмму по срезу с минимальным значением
(
    df
    .query('(3000000 < last_price <= (@last_price_Q3 + 1.5 * (@last_price_Q3-@last_price_Q1)))')['last_price']
    .hist(bins=50)
)
plt.title('Гистограмма цен квартир \n по срезу данных')
plt.xlabel('last_price')
plt.show()

# %% [markdown]
# #### Число комнат

# %% [markdown]
# Рассмотрим выборку числа комнат, выведем основные характеритики:

# %%
#общая информация о столбце `rooms`
df['rooms'].describe()
# Out:
# count    23699.000000
# mean         2.070636
# std          1.078405
# min          0.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max         19.000000
# Name: rooms, dtype: float64

# %% [markdown]
# 19 комнат максимально - похоже на выброс, что подтверждается гистограммой, которая смещена влево:

# %%
#гистограмма по столбцу rooms
df['rooms'].hist(bins=20)
plt.title('Гистограмма числа комнат в квартирах \n по исходному набору данных')
plt.xlabel('rooms')
plt.show()

# %% [markdown]
# Помня, что число комнат может принимать только целые значения, оценим интервал, в котором могут расположится наиболее вероятные значения. Сначала вычислим $Q1$ и $Q3$ для `rooms`:

# %%
#вычисляем первый квартиль для rooms
rooms_Q1 = df['rooms'].quantile(0.25)
rooms_Q1
# Out:
# 1.0

# %%
#вычисляем третий квартиль для rooms
rooms_Q3 = df['rooms'].quantile(0.75)
rooms_Q3
# Out:
# 3.0

# %% [markdown]
# Посмотрим, какое получится значение у $1,5IQR$:

# %%
#считаем 1.5IQR
1.5*(rooms_Q3-rooms_Q1)
# Out:
# 3.0

# %% [markdown]
# Полтора интерквартильных размаха - это всего лишь **3 комнаты**. Теперь делаем срез от минимального количества комнат до $Q3+1.5IQR$:

# %%
#характеристика выборки по срезу 'rooms'<=Q3+1.5IQR
df.query('rooms <= (@rooms_Q3 + 1.5 * (@rooms_Q3-@rooms_Q1))')['rooms'].describe()
# Out:
# count    23609.000000
# mean         2.047905
# std          1.006772
# min          0.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max          6.000000
# Name: rooms, dtype: float64

# %% [markdown]
# Из распределния получаем, что больше 6 комнат врядли мы сможем найти в Санкт-Петербурге, если и найдём, то это будет очень редко, ведь 75% объявлений с количеством комнат 1-3, только 25% объявлений с 3-6 комнатами. И только 90 объявлений (это 0,4; от полной выборки) с количеством комнат более 6.

# %% [markdown]
# Посмотим как выглядит гистограмма по срезу, количество корзин 6 - как максимальное количество комнат:

# %%
#строим гистограмму по срезу 'rooms'<=Q3+1.5IQR
(
    df
    .query('rooms <= (@rooms_Q3 + 1.5 * (@rooms_Q3-@rooms_Q1))')['rooms']
    .hist(bins=6)
)

plt.title('Гистограмма числа комнат в квартирах \n по срезу данных')
plt.xlabel('rooms')
plt.show()

# %% [markdown]
# Также можно будет исключить из рассмотрения объявления, в которых было указано нулевое количество комнат, так как их очень мало.

# %%
#строим гистограмму по срезу 1<='rooms'<=Q3+1.5IQR
(
    df
    .query('1<=rooms <= (@rooms_Q3 + 1.5 * (@rooms_Q3-@rooms_Q1))')['rooms']
    .hist(bins=6)
)

plt.title('Гистограмма числа комнат в квартирах \n по срезу данных')
plt.xlabel('rooms')
plt.show()

# %% [markdown]
# Тогда гистограмма ещё больше похожа на распределение Пуассона: примерно одинаково 1-комнатных и 2-комнатныхквартир, чуть меньше трехкомнатных. Значительно меньше 4-6 комнатных.

# %% [markdown]
# #### Высота потолков

# %% [markdown]
# Посмотрим характеристику выборки высоты потолков, для которой мы заменили пропущенные значения медианой на стадии предобработки данных:

# %%
#основные характеристики выборки столбца 'ceiling_height'
df['ceiling_height'].describe()
# Out:
# count    23699.000000
# mean         2.724358
# std          0.988298
# min          1.000000
# 25%          2.600000
# 50%          2.650000
# 75%          2.700000
# max        100.000000
# Name: ceiling_height, dtype: float64

# %% [markdown]
# Что следует отметить:
# 1. Очень маленький интерквартильный размах - 0,1 - одна десятая метра.
# 2. Нереалистичное минимальное значение - 1 метр.
# 3. Максимальное значение 100 м не бывает таких потолков.
#
# Гистограмма без фильтрации не даёт никакой информации о выборке, кроме как о наличии выбросов:

# %%
#гистограмма всех значений столбца `ceiling height`
df['ceiling_height'].hist()
plt.title('Гистограмма высоты потолков в квартирах \n по исходному набору данных')
plt.xlabel('ceiling_height')
plt.show()

# %% [markdown]
# Посмотрим, какой интервал наиболее реалистичных значений мы можем получить через $IQR$. Выделим первый и третий квартили:

# %%
#первый квартиль для 'ceiling_height'
ceiling_height_Q1 = df['ceiling_height'].quantile(0.25)
ceiling_height_Q1
# Out:
# 2.6

# %%
#третий квартиль для 'ceiling_height'
ceiling_height_Q3 = df['ceiling_height'].quantile(0.75)
ceiling_height_Q3
# Out:
# 2.7

# %% [markdown]
# Для определения минимального значения выборки, рассмотрим количество значений высоты потолка менее `2.4`:

# %%
#выводим количество значений высоты потолка менее 2.4 м
df[df['ceiling_height']<2.4]['ceiling_height'].count()
# Out:
# 21

# %% [markdown]
# Всего 21 значение, которое мы вправе не рассматривать в дальнейшем.
#
# Теперь сделаем срез по выборке с использованием минимума 2,4 м и $1.5IQR$ для максимума:

# %%
#общая информация выборки среза 2.4<'ceiling_height'<=(Q3+1.5IQR)

(
    df
    .query('2.4 <ceiling_height <= @ceiling_height_Q3 + 1.5 * (@ceiling_height_Q3-@ceiling_height_Q1)')
    ['ceiling_height']
    .describe()
)
# Out:
# count    20742.000000
# mean         2.631133
# std          0.081417
# min          2.450000
# 25%          2.600000
# 50%          2.650000
# 75%          2.650000
# max          2.850000
# Name: ceiling_height, dtype: float64

# %% [markdown]
# Также учтем, что заполнение пропущенных значений медианой дало эффект **выдающегося значения**:

# %%
#строим гистограмму по срезу 2.4<'ceiling_height'<=(Q3+1.5IQR)
plt.figure(figsize=(10,5))

(
    df
    .query('2.4 <ceiling_height <= (@ceiling_height_Q3 + 1.5 * (@ceiling_height_Q3-@ceiling_height_Q1))')
    ['ceiling_height']
    .hist(bins=7)
)

plt.title('Гистограмма высоты потолков в квартирах \n по срезу данных')
plt.xlabel('ceiling_height')
plt.show()

# %% [markdown]
# В результате вычислений мы видим максимум - 2,85 м. Но теоретически в квартирах может быть потолок высотой **до 4 метров**, поэтом можем немного увеличить срез и вывести его гистограмму:

# %%
#строим гистограмму по срезу 2.4<'ceiling_height'<=4
(
    df
    .query('2.4 <ceiling_height <= 4')
    ['ceiling_height']
    .hist(bins=7)
)

plt.title('Гистограмма высоты потолков в квартирах \n по срезу данных')
plt.xlabel('ceiling_height')
plt.show()

# %% [markdown]
# Тогда видим, что **наибольшее количество значений высоты потолка** в диапазоне **от 2.45 до 2.85 м**. Выше - реже.

# %% [markdown]
# #### Вывод

# %% [markdown]
# В результате анализа 4 основных характеристик объявления можем сделать следующие выводы:
# 1. В столбце `total_area` выборка достаточна для анализа в диапазоне площадей **от** примерно **20** квадратных метров, **до** **114**. Средняя общая площадь в данном диапазоне - около 55 квадратных метров.
# 2. После удаления выдающихся значений в `last_price` обнаружено, что **реалистичная цена** объекта недвижимости находится в диапазоне от **2 млн. до 12 млн. руб.** В среднем составляет около 4,8 млн. руб., медиана 4,4 млн. руб.
# 3. **Большинство** объектов недвижимости представлены для **1-3 комнат**, менее 25% для 3-6 комнат. Свыше 6 комнат только 0,4% объявлений, исключенные из рассмотрения.
# 4. **75% объектов недвижимости** имеют высоту потолков **2,45-2,65 м**, менее 25% объявлений с высотой потолка 2,65-2,8 м, оставшиеся с высотой 2,8- 4 м. Это также связано с заполнением пропусков медианным значением 2,65 м на стадии предобработки данных, так как требовалось восстановить большое количество пропусков.

# %% [markdown]
# ### Время продажи квартиры

# %% [markdown]
# Изучим время продажи квартиры. Но будем помнить, что на стадии предобработки данных мы выделили группу объявлений, которые были ещё размещены на сайте на момент выгрузки базы данных. Мы отметили их значением `0`, поэтому будем изучать информацию о выборке, учитывая этот факт:

# %%
#выводим информацию о выборке столбца 'days_exposition'
#без учета объявлений, которые были размещены на сайте
#на момент выгрузки базы данных
df[df['days_exposition']>0]['days_exposition'].describe()
# Out:
# count    20518.000000
# mean       180.888634
# std        219.727988
# min          1.000000
# 25%         45.000000
# 50%         95.000000
# 75%        232.000000
# max       1580.000000
# Name: days_exposition, dtype: float64

# %% [markdown]
# Посторим гистограмму для наглядности, увидим, что срок продажи соответствует распределению Пуассона:

# %%
#строим гистограмму выборки столбца 'days_exposition'
#без учета объявлений, которые были размещены на сайте
#на момент выгрузки базы данных
df[df['days_exposition']>0]['days_exposition'].hist(bins=100)

plt.title('Гистограмма days_exposition')
plt.xlabel('days_exposition')
plt.show()

# %% [markdown]
# Из приведенной информации видно, что **среднее - 180 суток**, **медиана - 95 суток**, **стандартное отклонение - 219**. Выборка характеризуется выбивающимис значениями в начале, а также слишком длительными продажами.
#
# **75% объявлений** снимаются с продажи **в срок менее 232** суток.
#
# Запишем первый и третий квартили для выборки:

# %%
#первый квартиль для 'days_exposition'
days_exposition_Q1 = df[df['days_exposition']>0]['days_exposition'].quantile(0.25)
days_exposition_Q1
# Out:
# 45.0

# %%
#третий квартиль для 'days_exposition'
days_exposition_Q3 = df[df['days_exposition']>0]['days_exposition'].quantile(0.75)
days_exposition_Q3
# Out:
# 232.0

# %% [markdown]
# Вычислим интерквартильный размах:

# %%
#Вычисляем интерквартильный размах:
days_exposition_IQR = days_exposition_Q3 - days_exposition_Q1
days_exposition_IQR
# Out:
# 187.0

# %% [markdown]
# Теперь выведем информацию по срезу, в котором нет значений больше $(Q3+1.5IQR)$:

# %%
#выводим характеристики выборки по срезу 0 < days_exposition < (Q3+1.5IQR)
(
    df.
    query('0 < days_exposition < (@days_exposition_Q3+1.5*@days_exposition_IQR)')
    ['days_exposition']
    .describe()
)
# Out:
# count    18849.000000
# mean       128.753886
# std        121.531193
# min          1.000000
# 25%         41.000000
# 50%         85.000000
# 75%        183.000000
# max        512.000000
# Name: days_exposition, dtype: float64

# %% [markdown]
# Количество объявлений **сократилось на 1700 штук**.
# Медиана и среднее стали различаться менее сильно, не в два раза, а в 1,5. Медиана снизилась. Максимальное значение сократилось до 512 суток.
#
# **Но, по-прежнему, большое стандартное отклонение** значит есть выбивающиеся значения.
#
# Построим гистограмму среза в диапазоне 1 - 512 суток:

# %%
#строим гистограмму по срезу 0 < days_exposition < (Q3+1.5IQR)
(
    df.
    query('0 < days_exposition < (@days_exposition_Q3+1.5*@days_exposition_IQR)')
    ['days_exposition']
    .hist(bins=512,figsize=(12,6))
)

plt.title('Гистограмма days_exposition по срезу данных')
plt.xlabel('days_exposition')
plt.show()

# %% [markdown]
# Очевидно, что есть несколько (примерно 5 шт) **выдающихся значений** в диапазоне 0-100 суток.
#
# Приблизим, чтобы посмотреть, где они находятся:

# %%
#строим гистограмму по срезу 0 < days_exposition < (Q3+1.5IQR)
# в диапазоне 0-100 дней
(
    df.
    query('0 < days_exposition < (@days_exposition_Q3+1.5*@days_exposition_IQR)')
    ['days_exposition']
    .hist(bins=100,range=(0,100),figsize=(15,6))
)

plt.title('Гистограмма days_exposition по срезу данных')
plt.xlabel('days_exposition')
plt.show()

# %% [markdown]
# Посмотрим какие по счету дни с момента размещения объявления имеют наибольшее количество снятий объявления с продажи:

# %%
#смотрим уникальные значения в срезе 0 < days_exposition < 100
#количество каждого из уникальных значений

days_exposition_uniq_0_100 = (df.
                              query('0 < days_exposition < 100')
                              ['days_exposition']
                              .value_counts()
                             )

days_exposition_uniq_0_100.head(10)
# Out:
# 45    880
# 60    538
# 7     234
# 30    208
# 90    204
# 4     176
# 3     158
# 5     152
# 14    148
# 9     143
# Name: days_exposition, dtype: int64

# %% [markdown]
# Теперь мы видим, что результат совпадает с гистограммой: это дни под номером **`7`,`30`,`45`,`60` и `90`**. Лидирует при этом день по номером `45` - **880** снятий с продажи.
#
# Очень похоже на **окончание определённых периодов размещения** объявления (платных/бесплатных).
#
# Поэтому **большое количество снятий объявлений** с продажи в эти дни **не означает**, что они были проданы.
#
# Посмотрим характеристику выборки уникальных значений среза `days_exposition` в диапазоне 0-100 дней.

# %%
# характеристика выборки по срезу 0 < days_exposition < 100
# в диапазоне 0-100 дней
(
    df.
    query('0 < days_exposition < 100')
    ['days_exposition']
    .describe()
)
# Out:
# count    10507.000000
# mean        44.707338
# std         26.763400
# min          1.000000
# 25%         21.000000
# 50%         45.000000
# 75%         63.000000
# max         99.000000
# Name: days_exposition, dtype: float64

# %% [markdown]
# Медиана и средняя близки по значению - около 45 суток. Значит в среднем в первые 100 дней размещения объявления снимаются с продажи за 45 дней. Но посмотрим, как поменяется характеристика, если мы отбросим выдающиеся значения.

# %%
# характеристика выборки по срезу 0 < days_exposition < 100
# в диапазоне 0-100 дней без выдающихся значений
(
    df.
    query('(0 < days_exposition < 100) & (days_exposition !=(7,30,45,60,90)) ')
    ['days_exposition']
    .describe()
)
# Out:
# count    8443.000000
# mean       44.015397
# std        27.958878
# min         1.000000
# 25%        19.000000
# 50%        41.000000
# 75%        67.000000
# max        99.000000
# Name: days_exposition, dtype: float64

# %% [markdown]
# Также посмотрим на гистограмму без выдающихся значений:

# %%
#строим гистограмму по срезу 0 < days_exposition < 100
# в диапазоне 0-100 дней без выдающихся значений
(
    df.
    query('(0 < days_exposition < 100) & (days_exposition !=(7,30,45,60,90)) ')
    ['days_exposition']
    .hist(bins=100,range=(0,100),figsize=(15,6))
)

plt.title('Гистограмма days_exposition по срезу данных \n без выдающихся значений')
plt.xlabel('days_exposition')
plt.show()

# %% [markdown]
# Видно, что выдающиеся значения удалены. Также видно, что в первые 1-2 дня **продаётся очень мало объявлений**. Зато на 3ий день продаж и в первую неделю с момента размещения - около 120-175 объявлений в день. **Такое возможно**, как известно, хорошие квартиры действительно быстро находят своего покупателя. Поэтому считаем, что быстрый срок продажи начинается с 3-7 дня от размещения, но встречается редко. Как будет показано далее 25% объявлений снимаются с продажи в течение 40 дней.
#
# Теперь посмотрим характеристики выборки без выдающихся значений от минимального срока продаж до $(Q3+1.5IQR)$:

# %%
#характеристика выборки по срезу 0 < days_exposition < (Q3+1.5IQR)
#без выдающихся значений
(
    df.
    query('(0 < days_exposition < (@days_exposition_Q3+1.5*@days_exposition_IQR)) & (days_exposition !=(7,30,45,60,90))')
    ['days_exposition']
    .describe()
)
# Out:
# count    16785.00000
# mean       138.74078
# std        124.98519
# min          1.00000
# 25%         40.00000
# 50%         99.00000
# 75%        201.00000
# max        512.00000
# Name: days_exposition, dtype: float64

# %% [markdown]
# Видно, что медиана приблизилась к значению стартовой выборки, не смотря на срез по максимальному сроку продажи. На это повлияло удаление выдающихся значений из рассмотрения.
# - **Лишь 25%** объявлений снимаются с продажи **в первые 40 дней**,
# - **50%** объявлений в течение первых **98 дней**,
# - **75%** объявлений продаются в течение **200 дней**.
#
# Теперь посмотрим обновлённую гистограмму от минимального срока продаж до $(Q3+1.5IQR)$:

# %%
#гистограмма выборки по срезу 0 < days_exposition < (Q3+1.5IQR)
#без выдающихся значений
(
    df.
    query('(0 < days_exposition < (@days_exposition_Q3+1.5*@days_exposition_IQR)) & (days_exposition !=(7,30,45,60,90))')
    ['days_exposition']
    .hist(bins=512,figsize=(12,6))
)

plt.title('Гистограмма days_exposition по срезу данных \n без выдающихся значений')
plt.xlabel('days_exposition')
plt.show()

# %% [markdown]
# Масштаб диаграммы изменился, что свидетельствует об исключении из рассмотрения выдающихся значений.
#
# Если сократить количество корзин для метода `hist()`, то гистограмма станет более гладкой:

# %%
#гистограмма выборки по срезу 0 < days_exposition < (Q3+1.5IQR)
#без выдающихся значений 50 корзин
(
    df.
    query('(0 < days_exposition < 512) & (days_exposition !=(7,30,45,60,90)) ')
    ['days_exposition']
    .hist(bins=50,figsize=(12,6))
)

plt.title('Гистограмма days_exposition по срезу данных \n без выдающихся значений')
plt.xlabel('days_exposition')
plt.show()

# %% [markdown]
# Итак, 75% объявлений снимаются с продажи через 200 дней с момента размещения, поэтому срок продажи свыше 1-1,5 лет можно считать необычно долгим, так как 512 сутками ограничены 1,5 интерквартильных размаха.

# %% [markdown]
# #### Вывод

# %% [markdown]
# В ходе анализа столбца `days_exposition` мы обнаружили анамально большое количество снятий объявления с продажи в **`7`,`30`,`45`,`60` и `90`** дни. Очень похоже на **окончание определённых периодов размещения** объявления (платных/бесплатных). Поэтому **большое количество снятий объявлений** с продажи в эти дни **не означает**, что они были проданы.
#
# Анализ выборки без выдающихся значений показал:
# - **Лишь 25%** объявлений снимаются с продажи **в первые 40 дней**,
# - **50%** объявлений в течение первых **98 дней**,
# - **75%** объявлений продаются в течение **200 дней**, поэтому необычно длинным сроком продажи можно считать превышение 1-1,5 лет.
#
# Так как хорошие квартиры действительно могут сниматься с продажи быстро, то реалистичный срок продажи начинается от 3-7 дня, но это бывает достаточно редко (около 2% от общей выборки).

# %% [markdown]
# ### Факторы, влияющие на стоимость квартиры

# %% [markdown]
# #### Стоимость квадратного метра

# %% [markdown]
# Перед исследованием зависимости стоимость квартиры от общей площади, числа комнат, этажа (первого или последнего), удалённости от центра, изучим выборку столбца `square_meter_price`:

# %%
#Характеристика выборки 'square_meter_price'
df['square_meter_price'].describe()
# Out:
# count    2.369900e+04
# mean     9.942166e+04
# std      5.030680e+04
# min      1.120000e+02
# 25%      7.658550e+04
# 50%      9.500000e+04
# 75%      1.142560e+05
# max      1.907500e+06
# Name: square_meter_price, dtype: float64

# %% [markdown]
# Построим гистограмму для `square_meter_price`:

# %%
df['square_meter_price'].hist(figsize=(8,3))
plt.title('Гистограмма стоимости квадратного метра')
plt.xlabel('square_meter_price')
plt.show()

# %% [markdown]
# Так как гистограмма смещена влево, то присутствуют слишком большие значения.
#
# 75% значений выборки не превышают 115 тыс. руб. за квадратный метр, поэтому ограничим выборку значением **200 тыс.руб.**:

# %%
#ограничим выборку 'square_meter_price' значением 200 тыс. руб.
#и строим гистограмму
plt.figure(figsize=(10,5))
(
    df
    .query('square_meter_price<200000')
    ['square_meter_price']
    .hist(bins=50)
)
plt.title('Гистограмма стоимости квадратного метра \n по срезу данных')
plt.xlabel('square_meter_price')
plt.show()

# %% [markdown]
# Получилось распределние очень похожее **на нормальное**. В дальнейшем будем иметь в виду диапазон значений стоимости квадратного метра.

# %% [markdown]
# Посмотрим как изменилась характеристика выборки:

# %%
#выводим общую характеристику о выборке 'square_meter_price' со значением <200 тыс. руб.
(
    df
    .query('square_meter_price<200000')
    ['square_meter_price']
    .describe()
)
# Out:
# count     23177.000000
# mean      94728.175217
# std       31341.050547
# min         112.000000
# 25%       75980.000000
# 50%       94262.000000
# 75%      112500.000000
# max      199880.000000
# Name: square_meter_price, dtype: float64

# %% [markdown]
# Средняя стоимость квадратного метра и медиана близки, что свидетельствует о **хорошем качестве выборки**, и составляют **95 тысяч рублей**.

# %% [markdown]
# Для **предварительного** укрупнённого анализа влияния различных факторов на **стоимость** используем матрицу корреляции для столбцов `total_area`, `rooms`, `floor_category`, `city_centers_nearest` *без срезов данных*:

# %%
#матрица корреляции для 'last_price','total_area','rooms','floor_category','city_centers_nearest'
df[['last_price','total_area','rooms','floor_category','city_centers_nearest']].corr()
# Out:
#                       last_price  total_area     rooms  city_centers_nearest
# last_price              1.000000    0.653675  0.363343             -0.050952
# total_area              0.653675    1.000000  0.758344             -0.076990
# rooms                   0.363343    0.758344  1.000000             -0.059838
# city_centers_nearest   -0.050952   -0.076990 -0.059838              1.000000

# %% [markdown]
# Как и следовало ожидать наибольшее влияние на общую стоимость оказывает общая площадь жилья. Расстояние от центра проанализируем более детальнее позднее. Этаж не выводится в таблице, так как имеет строковые значения. Далее подробнее рассмотрим влияние этих факторов на стоимость квадратного метра и общую цену.
# Также на стоимость должно влиять количество комнат, видимо в выборке без фильтрации сказываются выбросы.

# %% [markdown]
# #### Зависимость от площади квартиры

# %% [markdown]
# Как цена квадратного метра зависит от площади квартиры? Построим **диаграмму рассеяния** по срезу, который определили ранее: площадь менее 400 кв. м, цена квадратного метра - менее 200 тыс. руб.

# %%
#строим диаграмму рассеяния для зависимости square_meter_price от total_area
#срез df - square_meter_price<200000, total_area<400
(
    df
    .query('square_meter_price<200000')
    .query('total_area<400')
    .plot(x='total_area', y='square_meter_price', kind='scatter',alpha=0.3,figsize=(12,6))
)

plt.title('Диаграмма рассеяния зависимости стоимости квадратного метра \n от общей площади жилья')
plt.show()

# %% [markdown]
# Очевидно, что явной зависимости нет. И для малых, и для больших площадей представлены все ценовые диапазоны стоимости квадратного метра.
#
# Как зависит общая стоимость **от общей площади** (стоимость недвижимости ограничим 12 млн., как определили ранее):

# %%
#строим диаграмму рассеяния для зависимости last_price от total_area
#срез df - last_price<12000000, total_area<400
(
    df
    .query('last_price<12000000 and total_area<400')
    .plot(x='total_area', y='last_price', kind='scatter',alpha=0.3,figsize=(12,6))
)

plt.title('Диаграмма рассеяния зависимости стоимости квартиры \n от общей площади жилья')
plt.show()

# %% [markdown]
# В данном случае виден наклон группы точек, соответственно есть линейная взаимосвязь.
#
# Посчитаем коэффициент корреляции для этих величин:

# %%
#вычисляем коэффициент корреляции по срезу между last_price и total_area
#срез df - last_price<12000000, total_area<400
(
    df
    .query('last_price<12000000 and total_area<400')
    ['last_price']
    .corr(df['total_area'])
)
# Out:
# 0.7012608641114658

# %% [markdown]
# Можно сделать вывод, что линейная взаимосвязь между общей стоимостью и общей площадью довольно сильная - **коэффициент корреляции 0,7**.

# %% [markdown]
# #### Зависимость от числа комнат

# %% [markdown]
# Как зависит цена от числа комнат?
#
# Начнём со стоимости квадратного метра. Количество комнат ограничим - от 1 до 6 (как было определено ранее).
# Диаграмма рассеяния будет малоинформативной в данном случае, поэтому воспользуемся `pivot_table`. Запишем в новую переменную `rooms_id_sqm` сводную таблицу для `rooms` и `square_meter_price`, посчитаем выборку для каждой из комнат, оценим среднюю стоимость квадратного метра.

# %%
#сводная таблица, показывающая объём выборки для каждой из комнат,
#а также среднюю стоимость квадратного метра
rooms_id_sqm = (
    df
    .query('(square_meter_price<200000) and (0<rooms<=6)')
    .pivot_table(index = ['rooms'], 
                 values='square_meter_price', 
                 aggfunc=(['count','mean']))
)
#избавимся от двойного названия столбцов
rooms_id_sqm.columns=['count','mean_sq_meter_price']

#выведем на экран сводную таблицу
rooms_id_sqm
# Out:
#        count  mean_sq_meter_price
# rooms
# 1       7986         99383.743426
# 2       7795         92131.670558
# 3       5636         90533.652945
# 4       1102         95389.601633
# 5        293        100358.860068
# 6         91        102371.043956

# %% [markdown]
# Выборка достаточна для комнат 1-4 комнат. Для 5-6 комнат выборка мала. Построим график зависимости стоимости квадратного метра от количества комнат:

# %%
#строим график зависимости стоимости квадратного метра от количества комнат
rooms_id_sqm.plot(y='mean_sq_meter_price', 
                  style='-o',
                  ylim=0,
                  grid=True,
                  figsize=(12,6))

plt.title('Зависимость стоимости квадратного метра от количества комнат')
plt.show()

# %% [markdown]
# Получаем интересный результат. Стоимость квадратного метра снижается с увеличением количества комнат от 1 до 3: **от 100 тыс. до 90 тыс. руб. за квадратный метр**. На 4 комнатах средняя цена снова немного увеличивается и становится равной 95 тыс. руб. за кв. м.

# %% [markdown]
# Посмотрим, как на цену квартиры влияет количество комнат. Построим сводную таблицу и выведем график:

# %%
#сводная таблица, показывающая объём выборки для каждой из комнат,
#а также среднюю стоимость объекта недвижимости
rooms_id_lastprice = (
    df
    .query('(0<rooms<=6) & (last_price<12000000)')
    .pivot_table(index = ['rooms'], 
                 values='last_price', 
                 aggfunc=(['count','mean']))
)

rooms_id_lastprice.columns=['count','mean_last_price']

rooms_id_lastprice
# Out:
#        count  mean_last_price
# rooms
# 1       8008     3.759367e+06
# 2       7614     5.023046e+06
# 3       4973     6.025722e+06
# 4        768     6.984448e+06
# 5        123     8.403016e+06
# 6         18     9.760333e+06

# %%
#строим график зависимости средней стоимости объекта недвижимости от количества комнат
rooms_id_lastprice.plot(y='mean_last_price', 
                        style='-o',
                        ylim=0,
                        grid=True, 
                        figsize=(10,5))

plt.title('Зависимость средней стоимости объекта недвижимости от количества комнат', pad=15)
plt.show()

# %% [markdown]
# Зависимость стоимости объекта недвижимости явная - чем больше комнат, тем выше стоимость.

# %% [markdown]
# #### Влияние этажа

# %% [markdown]
# Влияние этажа на стоимость изучим с помощью сводбных таблиц по аналогии с предыдущим пунктом.
#
# Для стоимости квадратного метра создадим сводную таблицу показывающую объём выборки для каждой из категорий по этажу (первый, последний, другой), а также среднюю стоимость квадратного метра для каждой из категорий:

# %%
#сводная таблица, показывающая объём выборки для каждой из категорий,
#а также среднюю стоимость квадратного метра
floor_id_sqm = (df
                .query('(square_meter_price<200000)')
                .pivot_table(index = ['floor_category'], 
                             values='square_meter_price', 
                             aggfunc=(['count','mean']))
               )

#избавимся от двойного названия столбцов
floor_id_sqm.columns=['count','mean_sq_meter_price']

#выведем на экран сводную таблицу
floor_id_sqm
# Out:
#                 count  mean_sq_meter_price
# floor_category
# другой          17033         98729.766453
# первый           2892         80010.582296
# последний        3252         86857.380381

# %% [markdown]
# Визуализируем результат:

# %%
#строим столбчатую диаграмму для категорий по этажу
#смотрим как средняя цена квадратного метра зависит от этажа
(floor_id_sqm
 .plot(y='mean_sq_meter_price',
      figsize=(10,6),
      grid=True,
      ylim=0,
      kind='barh')
)

plt.title('Зависимость средней цены квадратного метра от этажа')
plt.show()

# %% [markdown]
# Получили, что стоимость квадратного метра самая низкая на **первом этаже** (около **80 тыс. руб.**), на **последнем** немного выше (**87 тыс. руб**), средняя цена квадратного метра в категории **другой** - около **100 тыс. руб. за кв.м**.
#
# С помощью сводной таблицы посмотрим, как зависит **общая цена** объекта недвижимости от этажа:

# %%
#сводная таблица, показывающая объём выборки для каждой из категорий,
#а также среднюю стоимость квадратного метра
floor_id_last_price = (df
    .query('(last_price<12000000)')
    .pivot_table(index = ['floor_category'], 
                 values='last_price', 
                 aggfunc=(['count','mean']))
)

#избавимся от двойного названия столбцов
floor_id_last_price.columns=['count','mean_last_price']

#выведем на экран сводную таблицу
floor_id_last_price
# Out:
#                 count  mean_last_price
# floor_category
# другой          15889     5.055577e+06
# первый           2808     4.132555e+06
# последний        3003     4.507350e+06

# %% [markdown]
# Визуализируем результаты на столбчатой диаграмме:

# %%
#строим столбчатую диаграмму для категорий по этажу
#смотрим как средняя общая стоимость квартиры зависит от этажа
(floor_id_last_price
 .plot(y='mean_last_price',
      figsize=(10,6),
      grid=True,
      ylim=0,
      kind='barh')
)

plt.title('Зависимость средней общей стоимости от этажа')
plt.show()

# %% [markdown]
# Результат аналогичен стоимости квадратного метра: средняя стоимость объекта недвижимости на **1 этаже - 4,1 млн. руб.**, на **последнем - 4,5 млн. руб.**, в категории **другой - 5 млн. руб.**

# %% [markdown]
# #### Влияние удалённости от центра

# %% [markdown]
# Посмотрим как цена зависит от удалённости от центра. Расстояние от центра в данном случае - непрерывная переменная, не категорийная (пока что), получена с помощью автоматизированной системы.
#
# Поэтому построим диаграмму рассеяния для анализа связи `square_meter_price` и `city_centers_nearest` (на стадии предобработки данных мы выявили пустые значения, которые заменили на `-1`, поэтому отсчет расстояния зададим `0<`):

# %%
#строим диаграмму рассеяния для `square_meter_price` и `city_centers_nearest`
#срез df - square_meter_price<200000 и 0<city_centers_nearest
(
    df
    .query('square_meter_price<200000 and 0<city_centers_nearest')
    .plot(x='city_centers_nearest', y='square_meter_price', kind='scatter',alpha=0.3)
)

plt.title('Диаграмма рассеяния стоимости квадратного метра от расстояния до центра')
plt.show()

# %% [markdown]
# Визуально прослеживается слабая отрицательная корреляция, что подтверждается вычислением коэффициента корреляции:

# %%
#вычисляем коэффициент корреляции для `square_meter_price` и `city_centers_nearest`
#срез df - square_meter_price<200000 и 0<city_centers_nearest
(
    df
    .query('square_meter_price<200000 and 0<city_centers_nearest')
    ['square_meter_price']
    .corr(df['city_centers_nearest'])
    
)
# Out:
# -0.40210686446191635

# %% [markdown]
# Результат вполне объяснимый - чем дальше от центра, тем дешевле будет квартира. И наоборот, чем ближе к центру, тем дороже квартира.

# %% [markdown]
# Аналогичный результат получим, если построим диаграмму рассеяния для общей стоимости объекта недвижимости и вычислим коэффициент корреляции:

# %%
#строим диаграмму рассеяния для `last_price` и `city_centers_nearest`
#срез df - last_price<12000000 и 0<city_centers_nearest
(
    df
    .query('last_price<12000000 and 0<city_centers_nearest')
    .plot(x='city_centers_nearest', y='last_price', kind='scatter',alpha=0.3)
)

plt.title('Диаграмма рассеяния цены жилья от расстояния до центра', pad=15)
plt.show()

# %%
#вычисляем коэффициент корреляции для `last_price` и `city_centers_nearest`
#срез df - last_price<12000000 и 0<city_centers_nearest
(
    df
    .query('last_price<12000000 and 0<city_centers_nearest')
    ['square_meter_price']
    .corr(df['city_centers_nearest'])
)
# Out:
# -0.3876607610499912

# %% [markdown]
# Коэффициент корреляции составляет около `-0.4`: чем дальше от центра, тем ниже общая стоимость. В данной выборке присутствует сладая зависимость от удалённости от центра. **Но** влияние расстояния **до центра** проанализируем **подробнее** после его перевода в километры и округления до целых значений (то есть мы, по сути, выполним категоризацию).

# %% [markdown]
# #### Влияние времени размещения (день недели, месяц, год)

# %% [markdown]
# Ранее мы добавили в общую таблицу `df` три столбца, которые помогут нам проследить зависимость цены от времени размещения:
#
# - `weekday_exposition` - выделен день размещения объявления,
# - `month_exposition` - определен месяц размещения объявления,
# - `year_exposition` - добавлен столбец с годом размещения объявления.

# %% [markdown]
# ##### День недели

# %% [markdown]
# Сделаем сводную таблицу по дням недели. Для каждого дня недели посмотрим объём выборки и среднюю цену квадратного метра (значения которой в исходной таблице ограничим 200 тыс. рублей):

# %%
#сводная таблица, показывающая объём выборки для каждого из дней недели,
#а также среднюю стоимость квадратного метра
weekday_id_sqm = (
    df
    .query('(square_meter_price<200000)')
    .pivot_table(index = ['weekday_exposition'], 
                 values='square_meter_price', 
                 aggfunc=(['count','mean']))
)
#избавимся от двойного названия столбцов
weekday_id_sqm.columns=['count','mean_sq_meter_price']


#выведем на экран сводную таблицу
weekday_id_sqm
# Out:
#                     count  mean_sq_meter_price
# weekday_exposition
# 0                    3532         95073.864100
# 1                    4102         95320.487079
# 2                    3894         95280.531844
# 3                    4193         94794.977582
# 4                    3909         94544.832182
# 5                    1884         92649.389066
# 6                    1663         93857.162357

# %% [markdown]
# Визуализируем сводную таблицу в виде столбчатой диаграммы:

# %%
#столбчатая диаграмма для дней недели, в которые состоялись продажи
#изучаем среднюю стоимость квадратного метра в зависимости дня недели
(weekday_id_sqm
 .plot(y='mean_sq_meter_price',
      figsize=(10,6),
      grid=True,
      ylim=0,
      kind='barh')
)

plt.title('Cредняя стоимость квадратного метра в зависимости дня недели')
plt.show()

# %% [markdown]
# Можно сделать вывод, что средняя стоимость квадратного метра практически не зависит от дня недели, в которое размещается объявление.
#
# Аналогичная ситуация с **общей стоимостью объекта недвижимости**:

# %%
#сводная таблица, показывающая объём выборки для каждого из дней недели,
#а также среднюю стоимость объекта недвижимости
weekday_id_last_price = (
    df
    .query('(last_price<12000000)')
    .pivot_table(index = ['weekday_exposition'], 
                 values='last_price', 
                 aggfunc=(['count','mean']))
)
#избавимся от двойного названия столбцов
weekday_id_last_price.columns=['count','mean_last_price']


#выведем на экран сводную таблицу
weekday_id_last_price
# Out:
#                     count  mean_last_price
# weekday_exposition
# 0                    3307     4.864690e+06
# 1                    3838     4.913034e+06
# 2                    3622     4.891873e+06
# 3                    3885     4.875146e+06
# 4                    3687     4.836325e+06
# 5                    1788     4.749503e+06
# 6                    1573     4.794753e+06

# %%
#столбчатая диаграмма для дней недели, в которые состоялись продажи
#изучаем среднюю стоимость объекта недвижимости в зависимости дня недели
(weekday_id_last_price
 .plot(y='mean_last_price',
      figsize=(10,6),
      grid=True,
      ylim=0,
      kind='barh')
)

plt.title('Cредняя стоимость объекта недвижимости в зависимости дня недели')
plt.show()

# %% [markdown]
# Следовательно, зависимости между днём недели и стоимостью объекта недвижимости - нет.

# %% [markdown]
# ##### Месяц продажи

# %% [markdown]
# Создадим сводную таблицу по месяцам продажи, в которой проанализируем среднюю стоимость квадратного метра по каждому месяцу и объём выборки:

# %%
#сводная таблица, показывающая объём выборки для каждого из месяцев,
#а также среднюю стоимость квадратного метра
month_id_sqm = (
    df
    .query('(square_meter_price<200000)')
    .pivot_table(index = ['month_exposition'], 
                 values='square_meter_price', 
                 aggfunc=(['count','mean']))
)
#избавимся от двойного названия столбцов
month_id_sqm.columns=['count','mean_sq_meter_price']


#выведем на экран сводную таблицу
month_id_sqm
# Out:
#                   count  mean_sq_meter_price
# month_exposition
# 1                  1462         95103.772230
# 2                  2576         93964.020575
# 3                  2537         94933.366181
# 4                  2327         96183.135797
# 5                  1249         94537.288231
# 6                  1707         91535.198008
# 7                  1653         94400.063521
# 8                  1710         95861.055556
# 9                  1943         96012.120432
# 10                 2097         94719.922270
# 11                 2314         95059.151253
# 12                 1602         93831.653558

# %% [markdown]
# В целом стоимость квадратного метра примерно одинаковая, но в **июне** наблюдается небольшое снижение цены до **91,5 тыс. руб.**. Самая высокая цена квадратного метра в апреле - **96,2 тыс. руб.**

# %%
#столбчатая диаграмма для месяцев, в которые состоялись продажи
#изучаем среднюю стоимость квадратного метра в зависимости от месяца
(month_id_sqm
 .plot(y='mean_sq_meter_price',
      figsize=(10,6),
      grid=True,
      ylim=0,
      kind='barh')
)

plt.title('Cредняя стоимость квадратного метра в зависимости от месяца')
plt.show()

# %% [markdown]
# В общей стоимости квартиры подобные результаты. Посмотрим сводную таблицу для средней стоимости по месяцам:

# %%
#сводная таблица, показывающая объём выборки для каждого из месяцев,
#а также среднюю стоимость объекта недвижимости
month_id_last_price = (
    df
    .query('(last_price<12000000)')
    .pivot_table(index = ['month_exposition'], 
                 values='last_price', 
                 aggfunc=(['count','mean']))
)
#избавимся от двойного названия столбцов
month_id_last_price.columns=['count','mean_last_price']


#выведем на экран сводную таблицу
month_id_last_price
# Out:
#                   count  mean_last_price
# month_exposition
# 1                  1362     4.827862e+06
# 2                  2418     4.848369e+06
# 3                  2375     4.827675e+06
# 4                  2183     4.956962e+06
# 5                  1165     4.845622e+06
# 6                  1623     4.698905e+06
# 7                  1545     4.860082e+06
# 8                  1602     4.863833e+06
# 9                  1806     4.964064e+06
# 10                 1960     4.825362e+06
# 11                 2160     4.889152e+06
# 12                 1501     4.881165e+06

# %% [markdown]
# В столбчатой диаграмме результат более выраженный: минимальная цена недвижимости в июне, максимальная в апреле и сентябре. Также в период с января по март цены держаться на относительно низком уровне:

# %%
#столбчатая диаграмма для месяцев, в которые состоялись продажи
#изучаем среднюю стоимость объекта недвижимости в зависимости от месяца
(month_id_last_price
 .plot(y='mean_last_price',
      figsize=(10,6),
      grid=True,
      ylim=0,
      kind='barh')
)

plt.title('Cредняя стоимость объекта недвижимости в зависимости от месяца')
plt.show()

# %% [markdown]
# ##### Год продажи

# %% [markdown]
# Создадим сводную таблицу для года продажи, посчитаем выборку для каждого года и среднюю стоимость квадратного метра:

# %%
#сводная таблица, показывающая объём выборки для каждого года продажи,
#а также среднюю стоимость квадратного метра
year_id_sqm = (
    df
    .query('(square_meter_price<200000)')
    .pivot_table(index = ['year_exposition'], 
                 values='square_meter_price', 
                 aggfunc=(['count','mean']))
)
#избавимся от двойного названия столбцов
year_id_sqm.columns=['count','mean_sq_meter_price']


#выведем на экран сводную таблицу
year_id_sqm
# Out:
#                  count  mean_sq_meter_price
# year_exposition
# 2014               127        109102.606299
# 2015              1147         95617.043592
# 2016              2699         91921.951464
# 2017              8015         92983.173550
# 2018              8381         94632.127192
# 2019              2808        101679.770655

# %% [markdown]
# Визуализируем результат на столбчатой диаграмме:

# %%
#столбчатая диаграмма для года продажи,изучаем 
#среднюю стоимость квадратного метра в зависимости от года продажи
(year_id_sqm
 .plot(y='mean_sq_meter_price',
      figsize=(10,6),
      grid=True,
      ylim=0,
      kind='bar')
)

plt.title('Cредняя стоимость квадратного метра в зависимости от года продажи')
plt.show()

# %% [markdown]
# **Средняя стоимость квадратного метра** *снижалась* в период 2014-2016, начиная с 2017 года **начался рост** цен на недвижимость. Посмотрим, как менялась стоимость квартиры в зависимости от года продажи с помощью сводной таблицы:

# %%
#сводная таблица, показывающая объём выборки для каждого года,
#а также среднюю стоимость объекта недвижимости
year_id_last_price = (
    df
    .query('(last_price<12000000)')
    .pivot_table(index = ['year_exposition'], 
                 values='last_price', 
                 aggfunc=(['count','mean']))
)
#избавимся от двойного названия столбцов
year_id_last_price.columns=['count','mean_last_price']


#выведем на экран сводную таблицу
year_id_last_price
# Out:
#                  count  mean_last_price
# year_exposition
# 2014                90     5.851464e+06
# 2015              1020     5.282245e+06
# 2016              2526     4.821229e+06
# 2017              7514     4.790789e+06
# 2018              7931     4.786947e+06
# 2019              2619     5.120898e+06

# %% [markdown]
# И столбчатой диаграммы:

# %%
#столбчатая диаграмма по годам продаж изучаем 
#среднюю стоимость объекта недвижимости в зависимости года продажи
(year_id_last_price
 .plot(y='mean_last_price',
      figsize=(10,6),
      grid=True,
      ylim=0,
      kind='bar')
)

plt.title('Cредняя стоимость объекта недвижимости в зависимости от года продажи')
plt.show()

# %% [markdown]
# Полная стоимость квартиры менялась примерно также,как цена квадратного метра: спад в период с 2014 по 2016, затем рост только с 2019 г. В период 2016-2018 стоимость квартир слабо менялась, возможно, на это повлияла общая площадь квартир, выставлявшихся на продажу.

# %% [markdown]
# #### Влияние населённого пункта

# %% [markdown]
# Выведем 10 населённых пунктов с наибольшим числом объявлений и посчитаем для каждого из них среднее значение стоимости квадратного метра. Сделаем это с помощью `pivot_table`:

# %%
#сводная таблица, показывающая объём выборки для каждого из населённых пунктов,
#а также среднюю стоимость квадратного метра
locality_id_sqm = (
    df
    .query('(square_meter_price<200000)')
    .pivot_table(index = ['locality_name'], 
                 values='square_meter_price', 
                 aggfunc=(['count','mean']))
)
#избавимся от двойного названия столбцов
locality_id_sqm.columns=['count','mean_sq_meter_price']


#выведем на экран сводную таблицу
locality_id_sqm.sort_values(by='count', ascending=False).head(10)
# Out:
#                    count  mean_sq_meter_price
# locality_name
# Санкт-Петербург    15206        108308.881691
# посёлок Мурино       522         85752.181992
# посёлок Шушары       440         78677.379545
# Всеволожск           397         67214.254408
# Пушкин               366        102148.204918
# Колпино              338         75424.571006
# посёлок Парголово    327         90175.886850
# Гатчина              307         68746.110749
# деревня Кудрово      299         92473.588629
# Выборг               237         58141.919831

# %% [markdown]
# Выборка 15206 объявлений получилась для г. Санкт-Петербург с учетом фильтрации по цене квадратного метра (<200 тыс. руб./кв. м). По остальным населённым пунктам выборка гораздо меньше - 240-500 объявлений - но попробуем сравнить полученные результаты.
#
# Посмотроим **столбчатую диаграмму** для наглядности:

# %%
#столбчатая диаграмма для 10 населённых пунктов с наибольшим количеством объявлений
#изучаем среднюю стоимость квадратного метра в зависимости от населённого пункта
(locality_id_sqm
 .sort_values(by='mean_sq_meter_price', ascending=False).head(10)
 .plot(y='mean_sq_meter_price',
      figsize=(16,6),
      grid=True,
      ylim=0,
      kind='bar')
)

plt.title('Cредняя стоимость квадратного метра в зависимости от населённого пункта')
plt.show()

# %% [markdown]
# Получили следующие результаты:
#
# - **Наибольшая средняя цена квадратного метра**, как и ожидалась, в **г. Санкт-Петербург** - около **108 тыс. руб. за кв. м**.
#
# - Близкая к этому значению цена  **в г. Пушкин** - около **102 тыс. руб. за кв. м**.
#
# - На **третьем месте** посёлок **Парголово** и деревня **Кудрово**: **90-92,5 тыс. руб. за кв. метр**.
#
# - **Самая низкая стоимость** квадратного метра получилась в **Выборге - 58 тыс. за кв. м.**

# %% [markdown]
# #### Вывод

# %% [markdown]
# Анализ зависимости различных факторов на стоимость выявил следующее:
#
# 1. **Общая площадь квартиры**
#     - Между стоимостью *квадратного метра* и площадью квартиры нет явной зависимости. И для малых, и для больших площадей представлены все ценовые диапазоны стоимости квадратного метра.
#     - Обнаружена довольно сильная **линейная взаимосвязь** между **полной стоимостью** и общей площадью: **коэффициент корреляции 0,7**.
#
# 2. **Число комнат**
#     - Средняя стоимость квадратного метра снижается с увеличением количества комнат от 1 до 3: **от 100 тыс. до 90 тыс. руб. за квадратный метр**. На 4 комнатах средняя цена снова немного увеличивается и становится равной 95 тыс. руб. за кв. м.
#     - Зависимость стоимости объекта недвижимости от числа комнат явная - чем больше комнат, тем выше стоимость. Это следствие первого пункта, так как чем больше комнат, тем больше площадь.
#
# 3. **Этаж**
#     - средняя стоимость квадратного метра самая низкая на **первом этаже** (около **80 тыс. руб.**), на **последнем** немного выше (**87 тыс. руб**), средняя цена квадратного метра в категории **другой** - около **100 тыс. руб. за кв.м**,
#     - результат анализа полной стоимости объекта недвижимости аналогичен стоимости квадратного метра: средняя стоимость объекта недвижимости на **1 этаже - 4,1 млн. руб.**, на **последнем - 4,5 млн. руб.**, в категории **другой - 5 млн. руб.**
#
# 4. **Удалённость от центра**
#     - При анализе всей выборки обнаружена слабая отрицательная корреляция между стоимостью квадратного метра и удалённостью от центра, а также полной стоимостью объекта недвижимости, то есть чем дальше от центра, тем ниже стоимость (коэффициент корреляции около **-0,4**. Но так как в выборке присутствуют все населённые пунткы, то этот параметр предстоит проанализировать более детально отдельно для г. Санкт-Петербург.
#
# 5. **День, месяц и год продажи**
#     - Стоимость объекта недвижимости практически **не зависит** от дня недели,
#     - Стоимость квадратного метра и общая стоимость ниже всего в **июне** месяце, дороже в апреле и сентябре
#
# 6. **Населённый пункт**
#     - Анализ 10 населённых пунктов с самым большим количеством объявлений показал, что **наибольшая средняя цена квадратного метра**, как и ожидалась, в **г. Санкт-Петербург** - около **108 тыс. руб. за кв. м
#     - **в Пушкине** цена квадратного метра близка к уровню цен в Санкт-Петербурге, что объясняется высоким культурным статусом данного населённого пункта (около **102 тыс. руб. за кв. м**).
#     - На **третьем месте** посёлок **Парголово** и деревня **Кудрово**: **90-92,5 тыс. руб. за кв. метр**.
#     - **Самая низкая стоимость** квадратного метра получилась в **Выборге - 58 тыс. за кв. м.**

# %% [markdown]
# ### Предложения квартир по населённым пунктам

# %% [markdown]
# Изучим предложения квартир: для каждой квартиры есть информация о расстоянии до центра. Наша задача — выяснить, какая область входит в центр и посчитать среднюю цену для каждого километра.

# %% [markdown]
# Выделим квартиры в Санкт-Петербурге по `locality_name`:

# %%
#делаем срез данных из исходного df по Санкт-Петербургу
#сохраняем в переменную для дальнейшей работы
df_sntp = (df
           .query('locality_name == "Санкт-Петербург" and city_centers_nearest>0')
           .reset_index())

#выводим информацию о срезе данных
df_sntp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15660 entries, 0 to 15659
# Data columns (total 30 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   index                 15660 non-null  int64
#  1   total_images          15660 non-null  int64
#  2   last_price            15660 non-null  int64
#  3   total_area            15660 non-null  float64
#  4   first_day_exposition  15660 non-null  datetime64[ns]
#  5   rooms                 15660 non-null  int64
#  6   ceiling_height        15660 non-null  float64
#  7   floors_total          15660 non-null  int64
#  8   living_area           15660 non-null  float64
#  9   floor                 15660 non-null  int64
#  10  is_apartment          15660 non-null  bool
#  11  studio                15660 non-null  bool
#  12  open_plan             15660 non-null  bool
#  13  kitchen_area          15660 non-null  float64
#  14  balcony               15660 non-null  int64
# ...

# %% [markdown]
# Выборка сократилась до 15660 значений.
#
# Создим столбец с расстоянием до центра в километрах, округлим до целых значений, проверим результат округления:

# %%
#создаём новый столбец с расстоянием до центра
df_sntp['city_centers_nearest_km'] = round(df_sntp['city_centers_nearest']/1000).astype('int')

#проверяем правильность округления на первых 15 строчках
df_sntp[['city_centers_nearest','city_centers_nearest_km']].head(15)
# Out:
#     city_centers_nearest  city_centers_nearest_km
# 0                  16028                       16
# 1                  13933                       14
# 2                   6800                        7
# 3                   8098                        8
# 4                  11634                       12
# 5                  15008                       15
# 6                  13878                       14
# 7                  14259                       14
# 8                  10698                       11
# 9                  14616                       15
# 10                 10842                       11
# 11                 12843                       13
# 12                  9722                       10
# 13                 14211                       14
# 14                  2336                        2

# %% [markdown]
# Округление выполнено успешно, новый столбец создан.

# %% [markdown]
# Посчитаем среднюю цену квадратного метра для каждого километра с помощью сводных таблиц:

# %%
#сводная таблица, показывающая объём выборки для каждого километра,
#а также среднюю стоимость квадратного метра
sntp_id_sqm = (
    df_sntp
    .query('(square_meter_price<200000)')
    .pivot_table(index = ['city_centers_nearest_km'], 
                 values='square_meter_price', 
                 aggfunc=(['count','mean']))
)

#избавимся от двойного названия столбцов
sntp_id_sqm.columns=['count','mean_sq_meter_price']

#выведем на экран сводную таблицу
sntp_id_sqm
# Out:
#                          count  mean_sq_meter_price
# city_centers_nearest_km
# 0                           16        124612.937500
# 1                          158        124920.031646
# 2                          256        116141.113281
# 3                          335        113522.044776
# 4                          631        118241.389857
# 5                          821        123730.252132
# 6                          536        125903.078358
# 7                          345        122226.286957
# 8                          583        121957.197256
# 9                          582        110452.139175
# 10                         706        110370.961756
# 11                        1161        106885.390181
# 12                        1597        106953.289292
# 13                        1452        107757.842287
# 14                        1278        104153.298905
# 15                        1567        104144.192087
# 16                        1263        100277.676960
# ...

# %% [markdown]
# Получили всего 29 уникальных значений, значит у нас есть данные по 29 километрам.
#
# Но **выборка в достаточном объёме** для диапазона: примерно от **4 км** (687 объявлений) до **17 км** (883 объявления).
#
# Построим график: он должен показывать, как цена зависит от удалённости от центра.
#
# Определим границу, где график сильно меняется — это и будет **центральная зона**.

# %%
#строим график зависимости средней стоимости квадратного метра от расстояния до центра
sntp_id_sqm.plot(y='mean_sq_meter_price', 
                        style='-o',
                        ylim=0,
                        grid=True,
                        figsize=(10,6))

plt.title('Зависимость средней стоимости квадратного метра от расстояния до центра')
plt.show()

# %% [markdown]
# Очевидно, что график резко меняется с 7 до 9 км:
# - **7 км - 156 176 руб. за кв. м.**
# - **8 км - 125 671 руб. за кв. м.**
# - **9 км - 113 131 руб. за кв. м.**
#
# Значит, будем считать **квартирами в центре** объекты, удалённые **не более чем на 9 км** от центра города.
#
# По **просадке графика в диапазоне 0-4 км** сложно делать какие-то выводы, так как на этом расстоянии **мало квартир**. Тем не менее исключать их из рассмотрения не стоит, любая квартира в центре - представляет интерес для анализа.

# %% [markdown]
# Посмотрим, как ведёт себя полная стоимость объекта недвижимости в зависимости от расстояния до центра:

# %%
#сводная таблица, показывающая объём выборки для каждого километра,
#а также среднюю стоимость объекта недвижимости
sntp_id_last_price = (
    df_sntp
    .query('(last_price<12000000)')
    .pivot_table(index = ['city_centers_nearest_km'], 
                 values='last_price', 
                 aggfunc=(['count','mean']))
)

#избавимся от двойного названия столбцов
sntp_id_last_price.columns=['count','mean_last_price']

#выведем на экран сводную таблицу
sntp_id_last_price
# Out:
#                          count  mean_last_price
# city_centers_nearest_km
# 0                           10     8.398000e+06
# 1                          104     8.254067e+06
# 2                          183     8.014224e+06
# 3                          252     7.419590e+06
# 4                          472     7.680381e+06
# 5                          597     7.682854e+06
# 6                          415     7.166816e+06
# 7                          290     6.708437e+06
# 8                          471     6.640097e+06
# 9                          525     5.564661e+06
# 10                         653     5.426309e+06
# 11                        1092     5.347362e+06
# 12                        1523     5.287692e+06
# 13                        1380     5.551910e+06
# 14                        1235     5.280398e+06
# 15                        1491     5.314769e+06
# 16                        1236     5.108559e+06
# 17                         853     4.871838e+06
# ...

# %% [markdown]
# Объём выборки в достаточном объёме от 4 до 17 км.
#
# Посмотроим на график: **резкий спад графика с 8 до 9 километра** ещё более очевиден, чем на графике стоимости квадратного метра.

# %%
#строим график зависимости средней стоимости объекта недвижимости от расстояния до центра
sntp_id_last_price.plot(y='mean_last_price', 
                               style='-o',
                               ylim=0,
                               grid=True,
                              figsize=(10,6))

plt.title('Зависимость средней стоимости объекта недвижимости от расстояния до центра', pad=15)
plt.show()

# %% [markdown]
# #### Вывод

# %% [markdown]
# В результате анализа выборки по Санкт-Петербургу (из `locality_name`) можно сделать вывод, что объекты недвижимости, удалённые **не более чем на 9 км от центра города**, можно отнести к центральной части города. Такой вывод удалось получить исходя из анализа полной стоимости объекта недвижимости и стоимости квадратного метра.

# %% [markdown]
# ### Анализ предложений в центре Санкт-Петербурга

# %% [markdown]
# Проанализируем объявления в центральной части Санкт-Петербурга, изучим следующие параметры: площадь, цена, число комнат, высота потолков. Затем попробуем выделить факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления). Посмотрим, отличаются ли результаты от полученных по всему городу.

# %% [markdown]
# Для начала выделим сегмент квартир в центре и посмотрим информацию о таблице:

# %%
#делаем срез данных из df_sntp по центру Санкт-Петербурга
#сохраняем в переменную для дальнейшей работы
df_sntp_center = (df_sntp
                  .query('city_centers_nearest<9000')
                  .reset_index())

#выводим информацию о срезе данных
df_sntp_center.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4382 entries, 0 to 4381
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   level_0                  4382 non-null   int64
#  1   index                    4382 non-null   int64
#  2   total_images             4382 non-null   int64
#  3   last_price               4382 non-null   int64
#  4   total_area               4382 non-null   float64
#  5   first_day_exposition     4382 non-null   datetime64[ns]
#  6   rooms                    4382 non-null   int64
#  7   ceiling_height           4382 non-null   float64
#  8   floors_total             4382 non-null   int64
#  9   living_area              4382 non-null   float64
#  10  floor                    4382 non-null   int64
#  11  is_apartment             4382 non-null   bool
#  12  studio                   4382 non-null   bool
#  13  open_plan                4382 non-null   bool
# ...

# %% [markdown]
# Выборка сократилась до почти 4 тысяч объявлений.
#
# Проанализируем эту территорию, изучим следующие параметры: площадь, цена, число комнат, высота потолков.

# %% [markdown]
# #### Анализ основных параметров

# %% [markdown]
# Посмотрим характеристики выборки столбцов `square_meter_price`, `last_price`, `total_area`, `ceiling_height`, `rooms` для сегмента объявлений - центр города:

# %%
#описание выборки столбцов 'total_area', 'last_price','ceiling_height', 'rooms'
#по всей выборке
df_sntp_center[['last_price','square_meter_price', 'total_area', 'ceiling_height', 'rooms' ]].describe()
# Out:
#          last_price  square_meter_price   total_area  ceiling_height  \
# count  4.382000e+03        4.382000e+03  4382.000000     4382.000000
# mean   1.376875e+07        1.407623e+05    88.570032        2.951157
# std    2.296136e+07        8.619537e+04    57.929565        1.677898
# min    1.600000e+06        1.534500e+04    12.000000        2.000000
# 25%    6.207104e+06        9.960275e+04    53.225000        2.650000
# 50%    8.707500e+06        1.222220e+05    75.000000        2.755000
# 75%    1.350000e+07        1.520660e+05   104.840000        3.100000
# max    7.630000e+08        1.907500e+06   900.000000      100.000000
#
#              rooms
# count  4382.000000
# mean      2.720904
# std       1.410307
# min       0.000000
# 25%       2.000000
# 50%       3.000000
# 75%       3.000000
# max      19.000000

# %% [markdown]
# Сравним с описанием выборки для отфильтрованных данных, для этого уберём значения, для которых выборка мала:
# - `last_price`<30 000 000
# - `square_meter_price` < 300 000
# - `total_area`<250
# - `ceiling_height`<4.5
# - `rooms`<7

# %%
#описание выборки столбцов 'total_area', 'last_price','ceiling_height', 'rooms'
#по отфильоавнному срезу
(
    df_sntp_center
    .query('total_area<250 and last_price<30000000 and ceiling_height<4.5 and rooms<7 and square_meter_price<300000')
    [['last_price','square_meter_price','total_area', 'ceiling_height', 'rooms']].describe()
)
# Out:
#          last_price  square_meter_price   total_area  ceiling_height  \
# count  3.997000e+03         3997.000000  3997.000000     3997.000000
# mean   9.704610e+06       125993.901176    77.754428        2.885649
# std    5.306540e+06        38538.480854    35.050929        0.321887
# min    1.600000e+06        15345.000000    12.000000        2.000000
# 25%    6.000000e+06        98422.000000    51.000000        2.650000
# 50%    8.299000e+06       119298.000000    71.000000        2.750000
# 75%    1.194000e+07       144558.000000    96.000000        3.070000
# max    2.999900e+07       295203.000000   240.000000        4.400000
#
#              rooms
# count  3997.000000
# mean      2.543658
# std       1.137190
# min       0.000000
# 25%       2.000000
# 50%       2.000000
# 75%       3.000000
# max       6.000000

# %% [markdown]
# **Средняя цена недвижимости** в центре Санкт-Петербурга - **9,70 млн. руб**, **медиана - 8.3 млн. руб**.
#
# **Средняя стоимость квадратного метра** жилья в центре города - **126 тыс. руб./кв.м**, **медиана около 120 тыс. руб/кв.м.**
#
# Средняя площадь - 77,8 кв.м., медиана -71 кв.м.
#
# Медиана числа комнат - 2 шт.
#
# Высоту потолка рассмотрим далее, подробнее. Нужно учесть, что мы заменили пропуски на `2.65`, посмотреть медиану без них.
#
# Построим гистограммы для выборки `last_price`,`square_meter_price`, `total_area`,  и `ceiling_height`:

# %%
#строим гистограмму для total_area, last_price и ceiling_height
#с использованием цикла
array = ['total_area', 'last_price','ceiling_height', 'square_meter_price']

for column in array:
    (df_sntp_center
     .query('total_area<250 and last_price<30000000 and ceiling_height<4.5 and rooms<7 and square_meter_price<300000')
    .hist(column, bins=50))
    plt.title('Гистограмма '+column+' для центра города')
    plt.show()

# %% [markdown]
# Обратим внимание на гистограмму высоты потолка. На стадии предобработки данных мы заполнили пропуски в столбце `ceiling_height` медианным значением **`2.65`**. Судя по гистограмме центра города, мы сильно исказили выборку.
# С **заполненными пропусками** получилось, что в центре:
# - 25% квартир с потолком ниже 2.65 м
# - медиана - 2,75 м
# Количество значений в такой выборке - 4016 объявлений.

# %% [markdown]
# Посмотрим, как выглядит высота потолка без заполнения пропусков в центре города, мы сохранили её в отдельной переменной на стадии предобработки данных:

# %%
#строим гистограмму для высоты потолка в центре Санкт-Петербурга без заполнения пропусков
(
    good_ceiling_height_stat
    .query('locality_name == "Санкт-Петербург" and city_centers_nearest<9000')
    .query('total_area<250 and last_price<30000000 and ceiling_height<4.5 and rooms<7')
    ['ceiling_height']
    .hist(bins=50)
)

plt.title('Гистограмма высоты потолка для центра города \n без заполнения пропусков')
plt.xlabel('ceiling_height')
plt.show()

# %% [markdown]
# И посмотрим на описание характеристик выборки высоты потолка в центре города до заполнения пропусков:

# %%
#характеристика выборки значений высоты потолка в центре Санкт-Петербурга
#до заполнения пропусков
(
    good_ceiling_height_stat
    .query('locality_name == "Санкт-Петербург" and city_centers_nearest<9000')
    .query('total_area<250 and last_price<30000000 and ceiling_height<4.5 and rooms<7')
    ['ceiling_height']
    .describe()
)
# Out:
# count    2605.000000
# mean        2.996618
# std         0.312470
# min         2.400000
# 25%         2.750000
# 50%         3.000000
# 75%         3.200000
# max         3.980000
# Name: ceiling_height, dtype: float64

# %% [markdown]
# Итак, выборка сократилась до **2605** значений вместо 4016 с заполненными пропусками, мы потеряли около 1400 значений. Но важно отметить, что **без заполнения пропущенных значений**:
# - 25% квартир с потолком ниже **2.75 м**
# - медиана - **3 м** очень близка к среднему значению 2,99 м
#
# **Разница** по сравнению с выборкой с заполненными пропусками **существенная**. Поэтому для центра города правильнее было *не заполнять* пропуски. Центр Санкт-Петербурга славится оригинальной архитектурой, поэтому и высота потолка там выше.

# %% [markdown]
# Осталось посмотреть как количество объявлений распределилось по количеству комнат в центре города, посмотроим гистограмму:

# %%
#строим гистограмму
(
    df_sntp_center
     .query('total_area<250 and last_price<30000000 and ceiling_height<4.5 and rooms<7')
    .hist('rooms', bins=7)
)

plt.title('Гистограмма количества комнат для центра города')
plt.xlabel('rooms')
plt.show()

# %% [markdown]
# Примерно одинаковое количество объявлений с 2 и 3 комнатами - около 2400 в сумме. Приличное количество 4 комнатных квартир - около 500 шт., однокомнатных - около 700 шт.

# %% [markdown]
# ##### Вывод

# %% [markdown]
# Сделаем вывод о том, как основные параметры объектов недвижимости **в центре отличаются** от всего города. Для этого воспользуемся нижеприведенными таблицами сравнения средних значений и медиан дл ядвух категорий (весь город и центр города):

# %% [markdown]
# Таблица сравнения **средних значений**
#
# |Параметр |Ед.изм.|Центр города|Весь город|
# |:-----|:----:|:----:|----:|
# |Цена объекта |млн. руб. |9.70 |4.85 |
# |Цена квадратного метра|руб/кв.м.|126 |94.7 |
# |Общая площадь |кв.м|77.8 |54.4 |
# |Число комнат |шт.|2.54 |2.04 |
# |Высота потолков|м |2.99 |2.65 |
#
# Таблица сравнения **медиан**
#
# |Параметр |Ед.изм.|Центр города|Весь город|
# |:-----|:----:|:----:|----:|
# |Цена объекта |млн. руб. |8.3 |4.4 |
# |Цена квадратного метра|руб/кв.м.|120 |94.2|
# |Общая площадь |кв.м|71 |50 |
# |Число комнат |шт.|2 |2 |
# |Высота потолков|м |3 |2.63 |

# %% [markdown]
# Квартиры в цетре города:
# - имеют бОльшую площадь,
# - стоят дороже (из-за большей площади квартир, цены на них почти в 2 раза дороже в среднем, квадратный метр дороже примерно на 33% в среднем и по медиане),
# - там, как правило, больше комнат, чем в целом по городу ( вреднем 2,5 комнаты, то есть удельно больше 2 и 3 контаных квартир),
# - и не менее важно, что в центре города ощутимо выше потоли (3 м против 2,65 по медиане).

# %% [markdown]
# #### Факторы, влияющие на цену квартир в центре

# %% [markdown]
# Определим факторы, которые влияют на стоимость квартиры в центре города (число комнат, этаж, удалённость от центра, дата размещения объявления).

# %% [markdown]
# Запишем выборку хороших данных по центру города в отдельную переменную для удобства:

# %%
#записываем срез данных из df_sntp_center в df_good_sntp_center
df_good_sntp_center = (
    df_sntp_center
    .query('total_area<250 and last_price<30000000 and ceiling_height<4.5 and rooms<7 and square_meter_price<300000')
                      )

# %% [markdown]
# Построим диаграмму ресеивания для стоимости квадратного метра в зависимости от площади квартиры:

# %% [markdown]
# ##### Общая площадь

# %%
#строим диаграмму рессеивания - зависимость стоимости квадратного метра от площади квартиры
(
    df_good_sntp_center
    .plot(x='total_area', y='square_meter_price', kind='scatter',alpha=0.3)
)
plt.title('Диаграмма рассеивания -  зависимость стоимости \n квадратного метра в центре от площади квартиры')
plt.show()

# %% [markdown]
# Из диаграммы не прослеживается какой-либо взаимосвязи. Посмотрим на диаграмму общей стоимости:

# %%
#строим диаграмму рессеивания - зависимость общей стоимости квартиры в центре от площади квартиры
(
    df_good_sntp_center
    .plot(x='total_area', y='last_price', kind='scatter',alpha=0.3)
)

plt.title('Диаграмма рассеивания -  зависимость стоимости \n объекта недвижимости в центре от площади квартиры', pad=15)
plt.show()

# %% [markdown]
# Видим явную взаимосвязь, оценим коэффициент корреляции:

# %%
#оцениваем коэффициент корреляции между стоимостью квартиры в центре и площадью квартиры
(
    df_good_sntp_center
    ['last_price']
    .corr(df_good_sntp_center['total_area'])
)
# Out:
# 0.7646303911931474

# %% [markdown]
# Коэффициент корреляции - 0,76, это довольно высокое значение.
#
# Чтобы ускорить процесс анализа, построим матрицу диаграмм рассеяния для параметров `last_price`, `square_meter_price`, `total_area`, `city_centers_nearest`:

# %%
#строим матрицу диаграм рассеивания для столбцов last_price, square_meter_price, total_area, city_centers_nearest
#датафрейма df_good_sntp_center
(
    pd
    .plotting
    .scatter_matrix(
        df_good_sntp_center[['last_price',
                             'square_meter_price',
                             'total_area', 
                             'city_centers_nearest'
                            ]
                           ],
        figsize=(12, 12)
    ) 
)

plt.show()

# %% [markdown]
# Как видно из матрицы диаграмм, явная зависимость параметров прослеживается только между `last_price` и `total_area`. Расстояние от центра предстоит проверить отдельно, пока что явной зависимости не выявлено.
#
# Матрица коэффициентов корреляции тоже не выявляет других зависимостей `last_price` или `square_meter_price`.

# %%
import seaborn as sb
sb.heatmap(
    df_good_sntp_center[['last_price',
                         'square_meter_price',
                         'total_area', 
                         'city_centers_nearest']
                       ]
    .corr(),
    annot=True,
)

plt.title('Матрица коэффициентов корреляции параметров \n для квартир в центре')
plt.show()

# %% [markdown]
# ##### Этаж

# %% [markdown]
# Создадим функцию, которая будет строить график и выводить сводную таблицу для категорийных строковых переменных.

# %%
#функция category_group_barh входные данные для которой - тип цены и колонка с категорийной переменной
def category_group_barh (price_type, colum1):
    id_price = ( df_good_sntp_center
    .pivot_table(index = [colum1], 
                 values= price_type, 
                 aggfunc=(['count','mean']))
             )
    #избавимся от двойного названия столбцов
    id_price.columns=['count',price_type+'_mean']
    
    #выведем на экран сводную таблицу
    display(id_price)
    
    #строим столбчутую диаграмму
    (id_price
     .plot(y=price_type+'_mean',
          figsize=(10,6),
          grid=True,
          ylim=0,
          kind='barh'))

# %% [markdown]
# Применем функцию к столбцу `floor_category`:

# %%
#применяем функцию к столбцу floor_category
category_group_barh('square_meter_price','floor_category')
plt.title('Зависимость стоимости квадратного метра от этажа', pad=15)
plt.show()
# Out:
#                 count  square_meter_price_mean
# floor_category
# другой           2904            129066.328512
# первый            445            112763.197753
# последний         648            121310.774691

# %% [markdown]
# Средняя цена квадратного метра на первом этаже (112,8 тыс. руб.) ниже, чем на последнем (121,3 тыс. руб.), а последний этаж дешевле других этажей (129 тыс. руб.).

# %% [markdown]
# Повторим применение функции для `floor_category`, но для цены `last_price`:

# %%
#применяем функцию к столбцу floor_category
category_group_barh('last_price','floor_category')
plt.title('Зависимость стоимости объекта недвижимости от этажа', pad=15)
plt.show()
# Out:
#                 count  last_price_mean
# floor_category
# другой           2904     1.005710e+07
# первый            445     7.226245e+06
# последний         648     9.826917e+06

# %% [markdown]
# В центре Санкт-Петербурга объекты недвижимости на первом этаже значительно дешевле последнего и других этажей, в среднем примерно на 35-40%. Это объяснимо, на первом этаже сложнее избежать городской суеты и шума автотрансопорта.

# %% [markdown]
# ##### Расстояние до центра

# %% [markdown]
# Теперь **запишем функцию** для создания **сводной таблицы** и построения графика **с линией и точками**. Функция будет выдавать результат сразу по двум типам цены - квадратный метр и общая стоимость.
#
# Пригодится для таких категорийных переменных, которые в тоже время являются числами: `rooms`, `floor_category` и `city_centers_nearest_km` и других.

# %%
#функция category_group_plot, входные данные для которой -  колонка с категорийной переменной

#создаём функцию
def category_group_plot (colum1):
    
    #массив типов цены
    array_price = ['square_meter_price', 'last_price']
    
    #перебираем типы цены
    for price_type in array_price:
        
        #делаем сводную таблицу
        id_price = ( df_good_sntp_center
                    .pivot_table(index = [colum1], 
                                 values= price_type, 
                                 aggfunc=(['count','mean']))
                   )
        
        #избавимся от двойного названия столбцов
        id_price.columns=['count',price_type+'_mean']
        
        #выведем на экран сводную таблицу
        display(id_price)
        
        #строим график    
        id_price.plot(y=price_type+'_mean',
                      figsize=(10,5),
                      style='-o',
                      ylim=0,
                      grid=True)
        plt.title('Зависимость '+price_type+'_mean'+' от '+ colum1, pad=15)
        plt.show()

# %% [markdown]
# Далее применяем функцию для столбца `city_centers_nearest_km`.
# Функция позволяет сделать это сразу для двух типов цены (общая и за кв. метр):

# %%
#применяем функцию к столбцу city_centers_nearest_km - расстояние до центра в километрах
category_group_plot('city_centers_nearest_km')
# Out:
#                          count  square_meter_price_mean
# city_centers_nearest_km
# 0                           15            120645.000000
# 1                          161            134202.720497
# 2                          271            126556.571956
# 3                          328            116133.652439
# 4                          644            123990.545031
# 5                          840            130323.801190
# 6                          532            130166.556391
# 7                          366            131463.379781
# 8                          583            123510.428816
# 9                          257            113229.385214
#                          count  last_price_mean
# city_centers_nearest_km
# 0                           15     1.131867e+07
# 1                          161     1.121913e+07
# 2                          271     1.092011e+07
# 3                          328     9.491321e+06
# 4                          644     1.017125e+07
# ...

# %% [markdown]
# Делаем вывод, что цена **квадратного метра** в центре Санкт-Петербурга слабо зависит от удалённости от центра. В свою очередь, общая цена объекта недвижимости снижается по мере удаления от центра.

# %% [markdown]
# ##### Число комнат

# %% [markdown]
# Применем функцию для столбца `rooms`:

# %%
#применяем функцию к столбцу rooms - число комнат
category_group_plot('rooms')
# Out:
#        count  square_meter_price_mean
# rooms
# 0         21            139002.428571
# 1        716            140190.722067
# 2       1306            130153.127871
# 3       1255            122639.132271
# 4        475            113353.865263
# 5        170            101423.988235
# 6         54             98606.574074
#        count  last_price_mean
# rooms
# 0         21     4.696429e+06
# 1        716     5.906704e+06
# 2       1306     8.402338e+06
# 3       1255     1.109408e+07
# 4        475     1.311561e+07
# 5        170     1.448351e+07
# 6         54     1.616426e+07

# %% [markdown]
# Получился интересный результат: чем **больше комнат**, тем **ниже** цена квадратного метра. Но общая цена объекта недвижимости растет с увеличением числа комнат, это логично, ведь увеличивается площадь квартиры.

# %% [markdown]
# ##### Время размещения

# %% [markdown]
# ###### День размещения

# %% [markdown]
# Посмотрим, как влияет день размещения объявления:

# %%
#применяем функцию к weekday_exposition, изучаем зависимость от дня размещения
category_group_plot('weekday_exposition')
# Out:
#                     count  square_meter_price_mean
# weekday_exposition
# 0                     608            129531.353618
# 1                     691            124343.625181
# 2                     694            127696.210375
# 3                     805            124003.751553
# 4                     677            124930.852290
# 5                     291            125858.120275
# 6                     231            126727.380952
#                     count  last_price_mean
# weekday_exposition
# 0                     608     1.017718e+07
# 1                     691     9.400527e+06
# 2                     694     1.006896e+07
# 3                     805     9.731733e+06
# 4                     677     9.509644e+06
# 5                     291     8.885755e+06
# 6                     231     9.784208e+06

# %% [markdown]
# Общая цена чуть меньше во вторник (9,4 млн.) и в субботу (8,8 млн.). В остальные дни 9,5-10 млн. руб.

# %% [markdown]
# ###### Месяц размещения

# %% [markdown]
# Посмотрим зависимость от месяца размещения:

# %%
#применяем функцию к month_exposition, изучаем зависимость от месяца размещения
category_group_plot('month_exposition')
# Out:
#                   count  square_meter_price_mean
# month_exposition
# 1                   244            127919.901639
# 2                   418            125613.942584
# 3                   431            129469.932715
# 4                   383            129224.911227
# 5                   237            124050.864979
# 6                   307            123053.944625
# 7                   315            124896.447619
# 8                   299            127345.127090
# 9                   363            125106.699725
# 10                  347            124885.962536
# 11                  391            126408.475703
# 12                  262            121422.870229
#                   count  last_price_mean
# month_exposition
# 1                   244     1.017051e+07
# 2                   418     9.960352e+06
# 3                   431     9.721183e+06
# 4                   383     9.646548e+06
# 5                   237     9.447875e+06
# ...

# %% [markdown]
# Средняя цена недвижимости в центре Санкт-Петербурга снижается с января до декабря с 10 млн. до 9 млн. руб. Есть небольшие колебания в течение года. Например, в период с июля до сентября средняя цена немного увеличивается, самая низкая цена в декабре.

# %% [markdown]
# ###### Год размещения

# %% [markdown]
# Проследим зависимость средней стоимости от года размещения

# %%
#применяем функцию к year_exposition, изучаем зависимость от года размещения
category_group_plot('year_exposition')
# Out:
#                  count  square_meter_price_mean
# year_exposition
# 2014                30            139624.366667
# 2015               327            120240.593272
# 2016               535            124038.300935
# 2017              1408            123782.004261
# 2018              1259            126980.320890
# 2019               438            136019.271689
#                  count  last_price_mean
# year_exposition
# 2014                30     1.415861e+07
# 2015               327     1.032421e+07
# 2016               535     9.871881e+06
# 2017              1408     9.585609e+06
# 2018              1259     9.386406e+06
# 2019               438     1.002984e+07

# %% [markdown]
# Выборка в 2014 слишком маленькая, его можно исключить из рассмотрения. За период с 2015 по 2018 год цена на недвижимость снизилась примерно на 10%, с 2019 года начался рост стоимости. В 2019 году средняя цена на недвижимость в центре города выросла на 10% по сравнению с 2018 годом.

# %% [markdown]
# ##### Дополнительные параметры

# %% [markdown]
# ###### Количество парков

# %% [markdown]
# Интересно, как количество парков влияет на цену:

# %%
#применяем функцию к parks_around_3000, изучаем зависимость от количества парков
category_group_plot('parks_around_3000')
# Out:
#                    count  square_meter_price_mean
# parks_around_3000
# 0                   1434            123878.843794
# 1                   1618            127347.461063
# 2                    678            125384.072271
# 3                    267            130699.505618
#                    count  last_price_mean
# parks_around_3000
# 0                   1434     9.076708e+06
# 1                   1618     1.004225e+07
# 2                    678     9.640633e+06
# 3                    267     1.119335e+07

# %% [markdown]
# С увеличением количества парков увеличивается полная цена, стоимость квадратного метра тоже растёт, но не так явно. Цена на недвижимость там где нет парков ниже на 20% по сравнению с объявлениями, где в радиусе 3 км есть 3 парка.

# %% [markdown]
# ###### Количество прудов

# %% [markdown]
# Есть ли связь между **количеством прудов** и ценой?

# %%
#применяем функцию к ponds_around_3000, изучаем зависимость от количества прудов
category_group_plot('ponds_around_3000')
# Out:
#                    count  square_meter_price_mean
# ponds_around_3000
# 0                   1224            120169.237745
# 1                   1414            126197.114569
# 2                    640            131491.345312
# 3                    719            130616.543811
#                    count  last_price_mean
# ponds_around_3000
# 0                   1224     9.165965e+06
# 1                   1414     9.628422e+06
# 2                    640     1.026964e+07
# 3                    719     1.026847e+07

# %% [markdown]
# Зависимость есть, но не такая сильная как в случае парков. Там, где нет прудов, цена ниже примерно на 10% тех объявлений, где есть целых 2-3 пруда.

# %% [markdown]
# ###### Число балконов

# %% [markdown]
# Число **балконов** влияет на стоимость?

# %%
#применяем функцию к balcony, изучаем зависимость от количества балконов
category_group_plot('balcony')
# Out:
#          count  square_meter_price_mean
# balcony
# 0         3160            123156.362658
# 1          451            129149.184035
# 2          324            146135.382716
# 3            9            147882.666667
# 4           27            140272.592593
# 5           26            142733.346154
#          count  last_price_mean
# balcony
# 0         3160     9.568017e+06
# 1          451     9.701388e+06
# 2          324     1.039116e+07
# 3            9     1.278322e+07
# 4           27     1.295585e+07
# 5           26     1.336442e+07

# %% [markdown]
# Рост цены есть, но уменьшается выборка, поэтому сложно делать выводы. Скорее всего, чем больше балконов, тем больше общая площадь, поэтому мы видим некоторую связь.

# %% [markdown]
# ###### Расстояние до парка, пруда, аэропорта

# %% [markdown]
# Напоследок построим матрицу корреляции, чтобы посомтреть зависимость

# %%
#строим матрицу диаграм рассеивания для столбцов last_price, square_meter_price, 'parks_nearest', 'ponds_nearest',
#'airports_nearest' датафрейма df_good_sntp_center
(df_good_sntp_center[['last_price',
                      'square_meter_price',
                      'parks_nearest', 
                      'ponds_nearest',
                      'airports_nearest']
                    ]
 .corr()
)
# Out:
#                     last_price  square_meter_price  parks_nearest  \
# last_price            1.000000            0.545051       0.077566
# square_meter_price    0.545051            1.000000       0.071522
# parks_nearest         0.077566            0.071522       1.000000
# ponds_nearest         0.016360            0.046749       0.031105
# airports_nearest      0.019050            0.061896       0.061167
#
#                     ponds_nearest  airports_nearest
# last_price               0.016360          0.019050
# square_meter_price       0.046749          0.061896
# parks_nearest            0.031105          0.061167
# ponds_nearest            1.000000          0.058126
# airports_nearest         0.058126          1.000000

# %% [markdown]
# Судя по матрице корреляции, явной взаимосвязи между `last_price`, `square_meter_price` и `parks_nearest`, `ponds_nearest`,
# `airports_nearest` нет.

# %% [markdown]
# ##### Вывод

# %% [markdown]
# При сравнении факторов, влияющих на цену недвижимости в центре Санкт-Петербурга и во всём городе выявлены как схожие закономерности, так и отличия:
# - общая площадь оказывает существенное влияние на цену недвижимости, в центре города коэффициент корреляции 0,76 - больше, чем по всему городу (0,70),
# - в городе разница стоимости первого и "другого" этажа 19%, в центральной части Санкт-Петербурга первый этаж дешевле другого на 29%. Разница существенна. Объясняется непривлекательностью городской суеты и шума автотранспорта на 1 этаже в центре города.
# - внутри центра корреляция между стоимостью и расстоянием до центра низкая (коэффициент -0.15), во всем городе коэффициент был -0.4, ощутимее выше. Объясняется тем, что мы виделили категорию "центр города", низкая корреляция цены с расстоянием подтверждает, что  мы выбрали её правильно.
# - выраженная зависимость общей стоимости от числа комнат сохраняется, только в центре с увеличением числа комнат от 1 до 6 стоимость увеличивается от 6 до 16 млн, а во всём городе от 4 до 10 млн.
# - цена квадратного метра в центре с увеличением числа комнат уменьшается, в то время как во всем городе цена снижается от 1 до 3 комнат, затем возвращается примерно на прежний уровень.
# - общая стоимость квартир во всём городе практически не зависит от дня недели, в центре цена немного ниже по вторникам и субботам (примерно на 10%), но есть колебания цены в течение недели.
# - средняя цена недвижимости в центре Санкт-Петербурга снижается с января до декабря с 10 млн. до 9 млн. руб. Есть небольшие колебания в течение года. Например, в период с июля до сентября средняя цена немного увеличивается, самая низкая цена в декабре. В выборке по всему городу самая низкая цена на недвижимость в июне, максимальная в апреле и сентябре.
# - в статистике за 2015-2019 год прослеживается следующий разультат. В центре города цена на недвижимость снизилась примерно на 10%, с 2019 года начался рост стоимости. В 2019 году средняя цена на недвижимость в центре города выросла на 10% по сравнению с 2018 годом. В выборке по всемугороду полная стоимость - спад в период с 2014 по 2016. В период 2016-2018 стоимость квартир слабо менялась (возможно, на это повлияла общая площадь квартир, выставлявшихся на продажу). Затем рост только с 2019 г.

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# 1. В исходной талице было **14 стоблцов** с пропущеными значениями. Пропущенные значения были устранены различными методами для дальнейшего анализа. В частности, была выделена группа пропущенных значений из примерно 5000 строк с данными, полученными автоматически на основе картографических показателей. Вероятная причина - отсутствие определённых объектов или сбой при передаче данных, группа была отмечена отдельным маркером.
#
# 2. В таблицу для анализа **были расчитаны и добавлены новые столбцы**: стоимость 1 квадратного метра, день недели размещения объявления, месяц размещения объявления, год размещения объявления, категоризация по этажу (первый, последний, другой), отношение жилой площади к общей, отношение площади кухни к общей площади.
#
# 3. В ходе анализа времени продажи мы обнаружили анамально большое количество снятий объявления с продажи в **`7`,`30`,`45`,`60` и `90`** дни. Очень похоже на **окончание определённых периодов размещения** объявления (платных/бесплатных). Поэтому **большое количество снятий объявлений** с продажи в эти дни **не означает**, что они были проданы. Анализ времени продажи без выдающихся значений показал:
#     - **Лишь 25%** объявлений снимаются с продажи **в первые 40 дней**,
#     - **50%** объявлений в течение первых **98 дней**,
#     - **75%** объявлений продаются в течение **200 дней**, поэтому необычно длинным сроком продажи можно считать превышение 1-1,5 лет.
#
# 4. Анализ зависимости различных факторов на стоимость выявил для всего города Санкт-Петербург и других населённых пунктов выявил следующее:
#     - **Общая площадь квартиры**. Между стоимостью *квадратного метра* и площадью квартиры нет явной зависимости. И для малых, и для больших площадей представлены все ценовые диапазоны стоимости квадратного метра. Обнаружена довольно сильная **линейная взаимосвязь** между **полной стоимостью** и общей площадью: **коэффициент корреляции 0,7**.
#     - **Число комнат**. Средняя стоимость квадратного метра снижается с увеличением количества комнат от 1 до 3: **от 100 тыс. до 90 тыс. руб. за квадратный метр**. На 4 комнатах средняя цена снова немного увеличивается и становится равной 95 тыс. руб. за кв. м. Зависимость стоимости объекта недвижимости от числа комнат явная - чем больше комнат, тем выше стоимость. Это следствие первого пункта, так как чем больше комнат, тем больше площадь.
#     - **Этаж**. Средняя стоимость квадратного метра самая низкая на **первом этаже** (около **80 тыс. руб.**), на **последнем** немного выше (**87 тыс. руб**), средняя цена квадратного метра в категории **другой** - около **100 тыс. руб. за кв.м**. Результат анализа полной стоимости объекта недвижимости аналогичен стоимости квадратного метра: средняя стоимость объекта недвижимости на **1 этаже - 4,1 млн. руб.**, на **последнем - 4,5 млн. руб.**, в категории **другой - 5 млн. руб.**
#     - **Удалённость от центра**. При анализе всей выборки обнаружена слабая отрицательная корреляция между стоимостью квадратного метра и удалённостью от центра, а также полной стоимостью объекта недвижимости, то есть чем дальше от центра, тем ниже стоимость (коэффициент корреляции около **-0,4**. Но так как в выборке присутствуют все населённые пунткы, то этот параметр предстоит проанализировать более детально отдельно для г. Санкт-Петербург.
#     - **День, месяц и год продажи**. Стоимость объекта недвижимости практически **не зависит** от дня недели. Стоимость квадратного метра и общая стоимость ниже всего в **июне** месяце, дороже в апреле и сентябре
#     - **Населённый пункт**. Анализ 10 населённых пунктов с самым большим количеством объявлений показал, что **наибольшая средняя цена квадратного метра**, как и ожидалась, в **г. Санкт-Петербург** - около **108 тыс. руб. за кв. м. **В Пушкине** цена квадратного метра близка к уровню цен в Санкт-Петербурге, что объясняется высоким культурным статусом данного населённого пункта (около **102 тыс. руб. за кв. м**). На **третьем месте** посёлок **Парголово** и деревня **Кудрово**: **90-92,5 тыс. руб. за кв. метр**. **Самая низкая стоимость** квадратного метра получилась в **Выборге - 58 тыс. за кв. м.**
#
# 5. При сравнении факторов, влияющих на цену недвижимости **в центре Санкт-Петербурга и во всём городе** выявлены как схожие закономерности, так и отличия:
#     - **общая площадь** оказывает существенное влияние на цену недвижимости, в центре города коэффициент корреляции 0,76 - больше, чем по всему городу (0,70),
#     - во всем городе разница стоимости первого и "другого" **этажа 19%**, в центральной части Санкт-Петербурга **первый этаж дешевле "другого" на 29%**. Разница существенна. Объясняется скорее всего непривлекательностью городской суеты и шума автотранспорта на 1 этаже в центре города.
#     - **в центре** корреляция между **стоимостью и расстоянием до центра** низкая (коэффициент -0.15), во всем городе коэффициент **был -0.4**, ощутимее выше. Объясняется тем, что мы виделили категорию "центр города". Низкая корреляция цены с расстоянием подтверждает, что  **мы выбрали её правильно**.
#     - выраженная зависимость общей стоимости от числа комнат сохраняется, только в центре с увеличением числа комнат от 1 до 6 стоимость увеличивается **от 6 до 16 млн**, а во всём городе **от 4 до 10 млн**.
#     - **цена квадратного метр**а в центре с увеличением числа комнат **уменьшается**, в то время как во всем городе цена снижается от 1 до 3 комнат, затем возвращается примерно на прежний уровень.
#     - **общая стоимость** квартир во всём городе практически не зависит **от дня недели**, в центре цена немного ниже по вторникам и субботам (примерно на 10%), есть небольшие колебания цены в течение недели (примерно 5%).
#     - средняя цена недвижимости в центре Санкт-Петербурга **снижается** с января до декабря с **10 млн. до 9 млн. руб.** (или с декабря по январь цена увеличивается, то есть с начала нового года). Затем Есть небольшие колебания в течение года. Например, в период **с июля до сентября** средняя цена немного увеличивается, самая низкая цена в декабре.
#     - в статистике за **2015-2019 год** в центре города цена на недвижимость снизилась примерно на 10%, с 2019 года начался рост стоимости. В 2019 году средняя цена на недвижимость в центре города выросла на 10% по сравнению с 2018 годом.
