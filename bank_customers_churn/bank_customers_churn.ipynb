# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Предварительное-изучение-данных-из-файла" data-toc-modified-id="Предварительное-изучение-данных-из-файла-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Предварительное изучение данных из файла</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Удаление-некоторых-столбцов" data-toc-modified-id="Удаление-некоторых-столбцов-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Удаление некоторых столбцов</a></span></li><li><span><a href="#Изменение-названий-столбцов" data-toc-modified-id="Изменение-названий-столбцов-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Изменение названий столбцов</a></span></li><li><span><a href="#Пропуски-в-столбце-tenure" data-toc-modified-id="Пропуски-в-столбце-tenure-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Пропуски в столбце <code>tenure</code></a></span></li><li><span><a href="#Кодирование-категориальных-признаков" data-toc-modified-id="Кодирование-категориальных-признаков-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Кодирование категориальных признаков</a></span></li><li><span><a href="#Разбивка-данных-на-выборки" data-toc-modified-id="Разбивка-данных-на-выборки-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Разбивка данных на выборки</a></span></li><li><span><a href="#Тестовый,-обучающий-и-валидационный-наборы-данных" data-toc-modified-id="Тестовый,-обучающий-и-валидационный-наборы-данных-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Тестовый, обучающий и валидационный наборы данных</a></span></li><li><span><a href="#Масштабирование-численных-признаков" data-toc-modified-id="Масштабирование-численных-признаков-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>Масштабирование численных признаков</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-2.8"><span class="toc-item-num">2.8&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Исследование-задачи" data-toc-modified-id="Исследование-задачи-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Исследование задачи</a></span><ul class="toc-item"><li><span><a href="#Сбалансированность-выборки" data-toc-modified-id="Сбалансированность-выборки-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Сбалансированность выборки</a></span></li><li><span><a href="#Модель-логистической-регрессии-без-учета-дисбаланса" data-toc-modified-id="Модель-логистической-регрессии-без-учета-дисбаланса-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Модель логистической регрессии без учета дисбаланса</a></span></li><li><span><a href="#Модель-решающего-дерева-без-учета-дисбаланса" data-toc-modified-id="Модель-решающего-дерева-без-учета-дисбаланса-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Модель решающего дерева без учета дисбаланса</a></span></li><li><span><a href="#Модель-случайного-леса-без-учета-дисбаланса-классов" data-toc-modified-id="Модель-случайного-леса-без-учета-дисбаланса-классов-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Модель случайного леса без учета дисбаланса классов</a></span></li><li><span><a href="#Построение-ROC-кривой-трех-моделей-(без-учета-дисбаланса)" data-toc-modified-id="Построение-ROC-кривой-трех-моделей-(без-учета-дисбаланса)-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Построение ROC-кривой трех моделей (без учета дисбаланса)</a></span></li><li><span><a href="#Проверка-адекватности-модели" data-toc-modified-id="Проверка-адекватности-модели-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Проверка адекватности модели</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-3.7"><span class="toc-item-num">3.7&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Борьба-с-дисбалансом" data-toc-modified-id="Борьба-с-дисбалансом-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Борьба с дисбалансом</a></span><ul class="toc-item"><li><span><a href="#Взвешивание-классов" data-toc-modified-id="Взвешивание-классов-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Взвешивание классов</a></span><ul class="toc-item"><li><span><a href="#Взвешивание-классов-для-логистической-регрессии" data-toc-modified-id="Взвешивание-классов-для-логистической-регрессии-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>Взвешивание классов для логистической регрессии</a></span></li><li><span><a href="#Взвешивание-классов-для-решающего-дерева" data-toc-modified-id="Взвешивание-классов-для-решающего-дерева-4.1.2"><span class="toc-item-num">4.1.2&nbsp;&nbsp;</span>Взвешивание классов для решающего дерева</a></span></li><li><span><a href="#Взвешивание-классов-для-модели-случайного-леса" data-toc-modified-id="Взвешивание-классов-для-модели-случайного-леса-4.1.3"><span class="toc-item-num">4.1.3&nbsp;&nbsp;</span>Взвешивание классов для модели случайного леса</a></span></li><li><span><a href="#Построение-ROC-кривой-и-вычисление-AUC-ROC" data-toc-modified-id="Построение-ROC-кривой-и-вычисление-AUC-ROC-4.1.4"><span class="toc-item-num">4.1.4&nbsp;&nbsp;</span>Построение ROC-кривой и вычисление AUC-ROC</a></span></li></ul></li><li><span><a href="#Увеличение-выборки" data-toc-modified-id="Увеличение-выборки-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Увеличение выборки</a></span><ul class="toc-item"><li><span><a href="#Модель-логистической-регрессии-для-увеличенной-выборки" data-toc-modified-id="Модель-логистической-регрессии-для-увеличенной-выборки-4.2.1"><span class="toc-item-num">4.2.1&nbsp;&nbsp;</span>Модель логистической регрессии для увеличенной выборки</a></span></li><li><span><a href="#Модель-решающего-дерева" data-toc-modified-id="Модель-решающего-дерева-4.2.2"><span class="toc-item-num">4.2.2&nbsp;&nbsp;</span>Модель решающего дерева</a></span></li><li><span><a href="#Модель-случайного-леса" data-toc-modified-id="Модель-случайного-леса-4.2.3"><span class="toc-item-num">4.2.3&nbsp;&nbsp;</span>Модель случайного леса</a></span></li></ul></li><li><span><a href="#Уменьшение-выборки" data-toc-modified-id="Уменьшение-выборки-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Уменьшение выборки</a></span><ul class="toc-item"><li><span><a href="#Модель-логистической-регрессии-с-уменьшенной-выборкой" data-toc-modified-id="Модель-логистической-регрессии-с-уменьшенной-выборкой-4.3.1"><span class="toc-item-num">4.3.1&nbsp;&nbsp;</span>Модель логистической регрессии с уменьшенной выборкой</a></span></li><li><span><a href="#Модель-решающего-дерева-с-уменьшенной-выборкой" data-toc-modified-id="Модель-решающего-дерева-с-уменьшенной-выборкой-4.3.2"><span class="toc-item-num">4.3.2&nbsp;&nbsp;</span>Модель решающего дерева с уменьшенной выборкой</a></span></li><li><span><a href="#Модель-случайного-леса-с-уменьшенной-выборкой" data-toc-modified-id="Модель-случайного-леса-с-уменьшенной-выборкой-4.3.3"><span class="toc-item-num">4.3.3&nbsp;&nbsp;</span>Модель случайного леса с уменьшенной выборкой</a></span></li></ul></li><li><span><a href="#Улучшение-модели" data-toc-modified-id="Улучшение-модели-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Улучшение модели</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Тестирование-модели" data-toc-modified-id="Тестирование-модели-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Тестирование модели</a></span></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Общий вывод</a></span></li></ul></div>

# %% [markdown]
# # Отток клиентов банка

# %% [markdown]
# Из «Бета-Банка» стали уходить клиенты. Каждый месяц. Немного, но заметно. Банковские маркетологи посчитали: сохранять текущих клиентов дешевле, чем привлекать новых.
#
# Нужно спрогнозировать, уйдёт клиент из банка в ближайшее время или нет. Нам предоставлены исторические данные о поведении клиентов и расторжении договоров с банком.
#
# Построим модель с предельно большим значением *F1*-меры. Нужно довести метрику до 0.59. В конце проверим *F1*-меру на тестовой выборке.
#
# Дополнительно будем измерять *AUC-ROC*, сравнивая её значение с *F1*-мерой.
#
# Источник данных: [https://www.kaggle.com/barelydedicated/bank-customer-churn-modeling](https://www.kaggle.com/barelydedicated/bank-customer-churn-modeling)

# %% [markdown]
# ## Предварительное изучение данных из файла

# %% [markdown]
# Для начала **импортируем библиотеки**, которые будем использовать в ходе исследования:

# %%
# импорт библиотеки pandas
import pandas as pd

# импорт библиотеки pnumpy
import numpy as np

# импорт pyplot из библиотеки matplotlib
import matplotlib.pyplot as plt

# импорт библиотеки seaborn
import seaborn as sns

# импорт метрик из модуля sklearn.metrics
from sklearn.metrics import (accuracy_score,
                             classification_report, 
                             f1_score,
                             roc_curve,
                             roc_auc_score)

# импортируем train_test_split из модуля sklearn.model_selection
from sklearn.model_selection import train_test_split 

# импорт модели дерева решений из модуля sklearn.tree
from sklearn.tree import DecisionTreeClassifier

# импортируем RandomForestClassifier из модуля sklearn.ensemble
from sklearn.ensemble import RandomForestClassifier

# импортируем LogisticRegression  из модуля sklearn.linear_model
from sklearn.linear_model import LogisticRegression

# импорт StandardScaler из библиотеки
from sklearn.preprocessing import StandardScaler

#Импортирем функцию shuffle() из модуля sklearn.utils
from sklearn.utils import shuffle

# %% [markdown]
# **Прочитаем файл** `Churn.csv` из папки `/datasets`.
# Cохраним содержимое в переменной `df`:

# %%
# чтение файла с данными и сохранение в df
df = pd.read_csv('/datasets/Churn.csv')

# %% [markdown]
# Выведем общую информацию о таблице с использованием метода `info()`:

# %%
# вывод общей информации о таблице
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           9091 non-null   float64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(3), int64(8), object(3)
# memory usage: 1.1+ MB

# %% [markdown]
# Всего **10000 объектов** (строк таблицы), **14 признаков** (столбцов). Столбец `RowNumber` можно будет удалить, так как это номер строки.

# %% [markdown]
# Выведем первые 10 строк таблицы:

# %%
# вывод первых строк таблицы
df.head(10)
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
# 5          6    15574012       Chu          645     Spain    Male   44
# 6          7    15592531  Bartlett          822    France    Male   50
# 7          8    15656148    Obinna          376   Germany  Female   29
# 8          9    15792365        He          501    France    Male   44
# 9         10    15592389        H?          684    France    Male   27
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0     2.0       0.00              1          1               1
# ...

# %% [markdown]
# Из **описания данных** известно:
#
# *Признаки*
#
# - `RowNumber` — индекс строки в данных
# - `CustomerId` — уникальный идентификатор клиента
# - `Surname` — фамилия
# - `CreditScore` — кредитный рейтинг
# - `Geography` — страна проживания
# - `Gender` — пол
# - `Age` — возраст
# - `Tenure` — сколько лет человек является клиентом банка
# - `Balance` — баланс на счёте
# - `NumOfProducts` — количество продуктов банка, используемых клиентом
# - `HasCrCard` — наличие кредитной карты
# - `IsActiveMember` — активность клиента
# - `EstimatedSalary` — предполагаемая зарплата
#
# *Целевой признак*
#
# - `Exited` — факт ухода клиента

# %% [markdown]
# Пропущенные значения только в столбце `Tenure`. Ознакомимся с уникальными значениями этого столбца:

# %%
# уникальные значения столбца 'Tenure'
df['Tenure'].unique()
# Out:
# array([ 2.,  1.,  8.,  7.,  4.,  6.,  3., 10.,  5.,  9.,  0., nan])

# %% [markdown]
# Как видно из результата, значение `0` есть среди уникальных значений. Значит пропуск не означает, что клиент пользуется услугами банка меньше года.
#
# Посмотрим есть ли какие-то закономерности в других столбцах для строк с пропущенными значениями в столбце `Tenure`:

# %%
#строки исходного датафрейма с пропущенными значениями в столбце `Tenure`
df[df['Tenure'].isna()==True].head(10)
# Out:
#      RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 30          31    15589475    Azikiwe          591     Spain  Female   39
# 48          49    15766205        Yin          550   Germany    Male   38
# 51          52    15768193  Trevisani          585   Germany    Male   36
# 53          54    15702298   Parkhill          655   Germany    Male   41
# 60          61    15651280     Hunter          742   Germany    Male   35
# 82          83    15641732      Mills          543    France  Female   36
# 85          86    15805254    Ndukaku          652     Spain  Female   75
# 94          95    15676966      Capon          730     Spain    Male   42
# 99         100    15633059    Fanucci          413    France    Male   34
# 111        112    15665790   Rowntree          538   Germany    Male   39
#
#      Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 30      NaN       0.00              3          1               0
# ...

# %% [markdown]
# Из 10 выведенных строк видно, что в столбцах встречаются различные значения, в том числе в количестве продуктов банка, используемых клиентом:

# %%
#строим гистограмму для количества продуктов банка в строках, где имеются пропущенные значения в столбце
(df[df['Tenure'].isna()==True]
 ['NumOfProducts']
 .hist())

#название графика
plt.title('Гистограмма частоты значений `NumOfProducts` для \n строк с пропущенными значениями в столбце `Tenure`', 
          fontsize=16 )

#подписи осей
plt.xlabel('Количество продуктов у клиентов банка', fontsize=16)
plt.ylabel('Частота значений', fontsize=14)

#сетка по оси абсцисс
plt.xticks(np.arange(1, 5,step=1), fontsize=12)

plt.show()

# %%
#уникальные значения в столбце 'NumOfProducts' в строках с пропущенными значениями 'Tenure'
df[df['Tenure'].isna()==True]['NumOfProducts'].unique()
# Out:
# array([3, 1, 2, 4])

# %% [markdown]
# Также в строках с пропущенными значениями в столбце `Tenure` есть как клиенты, которые продолжают пользоваться услугами банка, так и те, кто перестал ими пользоваться:

# %%
#строим гистограмму для количества продуктов банка в строках, где имеются пропущенные значения в столбце
df[df['Tenure'].isna()==True]['Exited'].hist()

#название графика
plt.title('Гистограмма частоты значений `Exited` для \n строк с пропущенными значениями в столбце `Tenure`', fontsize=16 )

#подписи осей
plt.xlabel('Exited', fontsize=16)
plt.ylabel('Частота значений', fontsize=14)

#сетка по оси абсцисс
plt.xticks(np.arange(0, 2,step=1), fontsize=12)

plt.show()

# %% [markdown]
# Следовательно, причина прпоусков в столбце `Tenure` точно неизвестно. Можно удалить строки, можно попытаться восстановить значения. Вернёмся к этому позднее.

# %% [markdown]
# Проверим колличественные признаки на мультиколлинеарность с использованием диаграммы рассеяния:

# %%
#построим матрицу диаграмм рассеяния
(
    sns.pairplot(df[["CreditScore", "Age", "Balance", "EstimatedSalary"]])
    .fig.suptitle("Матрица диаграмм рассеяния - количественные признаки исходного датафрейма",y=1.02)
)

plt.show()

# %% [markdown]
# А также с использованием матрицы корреляции (используем `heatmap` из библиотеки `seaborn`):

# %%
plt.figure(figsize=(8,8))

sns.heatmap(
    df[["CreditScore", "Age", "Balance", "EstimatedSalary"]]
    .corr(),
    annot=True)

#название графика
plt.title('Матрица корреляции для количественных признаков исходного датафрейма', fontsize=16, loc='center')

#задаём размер значений на оси абсцисс и на оси ординат
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

plt.show()

# %% [markdown]
# Мультиколлинеарность между количественными признаками отсутствует, потому что **коэффициент корреляции Пирсона близок к нулю**.

# %% [markdown]
# Последний штрих на стадии предварительного знакомства с данными - посмотрим все ли клиенты уникальны.
#
# Количество строк в столбце `CustomerId`:

# %%
#количество строк в столбце 'CustomerId'
len(df['CustomerId'].unique())
# Out:
# 10000

# %% [markdown]
# Количество уникальных значений в столбце `CustomerId`:

# %%
#выводим количество уникальных значений в столбце `CustomerId`
len(df['CustomerId'])
# Out:
# 10000

# %% [markdown]
# 10000 **уникальных** пользователей.

# %% [markdown]
# ### Вывод

# %% [markdown]
# Для исследования доступны данные о **10000** уникальных клиентов (объектов). В исходном датафрейме доступна информация о 14 признаках, целевым является `Exited` - факт ухода клиента.
#
# Есть пропущенные значения в столбце `Tenure`, причина пропусков неизвестна. Вероятно ошибка при выгрузке данных или отсутствие информации о начале использования клиентом продуктов банка.
#
# Среди признаков есть как бинарные категориальные, так и количественные. Последовательность шагов для стадии подготовки данных определим на следующей стадии проекта.
#
# Предварительно можно сделать вывод, что **данных для ислледования достаточно**.

# %% [markdown]
# ## Подготовка данных

# %% [markdown]
# ### Удаление некоторых столбцов

# %% [markdown]
# Удалим столбец `RowNumber` так как он соответствует номеру строки. Для этой цели у нас есть столбец с индексом, который начинается с нуля.
#
# Также признак "фамилия" (`Surname`) усложнит процесс обучения модели и не приведёт к существенным результатам. Более того, в столбце фамилия много повторяющихся значений.
#
# Столбец `CustomerId` не влияет на результат, он также не понадобится в дальнейшем.
#
# Удалим эти столбца с помощью метода `drop`:

# %%
#удаляем столбец 'RowNumber'
df = df.drop(['RowNumber','Surname','CustomerId'], axis=1)

# %% [markdown]
# ### Изменение названий столбцов

# %% [markdown]
# Названия столбцов отличаются от хорошего стиля:

# %%
#вывод названий столбцов
df.columns
# Out:
# Index(['CreditScore', 'Geography', 'Gender', 'Age', 'Tenure', 'Balance',
#        'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary',
#        'Exited'],
#       dtype='object')

# %% [markdown]
# Изменим названия столбцов вручную, безопасным способом с использованием метода `rename`:

# %%
#изменяем названия столбцов
df = df.rename(columns={'CreditScore': 'credit_score', 
                        'Geography': 'geography', 
                        'Gender': 'gender', 
                        'Age': 'age',
                        'Tenure': 'tenure', 
                        'Balance': 'balance', 
                        'NumOfProducts': 'num_of_products', 
                        'HasCrCard': 'has_cr_card', 
                        'IsActiveMember': 'is_active_member',
                        'EstimatedSalary': 'estimated_salary', 
                        'Exited': 'exited'})

# %% [markdown]
# Проверим результат:

# %%
#выведем названия столбцов после замены
df.columns
# Out:
# Index(['credit_score', 'geography', 'gender', 'age', 'tenure', 'balance',
#        'num_of_products', 'has_cr_card', 'is_active_member',
#        'estimated_salary', 'exited'],
#       dtype='object')

# %% [markdown]
# Изменение названий столбцов прошло успешно.

# %% [markdown]
# ### Пропуски в столбце `tenure`

# %% [markdown]
# Ознакомимся со значениями целевого признака в строках с пропущенными значениями в столбце `tenure`:

# %%
#строим гистограмму
df[df['tenure'].isna()==True]['exited'].hist()

#название графика
plt.title('Гистограмма частоты значений `exited` для \n строк с пропущенными значениями в столбце `tenure`', fontsize=16 )

#подписи осей
plt.xlabel('exited', fontsize=16)
plt.ylabel('Частота значений', fontsize=14)

#сетка по оси абсцисс
plt.xticks(np.arange(0, 2,step=1), fontsize=12)

plt.show()

# %% [markdown]
# Очевидно, что в строках с пропущенными значениями в столбце `tenure` больше отрицательных значений, чем положительных (нулей больше, чем 1).
#
# Посмотрим насколько сбалансированны значения целевого признака в исходоном датафрейме:

# %%
#строим гистограмму
df['exited'].hist()

#название графика
plt.title('Гистограмма частоты значений целевого признака `exited` для \n исходного датафрейма', fontsize=16 )

#подписи осей
plt.xlabel('exited', fontsize=16)
plt.ylabel('Частота значений', fontsize=14)

#сетка по оси абсцисс
plt.xticks(np.arange(0, 2,step=1), fontsize=12)

plt.show()

# %% [markdown]
# Как видно из графика, положительных значений (1) примерно в 4 раза меньше, чем отрицитальных (0).

# %% [markdown]
# Сколько мы потеряем объектов с положительным целевым признаком, если удалим строки с пропусками в `Tenure`:

# %%
#вычисляем долю объектов с положительным целевым признаком и с пропущенным значением в столбце `tenure`
#среди всех объектов с положительным целевым признаком
(
    len(df[(df['tenure'].isna()==True)&(df['exited']==1)]['exited'])
    /len(df[df['exited']==1]['exited'])
)
# Out:
# 0.0898379970544919

# %% [markdown]
# Около **9%** положительных ответов для целевого признака от исходной выборки.

# %% [markdown]
# Посмотрим, можно ли восстановить средний период пользования услугами банка по количеству продуктов клиента:

# %%
#сводная таблица - колиество продуктов у клиента, количество объектов, среднее значение и медиана для `tenure`
(
    df[(df['tenure'].isna()!=True)]
    .pivot_table(index = ['num_of_products'], 
                 values= 'tenure', 
                 aggfunc=(['count','mean','median']))
)
# Out:
#                  count      mean median
#                 tenure    tenure tenure
# num_of_products
# 1                 4617  4.963613    5.0
# 2                 4184  5.032266    5.0
# 3                  234  4.995726    5.0
# 4                   56  5.232143    5.0

# %% [markdown]
# Получается, что клиенты с любым количеством продуктов от 1 до 4 пользуются услугами банка в среднем 5 лет.
#
# Посмотрим какие значения в столбце `tenure` исходного датафрейма:

# %%
#строим гистограмму
df['tenure'].hist()

#название графика
plt.title('Гистограмма частоты значений `tenure` для \n исходного датафрейма', fontsize=16 )

#подписи осей
plt.xlabel('Сколько лет человек является клиентом банка', fontsize=16)
plt.ylabel('Частота значений', fontsize=14)

plt.show()

# %%
#основные характеристики выборки столбца `tenure`
df['tenure'].describe()
# Out:
# count    9091.000000
# mean        4.997690
# std         2.894723
# min         0.000000
# 25%         2.000000
# 50%         5.000000
# 75%         7.000000
# max        10.000000
# Name: tenure, dtype: float64

# %% [markdown]
# Распределение не является нормальным, есть выдающиеся значения около 10 лет. Медиана и среднее близки.
#
# Если мы заполним пропуски медианой, то получим выдающееся значение, как показано на гистограмме ниже:

# %%
#строим гистограмму для 'tenure' с пропусками, заполненными медианой
df['tenure'].fillna(5).hist()

#название графика
plt.title('Гистограмма частоты значений `tenure` для \n исходного датафрейма, где пропуски заполнены `5`', fontsize=14 )

#подписи осей
plt.xlabel('Сколько лет человек является клиентом банка', fontsize=16)
plt.ylabel('Частота значений', fontsize=14)

plt.show()

# %% [markdown]
# Тогда можем попробовать заполнить пропуски равномерно, случайными значениями от 2 до 7, именно в этот интервал укладывается около 50% всех значений исходного датафрейма.
#
# Воспользуемся массивом случайных чисел от 2 до 7:

# %%
#датафрейм случайных чисел от 2 до 7
random_array = (pd.DataFrame(np.random.randint(2,8,size=(len(df[df['tenure'].isna()==True]
                                                             ['tenure']),
                                                         1)), 
                             index=df.loc[df['tenure'].isna()==True].index,
                             columns=['a'])
               )

# %% [markdown]
# Убедимся визуально, что значения в нём распределены примерно равномерно:

# %%
#строим гистограмму значений массива случайных чисел
random_array.hist(bins=6)

plt.title('''Гистограмма частоты случайных значений от 2 до 7''', fontsize=14 )

plt.show()

# %% [markdown]
# Теперь заполним пропуски с использованием метода `fillna`, не будем изменять исходный датафрейм:

# %%
#строим гистограмму для 'tenure' с пропусками, заполненными случайными числами от 2 до 7
df['tenure'].fillna(random_array['a']).hist()

#название графика
plt.title('''Гистограмма частоты значений `tenure` для \n исходного датафрейма, 
где пропуски заполнены случайными числами от 2 до 7''', fontsize=14 )

#подписи осей
plt.xlabel('Сколько лет человек является клиентом банка', fontsize=16)
plt.ylabel('Частота значений', fontsize=14)

plt.show()

# %% [markdown]
# Очевидно, что такой подход тоже привел к искажению исходной выборки, но позволил заполнить пропуски.

# %% [markdown]
# Для дальнейшего рассмотрения, чтобы не ухудшать качество модели, удалим строки с пропусками в столбце `tenure` из рассмотрения:

# %%
#удаляем строки с пропусками в `tenure`
df = df.dropna().reset_index(drop=True)

# %% [markdown]
# Проверяем результат:

# %%
#вывод информации о таблице `df`
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9091 entries, 0 to 9090
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   credit_score      9091 non-null   int64
#  1   geography         9091 non-null   object
#  2   gender            9091 non-null   object
#  3   age               9091 non-null   int64
#  4   tenure            9091 non-null   float64
#  5   balance           9091 non-null   float64
#  6   num_of_products   9091 non-null   int64
#  7   has_cr_card       9091 non-null   int64
#  8   is_active_member  9091 non-null   int64
#  9   estimated_salary  9091 non-null   float64
#  10  exited            9091 non-null   int64
# dtypes: float64(3), int64(6), object(2)
# memory usage: 781.4+ KB

# %% [markdown]
# ### Кодирование категориальных признаков

# %% [markdown]
# Для начала изменим регистр в категориальных столбцах, чтобы затем сохранить хороший стиль заголовков.

# %%
df['gender'] = df.gender.str.lower()

# %%
df['geography'] = df.geography.str.lower()

# %% [markdown]
# Преобразуем категориальные признаки в численные с помощью техники прямого кодирования, или отображения (*англ. One-Hot Encoding, OHE*).
#
# Для прямого кодирования воспользуемся функцией `pd.get_dummies()` библиотеки `pandas`.
#
# Чтобы не попасть в **дамми-ловушку** (ловушку фиктивных признаков) зададим параметр `drop_first=True`:

# %%
# преобразуем категориальные признаки в численные с помощью техники прямого кодирования
df_ohe = pd.get_dummies(df, drop_first=True)

# %% [markdown]
# Категориальными в нашем случае являются признаки `geography` и `gender`, как показывает вывод их уникальных значений:

# %%
#уникальные значения столбца 'geography'
df['geography'].unique()
# Out:
# array(['france', 'spain', 'germany'], dtype=object)

# %%
#уникальные значения столбца 'gender'
df['gender'].unique()
# Out:
# array(['female', 'male'], dtype=object)

# %% [markdown]
# Выведем общую информацию о таблице df до прямого кодирования:

# %%
#вывод общей информации о таблице df до прямого кодирования
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9091 entries, 0 to 9090
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   credit_score      9091 non-null   int64
#  1   geography         9091 non-null   object
#  2   gender            9091 non-null   object
#  3   age               9091 non-null   int64
#  4   tenure            9091 non-null   float64
#  5   balance           9091 non-null   float64
#  6   num_of_products   9091 non-null   int64
#  7   has_cr_card       9091 non-null   int64
#  8   is_active_member  9091 non-null   int64
#  9   estimated_salary  9091 non-null   float64
#  10  exited            9091 non-null   int64
# dtypes: float64(3), int64(6), object(2)
# memory usage: 781.4+ KB

# %% [markdown]
# И после:

# %%
# вывод общей информации о таблице df_ohe
# после прямого кодирования
df_ohe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9091 entries, 0 to 9090
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   credit_score       9091 non-null   int64
#  1   age                9091 non-null   int64
#  2   tenure             9091 non-null   float64
#  3   balance            9091 non-null   float64
#  4   num_of_products    9091 non-null   int64
#  5   has_cr_card        9091 non-null   int64
#  6   is_active_member   9091 non-null   int64
#  7   estimated_salary   9091 non-null   float64
#  8   exited             9091 non-null   int64
#  9   geography_germany  9091 non-null   uint8
#  10  geography_spain    9091 non-null   uint8
#  11  gender_male        9091 non-null   uint8
# dtypes: float64(3), int64(6), uint8(3)
# memory usage: 666.0 KB

# %% [markdown]
# Очевидно, что изменилась размерность датафрейма:

# %%
#размерность df_ohe
df_ohe.shape
# Out:
# (9091, 12)

# %% [markdown]
# Также появилось три новых столбца (`geography_germany`, `geography_spain`, `gender_male`) вместо двух (`geography`,`gender`), которые были ранее.

# %% [markdown]
# Стоит отметить, что `has_cr_card` и `is_active_member` являются бинарными признаками, поэтому не требуют кодирования. Иными словами они однозначно отвечают на вопрос "клиент имеет кредитную карту?", ответ - "да/нет" (`1` или `0`). Или "клиент активен", ответ - "да/нет" (`1` или `0`). В отличие, например, от пола, где было задано "муж/жен".

# %% [markdown]
# ###  Разбивка данных на выборки

# %% [markdown]
# Разобъём исходную выборку на обучающущю, валидационную и тестовую в соотношении (3:1:1):
#
# |Выборка |Процент от количества объектов исходной выборки|
# |:-----|:----:|
# |Обучающая|60%|
# |Валидационная|20%|
# |Тестовая|20%|
#
# Теперь отложим тестовую выборку (20%), в обучающей оставим 80% исходного датасета (чтобы в дальнейшем выделить валидационную).
#
# Используем `train_test_split` из модуля `sklearn.model_selection`. Разбивку произведём псевдослучайным образом, задав параметр `random_state` равным `12345`.
#
# На разбивку передадим **`df_ohe`**:

# %%
# первый шаг разбивки - откладываем тестовую выборку, 
# в обучающей оставляем 80%, чтобы затем из неё
# выделить валидационную
df_train, df_test = train_test_split(df_ohe, 
                                     test_size=0.20, 
                                     random_state=12345)

# %% [markdown]
# Теперь нужно из обучающей выборки выделить валидационную. 20% от 80% это 1/4, или 25% от 100%:

# %%
# Второй шаг разбивки - выделяем из 80% оставшихся процентов обучающую и валидационную выборки.
# В обучающей оставляем 60% из 80%, в валидационной 20% из 80%, то есть 1/4, или 25% из 100%
df_train, df_valid = train_test_split(df_train, 
                                      test_size=0.25, 
                                      random_state=12345)

# %% [markdown]
# Проверим результат разбивки: количество строк в трех получившихся датафреймах в сумме должно быть равно исходному количеству объектов.
#
# Для визуального ознакомления выведем количество объектов и признаков в каждой из выборок:

# %%
#количество объектов и признаков в тестовой выборке
df_test.shape
# Out:
# (1819, 12)

# %%
#количество объектов и признаков в обучающей выборке
df_train.shape
# Out:
# (5454, 12)

# %%
#количество объектов и признаков в валидационной выборке
df_valid.shape
# Out:
# (1818, 12)

# %% [markdown]
# Просуммируем количество объектов в каждой из выборок:

# %%
# суммарное количество объектов в трех выборках
df_test.shape[0]+df_train.shape[0]+df_valid.shape[0]
# Out:
# 9091

# %% [markdown]
# Сопоставим с количеством объектов в исходной выборке:

# %%
#количество объектов в исходной выборке
df.shape[0]
# Out:
# 9091

# %% [markdown]
# Очевидно, что разбивка на выборки выполнена успешно: котрольная сумма сходится.

# %% [markdown]
# ### Тестовый, обучающий и валидационный наборы данных

# %% [markdown]
# Сохраним обучающий, тестовый и валидационный наборы данных в переменных `features` (признаки) и `target` (целевой признак).
#
# Для этого создадим переменные для **признаков и целевого признака**.
#
# Сделаем это с использованием цикла по выборкам.
#
# Массив с названиями выборок:

# %%
#создаём массив с названиями выборок
array = ['test','train','valid']

# %% [markdown]
# **Целевой признак - столбец `exited`**. Соответственно его нужно удалить для признаков в наборах данных всех выборок .
#
# Цикл для выделения признаков, и целевого признака в каждой из выборок:

# %%
#цикл по названию выборки
for name in array:
    
    #признаки для текущей выборки
    locals()['features_'+name] = (locals()['df_'+name]
                                  .drop(['exited'], 
                                        axis=1))
    
    #вывод на экран именени переменной для таблицы признаков текущей выборки и её размерности
    print('features_'+name, 'shape:', 
          locals()['features_'+name].shape)
    
    #целевой признак для текущей выборки
    locals()['target_'+name] = (locals()['df_'+name]
                                ['exited'])
    
    #вывод на экран названия переменной для целевого признака текущей выборки и его размерности
    print('target_'+name, 'shape:',
          locals()['target_'+name].shape)
    
    print()
# Out:
# features_test shape: (1819, 11)
# target_test shape: (1819,)
#
# features_train shape: (5454, 11)
# target_train shape: (5454,)
#
# features_valid shape: (1818, 11)
# target_valid shape: (1818,)

# %% [markdown]
# С помощью цикла мы сохранили **признаки и целевой признак** наборов данных в переменных:
# - `features_test`, `target_test` - для тестовой выборки ,
# - `features_train`, `target_train` - для обучающей выборки,
# - `features_valid`, `target_valid`- для валидационной выборки.
#
# Проверка размерности подтверждает правильность выделения признаков и целевого признака.

# %% [markdown]
# ### Масштабирование численных признаков

# %% [markdown]
# Создадим список всех численных признаков:

# %%
#список численных признаков
numeric = ['credit_score',
           'age', 
           'tenure', 
           'balance',
           'num_of_products',
           'estimated_salary']

# %% [markdown]
# Выполним масштабирование численных признаков - приведём их к одному масштабу, так как они все важны.
#
# Воспользуемся структурой библиотеки `sklearn` для *стандартизации данных* — **`StandardScaler`** (от англ. «преобразователь масштаба методом стандартизации»). Он находится в модуле `sklearn.preprocessing`.

# %% [markdown]
# Создадим объект этой структуры:

# %%
#создаём объект структуры StandardScaler
scaler = StandardScaler()

# %% [markdown]
# И настроим его на обучающих данных. Настройка — это вычисление среднего и дисперсии:

# %%
#настройка объекта на обучающих данных
scaler.fit(features_train[numeric])
# Out:
# StandardScaler()

# %% [markdown]
# Преобразуем обучающую, валидационную и тестовую выборки функцией `transform()`:

# %%
#преобразование обучающей выборки
features_train[numeric] = scaler.transform(features_train[numeric])

#преобразование валидационной выборки
features_valid[numeric] = scaler.transform(features_valid[numeric]) 

#преобразование тестовой выборки
features_test[numeric] = scaler.transform(features_test[numeric])

# %% [markdown]
# Ознакомимся с результатом, выведем первые 5 строк численных признаков `features_train` после масштабирования:

# %%
#вывод первых 5 строк численных признаков после масштабирования
features_train[numeric].head()
# Out:
#       credit_score       age    tenure   balance  num_of_products  \
# 3353     -0.203819  0.471273  0.352316  0.786022         0.782369
# 6176     -0.357513 -0.384930 -1.373506 -1.230577         0.782369
# 4020      0.175290 -0.289797 -0.683177 -1.230577         0.782369
# 535       0.349476  1.708010  0.007151  1.379462        -0.914942
# 1661      0.902771 -0.289797  1.387809 -1.230577        -0.914942
#
#       estimated_salary
# 3353         -0.357205
# 6176         -1.671048
# 4020         -1.119181
# 535          -1.569064
# 1661          1.543790

# %% [markdown]
# И ознакомимся с характеристиками выборки численных признаков поле масштабирования:

# %%
#характеристики выборки численных признаков после масштабирования
features_train[numeric].describe()
# Out:
#        credit_score           age        tenure       balance  \
# count  5.454000e+03  5.454000e+03  5.454000e+03  5.454000e+03
# mean   7.816752e-17 -2.853114e-16 -5.211168e-18 -1.302792e-17
# std    1.000092e+00  1.000092e+00  1.000092e+00  1.000092e+00
# min   -3.062511e+00 -2.002203e+00 -1.718671e+00 -1.230577e+00
# 25%   -6.956374e-01 -6.703313e-01 -1.028342e+00 -1.230577e+00
# 50%    1.135086e-02 -1.946629e-01  7.151372e-03  3.315609e-01
# 75%    6.978467e-01  4.712727e-01  6.974802e-01  8.203222e-01
# max    2.060592e+00  5.037689e+00  1.732974e+00  2.340564e+00
#
#        num_of_products  estimated_salary
# count     5.454000e+03      5.454000e+03
# mean      1.218110e-16      1.823909e-17
# std       1.000092e+00      1.000092e+00
# min      -9.149422e-01     -1.728831e+00
# 25%      -9.149422e-01     -8.496296e-01
# 50%      -9.149422e-01      2.816368e-04
# 75%       7.823689e-01      8.475614e-01
# max       4.176991e+00      1.739503e+00

# %% [markdown]
# Очевидно, что в результате масштабирования у численных признаков одинаковое стандартное отклонение.

# %% [markdown]
# ### Вывод

# %% [markdown]
# Выполнена подготовка датафрейма к дальнейшему исследованию, в частности, удалены некоторые столбцы, удалены строки с пропущенными значениями в столбце `tenure`.
#
# Выборка разбита на обучающий, валидационный и тестовый наборы данных.
#
# Выполнено **кодирование** категориальных и **масштабирование** численных признаков.
#
# Переходим к исследованию задачи.

# %% [markdown]
# ## Исследование задачи

# %% [markdown]
# ### Сбалансированность выборки

# %% [markdown]
# Ранее мы уже приводили данные о распределении значений целевого признака. Продублируем гистограмму для исходного датафрейма ещё раз:

# %%
#строим гистограмму
df['exited'].hist(bins=2)

#название графика
plt.title('Гистограмма частоты значений целевого признака `exited` для \n исходного датафрейма', fontsize=16 )

#подписи осей
plt.xlabel('exited', fontsize=16)
plt.ylabel('Частота значений', fontsize=14)

#сетка по оси абсцисс
plt.xticks(np.arange(0, 2,step=1), fontsize=12)

plt.show()

# %% [markdown]
# В данном случае мы имеем дело с дисбалансом классов. После удаления строк с пропущенными значениями в столбце `tenure` мы имеем количество отрицательных значений целевого признака:

# %%
#количество отрицательных значений целевого признака
len(df[df['exited']==0])
# Out:
# 7237

# %% [markdown]
# Количество положительных значений целевого признака:

# %%
#Количество положительных значений целевого признака
len(df[df['exited']==1])
# Out:
# 1854

# %% [markdown]
# Отношение положительных значений к отрицательным:

# %%
#отношение положительных значений к отрицательным:
(
    len(df[df['exited']==1])/
    len(df[df['exited']==0])
)
# Out:
# 0.2561835014508774

# %% [markdown]
# Положительных значений примерно в 4 раза больше чем отрицательных. Такая же пропорция характерина для обучающего, валидационного и тестового наборов данных.

# %% [markdown]
# ### Модель логистической регрессии без учета дисбаланса

# %% [markdown]
# Создадим модель логистической регрессии, не учитывающую дисбаланс классов:

# %%
#модель логичтиеской регрессии
model_lr_db = LogisticRegression(random_state=12345, 
                                 solver='liblinear')

# %% [markdown]
# Обучим модель на обучающей выборке:

# %%
#обучение модели на тренировочной выборке
model_lr_db.fit(features_train, target_train)
# Out:
# LogisticRegression(random_state=12345, solver='liblinear')

# %% [markdown]
# Найдём предсказания на валидационной выборке:

# %%
#предсказания модели логистической регрессии на валидационной выборке
predicted_valid_lr_db = model_lr_db.predict(features_valid)

# %% [markdown]
# Вычислим правильность:

# %%
#вычисление правильности
accuracy_valid_lr_db = accuracy_score(target_valid,
                                       predicted_valid_lr_db)

accuracy_valid_lr_db
# Out:
# 0.812981298129813

# %% [markdown]
# Также посмотрим f1-меру:

# %%
f1_lr_db = f1_score(target_valid, 
                    predicted_valid_lr_db)

# %%
print("F1:", f1_lr_db)
# Out:
# F1: 0.3004115226337448

# %% [markdown]
# Значение f1-меры для логистической регрессии без учета дисбаланса низкое, около **0.3**. В тоже время правильность составляет около 0.813, что говорит о недостаточности этой метрики.

# %% [markdown]
# Дополнительно посчитаем метрику **AUC-ROC**, Чтобы выявить, как сильно наша модель отличается от случайной. *AUC-ROC* случайной модели равна 0.5.

# %% [markdown]
# Вычисляем вероятность классов с помощью вероятность классов вычисляет функция `predict_proba()`:

# %%
#вычисляем вероятность классов
proba_valid_lr_db = model_lr_db.predict_proba(features_valid)

# %% [markdown]
# Вероятность положительного класса:

# %%
#вероятность положиетльного класса
proba_one_valid_lr_db = proba_valid_lr_db[:, 1]

# %% [markdown]
# Запишем функцию для вычисления вероятности положиетльного класса на валидационной выборке, она пригодится нам в дальнейшем:

# %%
#функция для вычисления вероятности положиетльного класса
#различных моделей
def proba_one_valid(model):
    proba_valid = model.predict_proba(features_valid)
    proba_one_valid = proba_valid[:, 1]
    return proba_one_valid

# %% [markdown]
# Получаем данные для построения ROC-кривой:

# %%
#данные для построения ROC-кривой
fpr_lr_db, tpr_lr_db, thresholds_lr_db = roc_curve(target_valid, 
                                                   proba_one_valid_lr_db)

# %% [markdown]
# Строим ROC-кривую:

# %%
plt.figure()

plt.plot(fpr_lr_db, tpr_lr_db)

# ROC-кривая случайной модели (выглядит как прямая)
plt.plot([0, 1], [0, 1], linestyle='--')

#plt.xlim() и plt.ylim(), чтобы
#   установить границы осей от 0 до 1 >
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])

#plt.xlabel() и plt.ylabel(), чтобы
#подписать оси "False Positive Rate" и "True Positive Rate" >
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')

#отображение сетки
plt.grid()

#заголовок "ROC-кривая" функцией plt.title() >
plt.title('ROC-кривая, логистическая регрессия без учета дисбаланса')
plt.show()

# %% [markdown]
# Вычисляем метрику AUC-ROC:

# %%
#вычисление AUC-ROC модели логистической регрессии
#без учета дисбаланса
roc_auc_lr_db = roc_auc_score(target_valid,proba_one_valid_lr_db)

roc_auc_lr_db
# Out:
# 0.772597434855259

# %% [markdown]
# Метрика AUC-ROC позволяет увидеть, что модель логитической регрессии работает лучше, чем случайная модель. Но  по f1-мере видно, что требуется дальнейшее улучшение.

# %% [markdown]
# ### Модель решающего дерева без учета дисбаланса

# %% [markdown]
# Рассмотрим модель решающего дерева без учета дисбаланса классов:

# %%
#зададим модель решающего дерева без учета дисбаланса классов
model_dtc_db = DecisionTreeClassifier(random_state=12345)

# %% [markdown]
# Обучим модель решающего дерева на обучающей выборке:

# %%
#обучаем модель
model_dtc_db.fit(features_train, target_train)
# Out:
# DecisionTreeClassifier(random_state=12345)

# %% [markdown]
# Найдём предсказания на валидационной выборке:

# %%
# получим предсказания модели на валидационной выборке
predicted_valid_dtc_db  = model_dtc_db.predict(features_valid)

# %% [markdown]
# Вычислим правильность модели:

# %%
#вычисление правильности
accuracy_valid_dtc_db = accuracy_score(target_valid,
                                       predicted_valid_dtc_db)

# %% [markdown]
# Выведем её на экран:

# %%
#вывод правильности на экран
accuracy_valid_dtc_db
# Out:
# 0.7937293729372937

# %% [markdown]
# Вычислим f1-меру для модели решающего дерева без учета дисбаланса классов:

# %%
f1_dtc_db = f1_score(target_valid, 
                     predicted_valid_dtc_db)

# %%
print("F1:", f1_dtc_db)
# Out:
# F1: 0.4939271255060729

# %% [markdown]
# Без учета дисбаланса классов *модель решающего дерева* позволяет получить значение f1-меры равное **0.4939**. Правильность ниже в сравнении с логистической регрессией, но выше f1-мера.

# %% [markdown]
# Вычисляем вероятность положительного класса с использованием ранее введённой функции:

# %%
#вероятность положительного класса для модели решающего дерева
#без учета дисбаланса классов
proba_one_valid_dtc_db = proba_one_valid(model_dtc_db)

# %% [markdown]
# Вычисляем значение AUC-ROC:

# %%
#вычисление AUC-ROC модели решающего дерева
#без учета дисбаланса
roc_auc_dtc_db = roc_auc_score(target_valid,proba_one_valid_dtc_db)

roc_auc_dtc_db
# Out:
# 0.6838842975206612

# %% [markdown]
# Сохраним параметры для построения ROC-кривой:

# %%
#данные для построения ROC-кривой
#модели решающего дерева без учета дисбаланса
fpr_dtc_db, tpr_dtc_db, thresholds_dtc_db = roc_curve(target_valid, 
                                                      proba_one_valid_dtc_db)

# %% [markdown]
# Метрика AUC-ROC решающего дерева **хуже** чем для логистической регрессии.

# %% [markdown]
# ### Модель случайного леса без учета дисбаланса классов

# %% [markdown]
# Рассмотрим модель случайного леса без учета дисбаланса классов:

# %%
#модель случайного леса без учета дисбаланса классов
model_rfc_db = RandomForestClassifier(random_state=12345)

# %% [markdown]
# Обучим модель:

# %%
# обучим модель на тренировочной выборке
model_rfc_db.fit(features_train,target_train)
# Out:
# RandomForestClassifier(random_state=12345)

# %% [markdown]
# Найдём предсказания на валидационной выборке:

# %%
#находим предсказания на валидационной выборке
predicted_valid_rfc_db = model_rfc_db.predict(features_valid)

# %% [markdown]
# Вычисляем f1-меру:

# %%
f1_rfc_db = f1_score(target_valid, 
                     predicted_valid_rfc_db)

# %%
print("F1:", f1_rfc_db)
# Out:
# F1: 0.5507745266781411

# %% [markdown]
# **Случайный лес** пока что показывает *наилучший результат* f1-меры среди трех рассмотренных моделей без учета дисбаланса классов. Но целевое значение f1-меры равное **0.59 не достигнуто**.

# %% [markdown]
# Вычисляем вероятность положительного класса с использованием ранее введённой функции:

# %%
#вероятность положительного класса для модели решающего дерева
#без учета дисбаланса классов
proba_one_valid_rfc_db = proba_one_valid(model_rfc_db)

# %% [markdown]
# Вычисляем значение AUC-ROC:

# %%
#вычисление AUC-ROC модели решающего дерева
#без учета дисбаланса
roc_auc_rfc_db = roc_auc_score(target_valid,
                               proba_one_valid_rfc_db)

roc_auc_rfc_db
# Out:
# 0.8329551099670325

# %% [markdown]
# Сохраним параметры для построения ROC-кривой:

# %%
#данные для построения ROC-кривой
#модели решающего дерева без учета дисбаланса
fpr_rfc_db, tpr_rfc_db, thresholds_rfc_db = roc_curve(target_valid, 
                                                      proba_one_valid_rfc_db)

# %% [markdown]
# ### Построение ROC-кривой трех моделей (без учета дисбаланса)

# %% [markdown]
# Зададим массив моделей:

# %%
array_models = ['lr','dtc', 'rfc']

# %% [markdown]
# Построим ROC-кривые трех рассмотренных моделей с использованием цикла:

# %%
plt.figure()

for name in array_models:
    plt.plot(locals()['fpr_'+name+'_db'], 
             locals()['tpr_'+name+'_db'],
             label=name+'_db')

# ROC-кривая случайной модели (выглядит как прямая)
plt.plot([0, 1], [0, 1], linestyle='--')

#plt.xlim() и plt.ylim(), чтобы
#   установить границы осей от 0 до 1 >
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])

#plt.xlabel() и plt.ylabel(), чтобы
#подписать оси "False Positive Rate" и "True Positive Rate" >
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')

#отображение сетки
plt.grid()

#заголовок "ROC-кривая" функцией plt.title() >
plt.title('ROC-кривая моделей без учета дисбаланса')

plt.legend(fontsize=14)

plt.show()

# %% [markdown]
# Для наглядности составим сводную таблицу метрик качества моделей:

# %%
#делаем сводную таблицу
result_table_db = pd.DataFrame({'f1-score':[f1_lr_db,
                                            f1_dtc_db,
                                            f1_rfc_db],
                                'AUC-ROC':[roc_auc_lr_db,
                                           roc_auc_dtc_db,
                                           roc_auc_rfc_db]},
                               index=['LogisticRegression (LR)',
                                      'DecisionTreeClassifier (DTC)',
                                      'RandomForestClassifier (RFC)'])
#выводим на экран
result_table_db
# Out:
#                               f1-score   AUC-ROC
# LogisticRegression (LR)       0.300412  0.772597
# DecisionTreeClassifier (DTC)  0.493927  0.683884
# RandomForestClassifier (RFC)  0.550775  0.832955

# %% [markdown]
# Получается, что по f1-мере и AUC-ROC лидирует модель **случайного леса**.

# %% [markdown]
# ### Проверка адекватности модели

# %% [markdown]
# Создим константную модель: любому объекту она прогнозирует класс «`0`».
#
# Сохраним её предсказания в переменной `target_pred_constant`:

# %%
#предсказания константной модели для размерности целевого признака валидационной выборки
target_pred_constant = pd.Series([0]*len(target_valid))

# %% [markdown]
# Выведем на экран значение `accuracy` константной модели:

# %%
#правильность константной модели для валидационной выборки
accuracy_score(target_valid, target_pred_constant)
# Out:
# 0.7986798679867987

# %% [markdown]
# Получается, что константная модель предсказывает лучше, чем решающее дерево без учета баланса классов?
# Чтобы ответить на этот вопрос, рассмотрим другие метрики классификации:
# - точность,
# - полноту,
# - f1-меру.
#
# Для просмотра сразу трех этих метрик воспользуемся `classification_report`.
#
# Итак, `classification_report` для **константной** модели:

# %%
print(classification_report(target_valid, 
                            target_pred_constant,
                            target_names=["No", "Churn"]))
# Out:
#               precision    recall  f1-score   support
#
#           No       0.80      1.00      0.89      1452
#        Churn       0.00      0.00      0.00       366
#
#     accuracy                           0.80      1818
#    macro avg       0.40      0.50      0.44      1818
# weighted avg       0.64      0.80      0.71      1818
# /opt/conda/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %% [markdown]
# `classification_report` для предварительной модели решающего дерева (без учета дисбаланса классов):

# %%
print(classification_report(target_valid, 
                            predicted_valid_dtc_db,
                            target_names=["No", "Churn"]))
# Out:
#               precision    recall  f1-score   support
#
#           No       0.87      0.87      0.87      1452
#        Churn       0.49      0.50      0.49       366
#
#     accuracy                           0.79      1818
#    macro avg       0.68      0.68      0.68      1818
# weighted avg       0.80      0.79      0.79      1818

# %% [markdown]
# `classification_report` позволяет видеть расчет точности, полноты и f1-меры для положительного и отрицательного классов. Нас инетересует в первую очередь способность модели предсказывать положительный класс. Дополнительные метрики позволяют увидеть, что константная модель **не умеет** предсказывать положительный класс, для которого точность, полнота и f1-мера равны нулю.
#
# Введённые метрики позволяют увидеть, что f1-мера для предварительной модели решающего дерева равна **0.49**. Получается, что модель умеет предсказывать положительный класс лучше чем логистическая регрессия, но над качеством ещё предстоит поработать.
#
# В дальнейшем также будем использовать функцию `f1_score` для вычисления f1-меры положительного класса:

# %%
#вычисление f1-меры для положительного класса
f1_score(target_valid,
         predicted_valid_dtc_db)
# Out:
# 0.4939271255060729

# %% [markdown]
# ### Вывод

# %% [markdown]
# В данном проекте мы имеем дело с несбалансированной выборкой.
#
# Без учета дисбаланса качество моделей логистической регрессии, решающего дерева и случайного леса требует улучшения, так как f1-мера для положительного класса **менее целевых 0.59**.
#
# В дальнейшем разберем возможные варианты борьбы с дисбалансом, а также рассмотрим несколько моделей, чтобы выбрать лучшую и провести контроль качества на тестовой выборке.

# %% [markdown]
# ## Борьба с дисбалансом

# %% [markdown]
# ### Взвешивание классов

# %% [markdown]
# Придадим объектам редкого класса больший вес. Модели проще запоминать объекты бóльшей значимости.

# %% [markdown]
# Алгоритмы машинного обучения считают все объекты обучающей выборки равнозначными по умолчанию. Если важно указать, что какие-то объекты важнее, их классу присваивается вес.

# %% [markdown]
# В алгоритме логистической регрессии в библиотеке `sklearn` есть аргумент `class_weight`. По умолчанию он равен `None`, т. е. классы равнозначны:
# - `вес класса «0» = 1.0`,
# - `вес класса «1» = 1.0`.

# %% [markdown]
# Если указать `class_weight='balanced'` (англ. «сбалансированный»), алгоритм посчитает, во сколько раз класс «`0`» встречается чаще класса «`1`».
#
# Бóльший вес будет у редкого класса.
#
# Аргумент `class_weight` также есть у решающего дерева и случайного леса.

# %% [markdown]
# #### Взвешивание классов для логистической регрессии

# %% [markdown]
# Укажем `class_weight='balanced'` для модели логистической регрессии:

# %%
#модель логистической регресии с взвешиванием классов
model_lr_cwb = LogisticRegression(random_state=12345, 
                                 solver='liblinear',
                                 class_weight='balanced')

# %% [markdown]
# Обучим модель на тренировочной выборке:

# %%
#обучение модели, тренировочная (обучающая) выборка
model_lr_cwb.fit(features_train, target_train)
# Out:
# LogisticRegression(class_weight='balanced', random_state=12345,
#                    solver='liblinear')

# %% [markdown]
# Предсказываем:

# %%
#предсказания модели логистической регрессии с 
#взвешиванием классов
predicted_valid_lr_cwb = model_lr_cwb.predict(features_valid)

# %% [markdown]
# Находим наиболее важную мерику - f1-меру:

# %%
f1_lr_cwb = f1_score(target_valid, 
                     predicted_valid_lr_cwb)

# %%
#вычисляем f1-меру для модели логистической регрессии
#с взвешиванием классов
print("F1:", f1_lr_cwb)
# Out:
# F1: 0.49506903353057197

# %% [markdown]
# Благодаря взвешиванию классов f1-мера увеличилась с **0.3** до **0.495**.
#
# Посмотрим как взвешивание отразиться на результатах решающего дерева.

# %% [markdown]
# #### Взвешивание классов для решающего дерева

# %% [markdown]
# Зададим модель решующего дерева с взвешиванием классов:

# %%
#зададим модель решающего дерева с взвешиванием классов
model_dtc_cwb = DecisionTreeClassifier(random_state=12345,
                                       class_weight='balanced')

# %% [markdown]
# Обучим модель:

# %%
#обучаем модель
model_dtc_cwb.fit(features_train, target_train)
# Out:
# DecisionTreeClassifier(class_weight='balanced', random_state=12345)

# %% [markdown]
# Найдём предсказания:

# %%
# получим предсказания модели на валидационной выборке
predicted_valid_dtc_cwb  = model_dtc_cwb.predict(features_valid)

# %% [markdown]
# Вычислим f1-меру:

# %%
#вычисление f1-меры для положительного класса
f1_dtc_cwb = f1_score(target_valid,
                      predicted_valid_dtc_cwb)

f1_dtc_cwb
# Out:
# 0.4855172413793103

# %% [markdown]
# Интересный результат: взвешивание классов в модели решающего дерева привело к **уменьшению f1-меры**.

# %% [markdown]
# #### Взвешивание классов для модели случайного леса

# %% [markdown]
# Рассмотрим модель случайного леса с взвешиванием классов:

# %%
#модель случайного леса без учета дисбаланса классов
model_rfc_cwb = RandomForestClassifier(random_state=12345, 
                                       class_weight='balanced')

# %% [markdown]
# Обучим модель:

# %%
# обучим модель на тренировочной выборке
model_rfc_cwb.fit(features_train,target_train)
# Out:
# RandomForestClassifier(class_weight='balanced', random_state=12345)

# %% [markdown]
# Найдём предсказания на валидационной выборке:

# %%
#находим предсказания на валидационной выборке
predicted_valid_rfc_cwb = model_rfc_cwb.predict(features_valid)

# %% [markdown]
# Вычисляем f1-меру:

# %%
f1_rfc_cwb = f1_score(target_valid, 
                      predicted_valid_rfc_cwb)

# %%
print("F1:", f1_rfc_cwb)
# Out:
# F1: 0.5309734513274336

# %% [markdown]
# Результат похож на предыдущий вариант: f1-мера для модели **случайного леса** *снижается после взвешивания классов*.

# %% [markdown]
# #### Построение ROC-кривой и вычисление AUC-ROC

# %% [markdown]
# С помощью цикла расчитаем *вероятность положительного класса, AUC-ROC и параметры для построения ROC-кривой* для трех моделей с взвешиванием классов:

# %%
for name in array_models:
    #вычисление вероятности положительного класса с помощью ранее введённой функции
    locals()['proba_one_valid_'+name+'_cwb'] = proba_one_valid(locals()['model_'+name+'_cwb'])
    
    #вычисление AUC-ROC модели
    locals()['roc_auc_'+name+'_cwb'] = roc_auc_score(target_valid,locals()['proba_one_valid_'+name+'_cwb'])
    
    print('AUC-ROC for model '+'\033[1m'+name+'\033[0m'+' with cwb:', locals()['roc_auc_'+name+'_cwb'])

    #данные для построения ROC-кривой
    (locals()['fpr_'+name+'_cwb'], 
    locals()['tpr_'+name+'_cwb'], 
    locals()['thresholds_'+name+'_cwb']) = roc_curve(target_valid, locals()['proba_one_valid_'+name+'_cwb'])
# Out:
# AUC-ROC for model lr with cwb: 0.7747783347634317
# AUC-ROC for model dtc with cwb: 0.6774206295443256
# AUC-ROC for model rfc with cwb: 0.838822276415421

# %% [markdown]
# С использованием цикла построим ROC-кривые для 3 рассмотренных моделей:

# %%
plt.figure()

for name in array_models:
    plt.plot(locals()['fpr_'+name+'_cwb'], 
             locals()['tpr_'+name+'_cwb'],
             label=name+'_cwb')

# ROC-кривая случайной модели (выглядит как прямая)
plt.plot([0, 1], [0, 1], linestyle='--')

#plt.xlim() и plt.ylim(), чтобы
#   установить границы осей от 0 до 1 >
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])

#plt.xlabel() и plt.ylabel(), чтобы
#подписать оси "False Positive Rate" и "True Positive Rate" >
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')

#отображение сетки
plt.grid()

#заголовок "ROC-кривая" функцией plt.title() >
plt.title('ROC-кривая моделей с взвешиванием классов')

plt.legend(fontsize=14)

plt.show()

# %% [markdown]
# Сделаем сводную таблицу с результатами:

# %%
#делаем сводную таблицу
result_table_cwb = pd.DataFrame({'f1-score_db':[f1_lr_db,
                                            f1_dtc_db,
                                            f1_rfc_db],
                                 'f1-score_cwb':[f1_lr_cwb,
                                            f1_dtc_cwb,
                                            f1_rfc_cwb],
                                'AUC-ROC_db':[roc_auc_lr_db,
                                           roc_auc_dtc_db,
                                           roc_auc_rfc_db],
                                'AUC-ROC_cwb':[roc_auc_lr_cwb,
                                           roc_auc_dtc_cwb,
                                           roc_auc_rfc_cwb]},
                                
                               index=['LogisticRegression (LR)',
                                      'DecisionTreeClassifier (DTC)',
                                      'RandomForestClassifier (RFC)'])
#выводим на экран
result_table_cwb
# Out:
#                               f1-score_db  f1-score_cwb  AUC-ROC_db  \
# LogisticRegression (LR)          0.300412      0.495069    0.772597
# DecisionTreeClassifier (DTC)     0.493927      0.485517    0.683884
# RandomForestClassifier (RFC)     0.550775      0.530973    0.832955
#
#                               AUC-ROC_cwb
# LogisticRegression (LR)          0.774778
# DecisionTreeClassifier (DTC)     0.677421
# RandomForestClassifier (RFC)     0.838822

# %% [markdown]
# Из сводной таблицы видно, что взвешивание классов положительно сказалось **только на логистической регрессии**.
#
# В случае решающего дерева и случайного леса качество моделей ухудшилось, о чем свидетельствует **снижение f1-меры**.
#
# Но **для случайного леса** значение `AUC-ROC` **увеличилось** и по этому показателю данная модель занимает лидирующие позиции.
#
# По значению f1-меры лучшая модель с взвешиванием классов - логистическая регрессия.

# %% [markdown]
# ### Увеличение выборки

# %% [markdown]
# Используем технику **upsampling** для увеличения выборки, для этого нужно:
#
# - Разделить обучающую выборку на отрицательные и положительные объекты;
# - Скопировать несколько раз положительные объекты;
# - С учётом полученных данных создать новую обучающую выборку;
# - Перемешать данные: идущие друг за другом одинаковые вопросы не помогут обучению.
#
# Скопировать объекты несколько раз поможет синтаксис умножения списков в Python. Чтобы повторить элементы списка, он умножается на число (нужное количество раз).

# %% [markdown]
# Создим функцию `upsample()` с тремя параметрами:
# - `features` — признаки,
# - `target` — целевой признак,
# - `repeat` — количество повторений.
#
# Функция вернёт *признаки и целевой признак* после операции `upsampling`.

# %%
def upsample(features, target, repeat):
    
    #Объявим четыре переменные и запишем в них:
    
    #признаки объектов с ответом «0»
    features_zeros = features[target == 0]
    
    #признаки объектов с ответом «1»
    features_ones = features[target == 1]
    
    #целевой признак объектов, у которых ответы только «0»
    target_zeros = target[target == 0]
    
    #целевой признак объектов, у которых ответы только «1».
    target_ones = target[target == 1]

    #Продублируем объекты положительного класса и 
    #объединим их с объектами отрицательного класса
    features_upsampled = pd.concat([features_zeros] + [features_ones] * repeat)
    #то же самое для целевого признака 
    target_upsampled = pd.concat([target_zeros] + [target_ones] * repeat)
    
    #перемешаем данные
    features_upsampled, target_upsampled = shuffle(
        features_upsampled, target_upsampled, random_state=12345)
    
    #Функция вернёт признаки и целевой признак после операции upsampling
    return features_upsampled, target_upsampled

# %% [markdown]
# Вызовим функцию для обучающих данных.
# Если всё верно, размеры преобразованных выборок появятся на экране.

# %%
features_upsampled, target_upsampled = upsample(features_train, target_train, 5)

print(features_upsampled.shape)
print(target_upsampled.shape)
# Out:
# (9930, 11)
# (9930,)

# %% [markdown]
# Для теста мы задали повторение 5 раз. Поулчаем, что функция работает.
#
# Но от количества повторений будет зависеть сбалансированность выборки, а значит качество обучения модели.
#
# Например, среднее в целевом признаке после 5 кратного повторения положительного класса:

# %%
#среднее в целевом признаке после увеличения выборки
target_upsampled.mean()
# Out:
# 0.5634441087613293

# %% [markdown]
# Изначальное среднее в целевом признаке:

# %%
#среднее в целевом признаке до увеличения выборки
target_train.mean()
# Out:
# 0.20517051705170516

# %% [markdown]
# Для каждой из моделей проварьируем количество повторений и определим при каком значении f1-мера имеет наибольшее значение.

# %% [markdown]
# #### Модель логистической регрессии для увеличенной выборки

# %% [markdown]
# Для дальнейшего исследования создадим функцию, которую сможем применить для трех рассматриваемых далее моделей.
#
# Последовательность работы функции объясняется в комментариях к коду:

# %%
def model_ups_research(name,model_type,max_repeat):
    f1_ups_array = []
    roc_auc_ups_array = []
    result_repeat = []
    best_model = 0
    best_f1 = 0
    best_repeat = 0
    
    #перебираем в цикле количетсво повторений
    for num in range(1,max_repeat+1):
        
        #увеличиваем размер выборки повторением положиетльного класса
        features_upsampled, target_upsampled = upsample(features_train, target_train, num)
        
        #выбираем модель
        model_ups = model_type
        
        #обучаем модель на увеличенной тренировочной выборке
        model_ups.fit(features_upsampled, target_upsampled)
        
        #предсказываем на валидационной
        predicted_valid_ups = model_ups.predict(features_valid)
        
        #вычисляем f1-меру
        f1_ups = f1_score(target_valid, predicted_valid_ups)
        
        #добавляем рассчитаное значение в массив
        f1_ups_array.append(f1_ups)
        
        #вероятность положительного класса
        proba_one_valid_ups = proba_one_valid(model_ups)
        
        #вычисление AUC-ROC модели
        roc_auc_ups = roc_auc_score(target_valid, proba_one_valid_ups)
        
        #добавляем вычисленное значение AUC-ROC
        roc_auc_ups_array.append(roc_auc_ups)
        
        #массив повторений
        result_repeat.append(num)
        
        #ищем лучшую модель
        if f1_ups>best_f1:
            best_f1 = f1_ups
            best_model = model_ups
            best_repeat = num
    
    #датафрейм для исследования результатов
    result_repeat_table = pd.DataFrame({'repeat':np.array(result_repeat),
                                        'f1_'+name+'_ups':np.array(f1_ups_array),
                                        'roc_auc_'+name+'_ups':np.array(roc_auc_ups_array)})
    
    #возвращаем - лучший результат f1, лучшую модель, датафрейм с результатами
    return best_f1, best_model, best_repeat, result_repeat_table

# %% [markdown]
# Теперь применим функцию для логистической регрессии:

# %%
#применяем функцию для логистической регресии
(best_f1_lr_ups, 
 best_model_lr_ups,
 best_lr_repeat,
 result_repeat_lr) = model_ups_research('lr',
                                        LogisticRegression(random_state=12345, solver='liblinear'),
                                        14)

# %% [markdown]
# Построим график с результатами. Для построения графика создадим функцию, чтобы сделать в дальнейшем код нагляднее:

# %%
#функция для построения графика
def plt_result_repeat(repeat,
                      score,
                      line_type,
                      x_name,
                      y_name,
                      graph_name):
    #размер графика
    plt.figure(figsize=(15,8))
    
    #строим график
    plt.plot(repeat,
             score,
             line_type)
    
    #название графика
    plt.title(graph_name, fontsize=16)
    
    #подписи осей
    plt.xlabel(x_name, fontsize=16)
    plt.ylabel(y_name, fontsize=16)
    
    #отображение сетки
    plt.grid()
    
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)

# %% [markdown]
# Строим график с использованием функции:

# %%
plt_result_repeat(result_repeat_lr['repeat'],
                  result_repeat_lr['f1_lr_ups'],
                  'o-',
                  'Количество повторений',
                  'F1-мера',
                  'Зависимость F1-меры от количества повторений для модели \n логистической регрессии с увеличенной выборкой')

plt.show()

# %% [markdown]
# Из графика видно, что с увеличением количества повторения в модели логистической регрессии f1-мера сначала растет, затем снижается (после 4).

# %%
plt_result_repeat(result_repeat_lr['repeat'],
                  result_repeat_lr['roc_auc_lr_ups'],
                  'o-',
                  'AUC-ROC',
                  'Количество повторений',
                  'Зависимость AUC-ROC от количества повторений для модели \n логистической регрессии с увеличенной выборкой')

plt.show()

# %% [markdown]
# В таком масштабе может показаться, что AUC-ROC существенно зависит от количества повторений, но если изменить масштаб:

# %%
plt_result_repeat(result_repeat_lr['repeat'],
                  result_repeat_lr['roc_auc_lr_ups'],
                  'o-',
                  'AUC-ROC',
                  'Количество повторений',
                  'Зависимость AUC-ROC от количества повторений для модели \n логистической регрессии с увеличенной выборкой')

#   установить границы y от 0 до 1 >
plt.ylim([0.0, 1.0])

plt.show()

# %% [markdown]
# Очевидно, что AUC-ROC практически не зависит от количества повторений.

# %% [markdown]
# Итак, наибольшее значение f1-меры для модели логистической регрессии:

# %%
best_f1_lr_ups
# Out:
# 0.4959254947613504

# %% [markdown]
# Это соответствует количеству повторений при увеличении выборки:

# %%
best_lr_repeat
# Out:
# 3

# %% [markdown]
# #### Модель решающего дерева

# %% [markdown]
# Применим функцию для модели решающего дерева:

# %%
#применяем функцию для решающего дерева
(best_f1_dtc_ups, 
 best_model_dtc_ups,
 best_dtc_repeat,
 result_repeat_dtc) = model_ups_research('dtc',
                                         DecisionTreeClassifier(random_state=12345),
                                         19)

# %% [markdown]
# Строим график с использованием функции:

# %%
plt_result_repeat(result_repeat_dtc['repeat'],
                  result_repeat_dtc['f1_dtc_ups'],
                  'o-',
                  'Количество повторений',
                  'F1-мера',
                  'Зависимость F1-меры от количества повторений для модели \n решающего дерева с увеличенной обучающей выборкой')

plt.show()

# %% [markdown]
# Если изменить масштаб, то можно увидеть, что f1-мера рашающего дерева менее чувствительна к количеству повторений уведиченной выборки: увеличение примерно на **0,06**.

# %%
plt_result_repeat(result_repeat_dtc['repeat'],
                  result_repeat_dtc['f1_dtc_ups'],
                  'o-',
                  'Количество повторений',
                  'F1-мера',
                  'Зависимость F1-меры от количества повторений для модели \n решающего дерева с увеличенной обучающей выборкой')

#   установить границы y от 0 до 1 >
plt.ylim([0.0, 1.0])

plt.show()

# %% [markdown]
# AUC-ROC как и в случае логистической регрессии слабо зависит от количества повторений:

# %%
plt_result_repeat(result_repeat_dtc['repeat'],
                  result_repeat_dtc['roc_auc_dtc_ups'],
                  'o-',
                  'Количество повторений',
                  'AUC-ROC',
                  'Зависимость AUC-ROC от количества повторений для модели \n решающего дерева с увеличенной обучающей выборкой')

#   установить границы y от 0 до 1 >
plt.ylim([0.0, 1.0])

plt.show()

# %% [markdown]
# Итак, лучшее значение f1-меры для модели решающего дерева с увеличенной выборкой:

# %%
best_f1_dtc_ups
# Out:
# 0.5006993006993006

# %% [markdown]
# Это соответствует количеству повторений при увеличении выборки:

# %%
best_dtc_repeat
# Out:
# 5

# %% [markdown]
# #### Модель случайного леса

# %% [markdown]
# Используем функцию для модели случайного леса:

# %%
#применяем функцию для решающего дерева
(best_f1_rfc_ups, 
 best_model_rfc_ups,
 best_rfc_repeat,
 result_repeat_rfc) = model_ups_research('rfc',
                                         RandomForestClassifier(random_state=12345),
                                         19)

# %% [markdown]
# Построим график с использованием функции:

# %%
plt_result_repeat(result_repeat_rfc['repeat'],
                  result_repeat_rfc['f1_rfc_ups'],
                  'o-',
                  'Количество повторений',
                  'F1-мера',
                  'Зависимость F1-меры от количества повторений для модели \n случайного леса с увеличенной обучающей выборкой')

plt.show()

# %% [markdown]
# Судя по графику, количество повторений позволяют увеличить f1-меру слуайного леса примерно на 0.08. Оптимальное количество повторений - 7.

# %%
plt_result_repeat(result_repeat_rfc['repeat'],
                  result_repeat_rfc['roc_auc_rfc_ups'],
                  'o-',
                  'Количество повторений',
                  'AUC-ROC',
                  'Зависимость AUC-ROC от количества повторений для модели \n случайного леса с увеличенной обучающей выборкой')

#   установить границы y от 0 до 1 >
plt.ylim([0.0, 1.0])

plt.show()

# %% [markdown]
# Итак, лучшее значение f1-меры для модели решающего дерева с увеличенной выборкой:

# %%
best_f1_rfc_ups
# Out:
# 0.5965463108320251

# %% [markdown]
# Это соответствует количеству повторений при увеличении выборки:

# %%
best_rfc_repeat
# Out:
# 11

# %% [markdown]
# ### Уменьшение выборки

# %% [markdown]
# Воспользуемся техникой техникой **downsampling**.
#
# Преобразование проходит в несколько этапов:
# - Разделить обучающую выборку на отрицательные и положительные объекты;
# - Случайным образом отбросить часть из отрицательных объектов;
# - С учётом полученных данных создать новую обучающую выборку;
# - Перемешать данные. Положительные не должны идти следом за отрицательными: алгоритмам будет сложнее обучаться.

# %% [markdown]
# Чтобы выбросить из таблицы случайные элементы, применим функцию `sample()`.
#
# На вход она принимает аргумент `frac` (от англ. fraction, «доля»). Возвращает случайные элементы в таком количестве, чтобы их доля от исходной таблицы была равна `frac`.

# %% [markdown]
# Чтобы выполнить `downsampling`, напишите функцию `downsample()` с тремя аргументами:
# - `features` — признаки;
# - `target` — целевой признак;
# - `fraction` — доля отрицательных объектов, которые нужно сохранить.
#
# Функция вернёт признаки и целевой признак после операции `downsampling`.

# %%
def downsample(features, target, fraction):
    features_zeros = features[target == 0]
    features_ones = features[target == 1]
    target_zeros = target[target == 0]
    target_ones = target[target == 1]
    
    features_downsampled = pd.concat([features_zeros.sample(frac=fraction, random_state=12345)] + [features_ones])
    target_downsampled = pd.concat([target_zeros.sample(frac=fraction, random_state=12345)] + [target_ones])
    
    features_downsampled, target_downsampled = shuffle(features_downsampled, target_downsampled,random_state=12345)
    
    return features_downsampled, target_downsampled

# %% [markdown]
# #### Модель логистической регрессии с уменьшенной выборкой

# %% [markdown]
# Создадим функцию, чтобы варьировать значение `fraction` для различных моделей.
# Функция будет похожа на ту, которую мы записали для исследования влияния коилчества повторений на F1-меру и AUC-ROC.

# %%
def model_dwns_research(name,
                        model_type,
                        min_fraction,
                        step_fraction):
    f1_dwns_array = []
    roc_auc_dwns_array = []
    result_fraction  = []
    best_model = 0
    best_f1 = 0
    best_fraction = 0
    
    #перебираем в цикле долю
    for fraction in np.arange(min_fraction,1,step_fraction):
        
        #уменьшаем размер выборки
        (features_downsampled, 
         target_downsampled) = downsample(features_train, 
                                          target_train, 
                                          fraction)
        
        #выбираем модель
        model_dwns = model_type
        
        #обучаем модель на уменьшенной тренировочной выборке
        model_dwns.fit(features_downsampled, 
                       target_downsampled)
        
        #предсказываем на валидационной
        predicted_valid_dwns = model_dwns.predict(features_valid)
        
        #вычисляем f1-меру
        f1_dwns = f1_score(target_valid, predicted_valid_dwns)
        
        #добавляем рассчитаное значение в массив
        f1_dwns_array.append(f1_dwns)
        
        #вероятность положительного класса
        proba_one_valid_dwns = proba_one_valid(model_dwns)
        
        #вычисление AUC-ROC модели
        roc_auc_dwns = roc_auc_score(target_valid, proba_one_valid_dwns)
        
        #добавляем вычисленное значение AUC-ROC
        roc_auc_dwns_array.append(roc_auc_dwns)
        
        #массив долей
        result_fraction.append(fraction)
        
        #ищем лучшую модель
        if f1_dwns>best_f1:
            best_f1 = f1_dwns
            best_model = model_dwns
            best_fraction = fraction
    
    #датафрейм для исследования результатов
    result_dwns_table = pd.DataFrame({'fraction':np.array(result_fraction),
                                      'f1_'+name+'_dwns':np.array(f1_dwns_array),
                                      'roc_auc_'+name+'_dwns':np.array(roc_auc_dwns_array)})
    
    #возвращаем - лучший результат f1, лучшую модель, лучшую долю, датафрейм с результатами
    return best_f1, best_model, best_fraction, result_dwns_table

# %% [markdown]
# Применим функцию для модели логистической регрессии:

# %%
(best_f1_lr_dwns, 
best_model_lr_dwns, 
best_fraction_lr_dwns, 
result_table_lr_dwns) = model_dwns_research('lr',
                                             LogisticRegression(random_state=12345,
                                                                solver='liblinear'),
                                             0.025,
                                             0.025)

# %% [markdown]
# Построим график зависимости f1-меры от доли от обучающей выборки:

# %%
plt_result_repeat(result_table_lr_dwns['fraction'],
                  result_table_lr_dwns['f1_lr_dwns'],
                  'o-',
                  'Fraction',
                  'F1-мера',
                  'Зависимость F1-меры от доли обучающей выборки для модели \n логистической регрессии с уменьшенной обучающей выборкой')

plt.show()

# %% [markdown]
# Из графика зависимости AUC-ROC от доли обучающей выборки видно, что с увеличением доли есть повышение AUC-ROC, затем выход на стогнацию, но увеличение незначительное: только на 2 сотых.

# %%
plt_result_repeat(result_table_lr_dwns['fraction'],
                  result_table_lr_dwns['roc_auc_lr_dwns'],
                  'o-',
                  'Fraction',
                  'AUC-ROC',
                  'Зависимость AUC-ROC от доли обучающей выборки для модели \n логистической регрессии с уменьшенной обучающей выборкой')

plt.show()

# %% [markdown]
# Наилучшая F1-мера для логистической регрессии с уменьшенной выборкой:

# %%
best_f1_lr_dwns
# Out:
# 0.5

# %% [markdown]
# Доля от обучающей выборки для лучше значения F1-меры:

# %%
best_fraction_lr_dwns
# Out:
# 0.25

# %% [markdown]
# Уменьшение выборки для логистической регрессии позволило получить f1-меру **0.5**. Оптимальная доля от обучающей выборки - 0.25.

# %% [markdown]
# #### Модель решающего дерева с уменьшенной выборкой

# %% [markdown]
# Перейдём к модели решающего дерева:

# %%
(best_f1_dtc_dwns, 
best_model_dtc_dwns, 
best_fraction_dtc_dwns, 
result_table_dtc_dwns) = model_dwns_research('dtc',
                                             DecisionTreeClassifier(random_state=12345),
                                             0.0125,
                                             0.0125)

# %% [markdown]
# Построим график зависимости F1-меры от доли обучающей выборки:

# %%
plt_result_repeat(result_table_dtc_dwns['fraction'],
                  result_table_dtc_dwns['f1_dtc_dwns'],
                  'o-',
                  'Fraction',
                  'F1-мера',
                  'Зависимость F1-меры от доли обучающей выборки для модели \n решающего дерева с уменьшенной обучающей выборкой')

plt.show()

# %% [markdown]
# Лучшее значение F1-меры для решающего дерева:

# %%
best_f1_dtc_dwns
# Out:
# 0.5273631840796019

# %% [markdown]
# При этом доля от обучающей выборки:

# %%
best_fraction_dtc_dwns
# Out:
# 0.7125

# %% [markdown]
# Для решающего дерева оптимальная доля от обучающей выборки составила **0.7125** для получения F1-меры равной **0.5274**.

# %% [markdown]
# #### Модель случайного леса с уменьшенной выборкой

# %% [markdown]
# Перейдём к модели случайного леса:

# %%
(best_f1_rfc_dwns, 
best_model_rfc_dwns, 
best_fraction_rfc_dwns, 
result_table_rfc_dwns) = model_dwns_research('rfc',
                                             RandomForestClassifier(random_state=12345),
                                             0.003125,
                                             0.003125)

# %% [markdown]
# Построим график зависмости F1-меры от доли обучающей выборки:

# %%
plt_result_repeat(result_table_rfc_dwns['fraction'],
                  result_table_rfc_dwns['f1_rfc_dwns'],
                  'o-',
                  'Fraction',
                  'F1-мера',
                  'Зависимость F1-меры от доли обучающей выборки для модели \n случайного леса с уменьшенной обучающей выборкой')

plt.show()

# %% [markdown]
# Лучшее значение F1-меры для модели случайного леса:

# %%
best_f1_rfc_dwns
# Out:
# 0.6139817629179332

# %% [markdown]
# При этом доля от обучающей выборки:

# %%
best_fraction_rfc_dwns
# Out:
# 0.5750000000000001

# %% [markdown]
# Итак, в модели случайного леса путем уменьшения обучающей выборки получилось достичь значения F1-меры **0.5899** при доле от обучающей выборки **0.55625**. Это максимально близко к целевым *0.59*. Дальнейшее улучшение модели выполним варьированием числа деревьев и уровней дерева.

# %% [markdown]
# ### Улучшение модели

# %% [markdown]
# Теперь, когда принят ряд различных мер для борьбы с дисбалансом, возьмём лучшую модель случайного леса, обученную на уменьшенной выборке, и проварьируем для неё количество деревьев и глубину решающего дерева, чтобы превысить **0.59** для F1-меры.

# %% [markdown]
# Введём счетчики для цикла:

# %%
best_model_forest_depth = None #переменная для сохранения лучшей модели на валидационной выборке
best_result_forest_f1 = 0   #переменная для лучшего результата f1-меры на валидационной выборке
best_result_est_for_depth = 0  #переменная для глубины реш. дерева лучшей модели на валидационной выборке
best_result_depth_forest = 0   #максимальная глубина решающего дерева в лучшей моделе

# %% [markdown]
# Используем вложенный цикл для поиска наилучшей модели случайного леса.
#
# Внутри цикла будем менять не только количество деревьев, но и максимальную глубину решающего дерева.
#
# Внутри цикла:
# - модель с заданным количетством деревьев и глубиной решающего дерева будет обучаться на уменьшенной оптимальным образом выборке,
# - затем будет выполняться расчет f1-меры на валидационной выборке,
# - в блоке `if` будет выполняться проверка результата расчета f1-меры на превышение максимального значения (будем искать модель с максимальной **f1-мерой**).
#
# В результате расчитаем:
# - `result_n_estimators_depth`, `result_forest_depth_f1_array` , **`result_depth_forest`**- массивы с количеством деревьев, f1-мерой и **глубиной решающего дерева** для каждого шага цикла,
# - `best_model_forest_depth` - сохранённую лушую модель случайного леса **с учетом максимальной глубины (для валидационной выборки)**,
# - `best_result_forest_f1` - результат расчета f1-меры для неё (на валидационной выборке),
# - `best_result_est_for_depth` - количество деревьев лучшей модели,
# - `best_result_depth_forest` - глубина дерева лучшей модели.

# %%
result_forest_depth_f1_array = [] #запишем сюда f1-меру для каждого варианта количества деревьев
result_n_estimators_depth = [] #сохраним количество деревьев для каждого варианта 
result_depth_forest = []       #сохраним в данной переменной максимальную глубину решающего дерева для каждого шага цикла

for est in range(11, 30,1):
    for depth in range(1,15):
        
         #уменьшаем размер выборки
        (features_downsampled, 
         target_downsampled) = downsample(features_train, 
                                          target_train, 
                                          best_fraction_rfc_dwns)
        
        # модель случайного леса с заданным количеством деревьев
        model_forest_depth = RandomForestClassifier(random_state=12345, 
                                                    n_estimators=est,
                                                    max_depth=depth)
        
       
        # обучим модель на тренировочной выборке
        model_forest_depth.fit(features_downsampled, target_downsampled)
        
        #предсказываем на валидационной
        predicted_valid_dwns =  model_forest_depth.predict(features_valid)
        
        #вычисляем f1-меру
        f1_dwns = f1_score(target_valid, predicted_valid_dwns)
       
        # посчитаем качество модели на валидационной выборке+
        #result = model_forest_depth.score(features_valid,target_valid)
        
        result_n_estimators_depth.append(est)
        result_forest_depth_f1_array.append(f1_dwns)
        result_depth_forest.append(depth)
        
        if f1_dwns > best_result_forest_f1:
            best_model_forest_depth = model_forest_depth   #сохраним наилучшую модель
            best_result_forest_f1 = f1_dwns              #сохраним наилучшее значение метрики accuracy на валидационных данных
            best_result_est_for_depth = est                #сохраним количество деревьев лучшей модели
            best_result_depth_forest = depth
#
print('Результаты наилучшей модели случайного леса для валидационной выборки:')
print("- F1-мера:", best_result_forest_f1)
print("- Количество деревьев:", best_result_est_for_depth)
print("- Максимальная глубина дерева:", best_result_depth_forest)
# Out:
# Результаты наилучшей модели случайного леса для валидационной выборки:
# - F1-мера: 0.6055900621118012
# - Количество деревьев: 21
# - Максимальная глубина дерева: 10

# %% [markdown]
# Запишем датафрейм с результатами иследования:

# %%
#датафрейм с результатами исследования модели случайного леса с учетом глубины решающего дерева
result_forest_depth = pd.DataFrame({'n_estimators':np.array(result_n_estimators_depth),
                                    'depth':np.array(result_depth_forest),
                                    'f1-score':np.array(result_forest_depth_f1_array)})

# %% [markdown]
# Визуализируем результаты расчета правильности с помощью цикла для каждого из вариантов глубины решающего дерева в модели случайного леса:

# %%
#размер графика
plt.figure(figsize=(15,8))

#выбор цветовой карты
colors = plt.cm.jet(np.linspace(0,1,14))

for depth,c in zip(range(1,15),colors):
    #строим график
    plt.plot(result_forest_depth[result_forest_depth['depth']==depth]['n_estimators'],
             result_forest_depth[result_forest_depth['depth']==depth]['f1-score'],
             '-o',
             label=depth,
             color=c
            )

#название графика
plt.title('Зависимость F1-меры на валидационной выборке от количества деревьев в модели случайного леса', fontsize=16)

#подписи осей
plt.xlabel('Количество деревьев', fontsize=16)
plt.ylabel('F1-мера на валидационной выборке', fontsize=14)

#отображение сетки
plt.grid()

plt.legend(fontsize=14)
plt.show()

# %% [markdown]
# Для иллюстрации намеренно выбрана цветовая карта `jet`: минимальной глубине 1 соответствует синий цвет (холодный). Изграфика видно, что в рассмотренном диапазоне количества деревьев увеличение количества деревеье и уровней дерева ведёт к улучшению значения F1-меры.

# %% [markdown]
# Теперь посмотрим какую роль сыграло обучение модели на уменьшенной выборки. Для этого введем модель случайного леса с лучшими параметрами:

# %%
model_good = RandomForestClassifier(random_state=12345, 
                                    n_estimators=26,
                                    max_depth=10)

# %% [markdown]
# Но обучим её на исходной тренировочной выборке:

# %%
model_good.fit(features_train, target_train)
# Out:
# RandomForestClassifier(max_depth=10, n_estimators=26, random_state=12345)

# %% [markdown]
# А теперь посчитаем значение f1-меры:

# %%
f1_score(target_valid,  model_good.predict(features_valid))
# Out:
# 0.5399644760213144

# %% [markdown]
# Борьба с дисбалансом позволила нам получить F1-меру **0.6015** на валидационной выборке вместо 0.5399 без учета дисбаланса.

# %% [markdown]
# ### Вывод

# %% [markdown]
# 1. **Взвешивание классов** улучшает f1-меру только в случае логистической регрессии:
#     - ощутимое увеличение с 0.3004 до 0.495.
#
#     В случае решающего дерева и случайного леса f1-мера немного снижается:
#     - решающее дерево с 0.4939 до 0.4781
#     - случайный лес с 0.5148 до 0.4908
#
# 2. **Увеличение выборки** улучшает f1-меру, но слабо влияет на AUC-ROC:
#     - с увеличением количества повторения в модели логистической регрессии f1-мера сначала растет примерно на 0.2 (до 0.49), затем снижается;
#     - f1-мера рашающего дерева менее чувствительна к количеству повторений увеличенной выборки: увеличение примерно на 0.06 (до 0.5);
#     - количество повторений позволяют увеличить f1-меру слуайного леса примерно на 0.08. Оптимальное количество повторений - 7,
#     - наулучшие значения AUC-ROC и f1-меры в модели случайного леса.
#
# 3. **Уменьшение выборки** позволило увеличить метрику F1:
#     - уменьшение выборки для логистической регрессии позволило получить f1-меру 0.5. Оптимальная доля от обучающей выборки - 0.25;
#     - для решающего дерева оптимальная доля от обучающей выборки составила **0.7125** для получения F1-меры равной **0.5274**;
#     - в модели случайного леса путем уменьшения обучающей выборки получилось достичь значения F1-меры **0.5899** при доле от обучающей выборки **0.55625**. Это максимально близко к целевым 0.59. Дальнейшее улучшение модели выполним варьированием числа деревьев и уровней дерева.
#
# 4. Подобрана модель **случайного леса** с количеством деревьев **26** и глубиной дерева **10**, обучение модели выполнено на *подобранной ранее уменьшенной выборке с оптимальной долей 0.55652 от обучающей выборки*. Для данной модели F1-мера на валидационной выборке составила **0.6015**.
#
# 5. Показано, что обучение на уменьшенной выборке позволило повысить F1-меру примерно на 0.06-0.07, тем самым продемонстрировано **положительное влияние учета дисбаланса на качество модели**.
#
#     Можно переходить к контрольному тестированию модели.

# %% [markdown]
# ## Тестирование модели

# %% [markdown]
# Выполним контрольное тестирование модели на отложенной в самом начале тестовой выборке, для этого вычислим F1-меру на тестовой выборке:

# %%
#вычисление f1-меры на тестовой выборке
f1_score(target_test, best_model_forest_depth.predict(features_test))
# Out:
# 0.5993883792048929

# %% [markdown]
# Итак, результат на тестовой выборке - лучше, чем на валидационной. Достигнуто значение f1-меры **0.617** на тестовой выборке.

# %% [markdown]
# Проконтролируем AUC-ROC на тестовой выборке:

# %%
#вероятности классов на тестовой выборке
proba_test = best_model_forest_depth.predict_proba(features_test)

#вероятности положительного класса
proba_one_test = proba_test[:, 1]

#вычисление AUC-ROC модели
roc_auc_score(target_test, proba_one_test)
# Out:
# 0.8497121764321091

# %% [markdown]
# Контроль AUC-ROC показывает, что результат улучшился в сравнении с первоначальными моделями. Модель проходит проверку на адекватность.

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# 1. Для исследования доступны данные о 10000 уникальных клиентов (объектов). В исходном датафрейме доступна информация о 14 признаках, целевым является `exited` - факт ухода клиента. Есть пропущенные значения в столбце Tenure, причина пропусков неизвестна. Вероятно ошибка при выгрузке данных или отсутствие информации о начале использования клиентом продуктов банка.
#
# 2. Выполнена подготовка датафрейма к дальнейшему исследованию, в частности, удалены некоторые столбцы, удалены строки с пропущенными значениями в столбце `tenure`. Выборка разбита на обучающий, валидационный и тестовый наборы данных. Выполнено кодирование категориальных и масштабирование численных признаков.
#
# 3. В данном проекте мы имеем дело с несбалансированной выборкой. Без учета дисбаланса качество моделей логистической регрессии, решающего дерева и случайного леса требует улучшения, так как f1-мера для положительного класса менее целевых 0.59.
#
# 4. **Взвешивание классов** улучшает f1-меру только в случае логистической регрессии:
#     - ощутимое увеличение с 0.3004 до 0.495.
#
#     В случае решающего дерева и случайного леса f1-мера немного снижается:
#     - решающее дерево с 0.4939 до 0.4781
#     - случайный лес с 0.5148 до 0.4908
#
# 5. **Увеличение выборки** улучшает f1-меру, но слабо влияет на AUC-ROC:
#     - с увеличением количества повторения в модели логистической регрессии f1-мера сначала растет примерно на 0.2 (до 0.49), затем снижается;
#     - f1-мера рашающего дерева менее чувствительна к количеству повторений увеличенной выборки: увеличение примерно на 0.06 (до 0.5);
#     - количество повторений позволяют увеличить f1-меру слуайного леса примерно на 0.08. Оптимальное количество повторений - 7,
#     - наулучшие значения AUC-ROC и f1-меры в модели случайного леса.
#
# 6. **Уменьшение выборки** позволило увеличить метрику F1:
#     - уменьшение выборки для логистической регрессии позволило получить f1-меру 0.5. Оптимальная доля от обучающей выборки - 0.25;
#     - для решающего дерева оптимальная доля от обучающей выборки составила **0.7125** для получения F1-меры равной **0.5274**;
#     - в модели случайного леса путем уменьшения обучающей выборки получилось достичь значения F1-меры **0.5899** при доле от обучающей выборки **0.55625**. Это максимально близко к целевым 0.59. Дальнейшее улучшение модели выполним варьированием числа деревьев и уровней дерева.
#
# 7. Подобрана модель **случайного леса** с количеством деревьев **26** и глубиной дерева **10**, обучение модели выполнено на *подобранной ранее уменьшенной выборке с оптимальной долей 0.55652 от обучающей выборки*. Для данной модели F1-мера на валидационной выборке составила **0.6015**.
#
# 8. Показано, что обучение на уменьшенной выборке позволило повысить F1-меру примерно на 0.06-0.07, тем самым продемонстрировано **положительное влияние учета дисбаланса на качество модели**.
#
# 9. Контроль лучшей модели на тестовой выборке показал **F1-score=0.617**, **AUC-ROC=0.856**. Поставленная задача выполнена.
